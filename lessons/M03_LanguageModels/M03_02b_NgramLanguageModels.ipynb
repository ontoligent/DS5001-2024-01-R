# %% [markdown]
# # NGram Language Models
#
# ```yaml
# Course:  DS 5001
# Module:  03 Lab
# Topic:   NGram Language Models
# Version: 1
# Author:  R.C. Alvarado
# Date:    12 December 2023
# ```

# %% [markdown]
# ## Purpose
#
# We now create a series of simple n-gram langage models from our small corpus and evaluate them.

# %% [markdown]
# ## Pattern
#
# 1. Import corpus &rarr; `TOKEN`, `VOCAB`.
# 2. Extract ngrams from training tokens &rarr; `NGRAM`.
# 3. Count ngrams and convert to models &rarr; `MODEL`.
# 4. Convert test sentences into tokens &rarr; `TEST_SENT`, `TEST_TOKEN`.
# 5. Extract ngrams from test tokens &rarr; `TEST_NGRAM`.
# 6. Test model by joining model information `M.i` to `TEST_NGRAM` and then summing i per sentence &rarr; `TEST_NGRAM'`, `TEST_SENT'`.
# 7. Compute model perplexity by averaging sentence information sums and exponentiating.

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Configure

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_dir = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']

# %%
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']
path_prefix = f"{output_dir}/austen-combo"
n = 3

# %% [markdown]
# ## Get Data
#
# We grab our corpus of two novels.

# %%
VOCAB = pd.read_csv(f"{path_prefix}-VOCAB.csv").set_index('term_str')
TOKEN = pd.read_csv(f"{path_prefix}-TOKENS.csv").set_index(OHCO)

# %% [markdown]
# ## Generate Models
#
# This function generates models up to the length specified.
#
# Our approach is to bind the sequence of term strings in TOKEN to itself with an offset of 1 for each value of $n$.

# %%
TOKEN
# Out:
#                                                 token_str     term_str
# book_id chap_num para_num sent_num token_num
# 1       1        0        0        0                  Sir          sir
#                                    1               Walter       walter
#                                    2               Elliot       elliot
#                                    3                   of           of
#                                    4             Kellynch     kellynch
# ...                                                   ...          ...
# 2       50       23       0        8                  and          and
#                                    9          Sensibility  sensibility
#                                    10                  by           by
#                                    11                Jane         jane
#                                    12              Austen       austen
#
# [204801 rows x 2 columns]

# %%
def get_ngrams(TOKEN, n=2, sent_key='sent_num'):

    OHCO = TOKEN.index.names
    grouper = list(OHCO)[:OHCO.index(sent_key)+1]

    PADDED = TOKEN.groupby(grouper)\
        .apply(lambda x: '<s> ' + ' '.join(x.term_str) + ' <s>')\
        .apply(lambda x: pd.Series(x.split()))\
        .stack().to_frame('term_str')
    PADDED.index.names = grouper + ['token_num']

    for i in range(1, n):
        PADDED = PADDED.join(PADDED.term_str.shift(-i), rsuffix=i)

    PADDED.columns = [f'w{j}' for j in range(n)]

    return PADDED

# %%
NG = get_ngrams(TOKEN, n=3)

# %%
NG.fillna('<s>')
# Out:
#                                                        w0        w1        w2
# book_id chap_num para_num sent_num token_num
# 1       1        0        0        0                  <s>       sir    walter
#                                    1                  sir    walter    elliot
#                                    2               walter    elliot        of
#                                    3               elliot        of  kellynch
#                                    4                   of  kellynch      hall
# ...                                                   ...       ...       ...
# 2       50       23       0        10         sensibility        by      jane
#                                    11                  by      jane    austen
#                                    12                jane    austen       <s>
#                                    13              austen       <s>       <s>
#                                    14                 <s>       <s>       <s>
#
# [232051 rows x 3 columns]

# %%
NG.iloc[:,:3]
# Out:
#                                                        w0        w1        w2
# book_id chap_num para_num sent_num token_num
# 1       1        0        0        0                  <s>       sir    walter
#                                    1                  sir    walter    elliot
#                                    2               walter    elliot        of
#                                    3               elliot        of  kellynch
#                                    4                   of  kellynch      hall
# ...                                                   ...       ...       ...
# 2       50       23       0        10         sensibility        by      jane
#                                    11                  by      jane    austen
#                                    12                jane    austen       <s>
#                                    13              austen       <s>      None
#                                    14                 <s>      None      None
#
# [232051 rows x 3 columns]

# %%
def get_ngram_counts(NGRAM):
    "Compress the sequences into counts"
    
    n = len(NGRAM.columns)
    C = [None for i in range(n)]
    
    for i in range(n):

        # Count distinct ngrams
        C[i] = NGRAM.iloc[:, :i+1].value_counts().to_frame('n').sort_index()
    
        # Get joint probabilities (MLE)
        C[i]['p'] = C[i].n / C[i].n.sum()
        C[i]['i'] = np.log2(1/C[i].p)

        # Get conditional probabilities (MLE)
        if i > 0:
            C[i]['cp'] = C[i].n / C[i-1].n
            C[i]['ci'] = np.log2(1/C[i].cp)
            
    return C

# %% [markdown]
# Generate unigram, bigram, and trigram models.

# %%
M = get_ngram_counts(NG)

# %%
M[0].sort_values('n')
# Out:
#                  n         p          i
# w0
# scolding         1  0.000004  17.824082
# seducer          1  0.000004  17.824082
# diversified      1  0.000004  17.824082
# seduced          1  0.000004  17.824082
# diverting        1  0.000004  17.824082
# ...            ...       ...        ...
# of            6146  0.026486   5.238650
# and           6290  0.027106   5.205238
# to            6923  0.029834   5.066901
# the           7435  0.032040   4.963965
# <s>          27250  0.117431   3.090114
#
# [8239 rows x 3 columns]

# %%
M[1].sample(5)
# Out:
#                         n         p          i        cp         ci
# w0        w1
# any       creature      1  0.000004  17.824076  0.001695   9.204571
# am        sorry        13  0.000056  14.123636  0.031707   4.979040
# and       laugh         2  0.000009  16.824076  0.000318  11.618844
# exquisite grace         1  0.000004  17.824076  0.100000   3.321928
# the       importunate   1  0.000004  17.824076  0.000134  12.860117

# %%
M[2].sample(5)
# Out:
#                            n         p         i        cp        ci
# w0     w1       w2
# little way      our        1  0.000004  17.82407  0.500000  1.000000
# <s>    was      she        1  0.000004  17.82407  0.032258  4.954196
# not    enough   to         1  0.000004  17.82407  0.500000  1.000000
# to     allenham satisfied  1  0.000004  17.82407  0.200000  2.321928
# she    started  as         1  0.000004  17.82407  0.500000  1.000000

# %%
M[2].loc[('captain','wentworth')].sort_values('n', ascending=False).head()
# Out:
#       n         p          i        cp        ci
# w2
# s    26  0.000112  13.123630  0.132653  2.914270
# <s>  24  0.000103  13.239107  0.122449  3.029747
# was  15  0.000065  13.917179  0.076531  3.707819
# in    8  0.000034  14.824070  0.040816  4.614710
# had   7  0.000030  15.016715  0.035714  4.807355

# %%
M[2].loc[('anne','elliot')].sort_values('n', ascending=False).head()
# Out:
#        n         p          i        cp        ci
# w2
# <s>    5  0.000022  15.502142  0.217391  2.201634
# and    3  0.000013  16.239107  0.130435  2.938599
# as     2  0.000009  16.824070  0.086957  3.523562
# with   2  0.000009  16.824070  0.086957  3.523562
# again  1  0.000004  17.824070  0.043478  4.523562

# %% [markdown]
# ## Predict Sentences

# %% [markdown]
# ### Get a list of test sentences

# %%
test_sentences = """
I love you
I love cars
I want to
Anne said to
said to her
he said to
she said to
said to him
she read the
she went to
robots fly ufos
""".split('\n')[1:-1]

# %% [markdown]
# ### Convert list to TEST_SENT

# %%
TEST_SENT = pd.DataFrame({'sent_str':test_sentences})
TEST_SENT.index.name = 'sent_num'

# %%
TEST_SENT
# Out:
#                  sent_str
# sent_num
# 0              I love you
# 1             I love cars
# 2               I want to
# 3            Anne said to
# 4             said to her
# 5              he said to
# 6             she said to
# 7             said to him
# 8            she read the
# 9             she went to
# 10        robots fly ufos

# %% [markdown]
# ### Convert TEST_SENT to TEST_TOKEN

# %%
TEST_TOKEN = TEST_SENT.sent_str.str.split(expand=True).stack().to_frame('token_str')
TEST_TOKEN.index.names = ['sent_num', 'token_num']
TEST_TOKEN['term_str'] = TEST_TOKEN.token_str.str.replace(r'[\W_]+', '').str.lower()

# %%
TEST_TOKEN
# Out:
#                    token_str term_str
# sent_num token_num
# 0        0                 I        i
#          1              love     love
#          2               you      you
# 1        0                 I        i
#          1              love     love
#          2              cars     cars
# 2        0                 I        i
#          1              want     want
#          2                to       to
# 3        0              Anne     anne
#          1              said     said
#          2                to       to
# 4        0              said     said
#          1                to       to
#          2               her      her
# 5        0                he       he
#          1              said     said
#          2                to       to
# 6        0               she      she
#          1              said     said
#          2                to       to
# 7        0              said     said
#          1                to       to
#          2               him      him
# 8        0               she      she
#          1              read     read
#          2               the      the
# 9        0               she      she
#          1              went     went
#          2                to       to
# 10       0            robots   robots
#          1               fly      fly
#          2              ufos     ufos

# %% [markdown]
# ### Extract TEST_NGRAMS from TEST_TOKEN

# %%
# TEST_TOKEN

# %%
TEST_NGRAMS = get_ngrams(TEST_TOKEN, n=3, sent_key='sent_num')

# %%
TEST_NGRAMS.head(10)
# Out:
#                       w0    w1    w2
# sent_num token_num
# 0        0           <s>     i  love
#          1             i  love   you
#          2          love   you   <s>
#          3           you   <s>   <s>
#          4           <s>   <s>     i
# 1        0           <s>     i  love
#          1             i  love  cars
#          2          love  cars   <s>
#          3          cars   <s>   <s>
#          4           <s>   <s>     i

# %% [markdown]
# ### Test the model
#
# We test by joining the test ngrams with the model and then saving aggregate statistics to the sentence dataframe.
#
# Note that testing is a special case of the split-apply-combine pattern.

# %%
def test_model(model, test_ngrams):

    # Get the model level and info feature
    n = len(model.index.names) - 1 
    f = 'c' * bool(n) + 'i'        

    # Do the test by join and then split-apply-combine
    T = test_ngrams.join(model[f], on=model.index.names).fillna(model[f].max()).copy()
    
    R = T.groupby('sent_num')[f].agg(['sum','mean'])
    R['pp'] = np.exp2(R['mean'])
    
    return R

# %% [markdown]
# ### Run tests and save as RESULT

# %%
# TEST_NGRAMS

# %%
RESULT = pd.concat(
    [test_model(M[i], TEST_NGRAMS.iloc[:,:i+1]) for i in range(len(M))],
    keys=[f"M{n}" for n in range(len(M))],
    axis=1
)

# %%
RESULT.style.background_gradient()
# Out:
# <style type="text/css">
# #T_9b7c2_row0_col0, #T_9b7c2_row0_col1, #T_9b7c2_row8_col0, #T_9b7c2_row8_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_9b7c2_row0_col2, #T_9b7c2_row8_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_9b7c2_row0_col3, #T_9b7c2_row0_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_9b7c2_row0_col5, #T_9b7c2_row0_col8, #T_9b7c2_row2_col5, #T_9b7c2_row3_col5, #T_9b7c2_row4_col0, #T_9b7c2_row4_col1, #T_9b7c2_row4_col2, #T_9b7c2_row4_col3, #T_9b7c2_row4_col4, #T_9b7c2_row4_col5, #T_9b7c2_row4_col8, #T_9b7c2_row5_col2, #T_9b7c2_row5_col5, #T_9b7c2_row5_col8, #T_9b7c2_row6_col2, #T_9b7c2_row6_col5, #T_9b7c2_row6_col8, #T_9b7c2_row7_col2, #T_9b7c2_row7_col3, #T_9b7c2_row7_col4, #T_9b7c2_row7_col5, #T_9b7c2_row7_col6, #T_9b7c2_row7_col7, #T_9b7c2_row7_col8, #T_9b7c2_row9_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9b7c2_row0_col6, #T_9b7c2_row0_col7, #T_9b7c2_row3_col0, #T_9b7c2_row3_col1, #T_9b7c2_row5_col3, #T_9b7c2_row5_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_9b7c2_row1_col0, #T_9b7c2_row1_col1 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_9b7c2_row1_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_9b7c2_row1_col3, #T_9b7c2_row1_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_9b7c2_row1_col5, #T_9b7c2_row3_col8, #T_9b7c2_row6_col0, #T_9b7c2_row6_col1, #T_9b7c2_row8_col5, #T_9b7c2_row9_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_9b7c2_row1_col6, #T_9b7c2_row1_col7 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_9b7c2_row1_col8 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_9b7c2_row2_col0, #T_9b7c2_row2_col1, #T_9b7c2_row2_col3, #T_9b7c2_row2_col4, #T_9b7c2_row9_col0, #T_9b7c2_row9_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_9b7c2_row2_col2, #T_9b7c2_row3_col2, #T_9b7c2_row9_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_9b7c2_row2_col6, #T_9b7c2_row2_col7 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_9b7c2_row2_col8, #T_9b7c2_row5_col0, #T_9b7c2_row5_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_9b7c2_row3_col3, #T_9b7c2_row3_col4 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_9b7c2_row3_col6, #T_9b7c2_row3_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_9b7c2_row4_col6, #T_9b7c2_row4_col7, #T_9b7c2_row7_col0, #T_9b7c2_row7_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_9b7c2_row5_col6, #T_9b7c2_row5_col7, #T_9b7c2_row8_col8 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_9b7c2_row6_col3, #T_9b7c2_row6_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_9b7c2_row6_col6, #T_9b7c2_row6_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_9b7c2_row8_col3, #T_9b7c2_row8_col4 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_9b7c2_row8_col6, #T_9b7c2_row8_col7 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_9b7c2_row9_col3, #T_9b7c2_row9_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_9b7c2_row9_col6, #T_9b7c2_row9_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_9b7c2_row10_col0, #T_9b7c2_row10_col1, #T_9b7c2_row10_col2, #T_9b7c2_row10_col3, #T_9b7c2_row10_col4, #T_9b7c2_row10_col5, #T_9b7c2_row10_col6, #T_9b7c2_row10_col7, #T_9b7c2_row10_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9b7c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b7c2_level0_col0" class="col_heading level0 col0" colspan="3">M0</th>
#       <th id="T_9b7c2_level0_col3" class="col_heading level0 col3" colspan="3">M1</th>
#       <th id="T_9b7c2_level0_col6" class="col_heading level0 col6" colspan="3">M2</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_9b7c2_level1_col0" class="col_heading level1 col0" >sum</th>
#       <th id="T_9b7c2_level1_col1" class="col_heading level1 col1" >mean</th>
#       <th id="T_9b7c2_level1_col2" class="col_heading level1 col2" >pp</th>
#       <th id="T_9b7c2_level1_col3" class="col_heading level1 col3" >sum</th>
#       <th id="T_9b7c2_level1_col4" class="col_heading level1 col4" >mean</th>
#       <th id="T_9b7c2_level1_col5" class="col_heading level1 col5" >pp</th>
#       <th id="T_9b7c2_level1_col6" class="col_heading level1 col6" >sum</th>
#       <th id="T_9b7c2_level1_col7" class="col_heading level1 col7" >mean</th>
#       <th id="T_9b7c2_level1_col8" class="col_heading level1 col8" >pp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b7c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b7c2_row0_col0" class="data row0 col0" >30.317702</td>
#       <td id="T_9b7c2_row0_col1" class="data row0 col1" >6.063540</td>
#       <td id="T_9b7c2_row0_col2" class="data row0 col2" >66.881740</td>
#       <td id="T_9b7c2_row0_col3" class="data row0 col3" >23.072274</td>
#       <td id="T_9b7c2_row0_col4" class="data row0 col4" >4.614455</td>
#       <td id="T_9b7c2_row0_col5" class="data row0 col5" >24.495670</td>
#       <td id="T_9b7c2_row0_col6" class="data row0 col6" >27.052688</td>
#       <td id="T_9b7c2_row0_col7" class="data row0 col7" >5.410538</td>
#       <td id="T_9b7c2_row0_col8" class="data row0 col8" >42.533792</td>
#     </tr>
#     <tr>
#       <th id="T_9b7c2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b7c2_row1_col0" class="data row1 col0" >41.146632</td>
#       <td id="T_9b7c2_row1_col1" class="data row1 col1" >8.229326</td>
#       <td id="T_9b7c2_row1_col2" class="data row1 col2" >300.105601</td>
#       <td id="T_9b7c2_row1_col3" class="data row1 col3" >43.785131</td>
#       <td id="T_9b7c2_row1_col4" class="data row1 col4" >8.757026</td>
#       <td id="T_9b7c2_row1_col5" class="data row1 col5" >432.640857</td>
#       <td id="T_9b7c2_row1_col6" class="data row1 col6" >52.935451</td>
#       <td id="T_9b7c2_row1_col7" class="data row1 col7" >10.587090</td>
#       <td id="T_9b7c2_row1_col8" class="data row1 col8" >1538.266952</td>
#     </tr>
#     <tr>
#       <th id="T_9b7c2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b7c2_row2_col0" class="data row2 col0" >29.074815</td>
#       <td id="T_9b7c2_row2_col1" class="data row2 col1" >5.814963</td>
#       <td id="T_9b7c2_row2_col2" class="data row2 col2" >56.296097</td>
#       <td id="T_9b7c2_row2_col3" class="data row2 col3" >26.528941</td>
#       <td id="T_9b7c2_row2_col4" class="data row2 col4" >5.305788</td>
#       <td id="T_9b7c2_row2_col5" class="data row2 col5" >39.555000</td>
#       <td id="T_9b7c2_row2_col6" class="data row2 col6" >42.494785</td>
#       <td id="T_9b7c2_row2_col7" class="data row2 col7" >8.498957</td>
#       <td id="T_9b7c2_row2_col8" class="data row2 col8" >361.777006</td>
#     </tr>
#     <tr>
#       <th id="T_9b7c2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b7c2_row3_col0" class="data row3 col0" >28.766060</td>
#       <td id="T_9b7c2_row3_col1" class="data row3 col1" >5.753212</td>
#       <td id="T_9b7c2_row3_col2" class="data row3 col2" >53.937325</td>
#       <td id="T_9b7c2_row3_col3" class="data row3 col3" >29.798316</td>
#       <td id="T_9b7c2_row3_col4" class="data row3 col4" >5.959663</td>
#       <td id="T_9b7c2_row3_col5" class="data row3 col5" >62.235389</td>
#       <td id="T_9b7c2_row3_col6" class="data row3 col6" >40.232394</td>
#       <td id="T_9b7c2_row3_col7" class="data row3 col7" >8.046479</td>
#       <td id="T_9b7c2_row3_col8" class="data row3 col8" >264.381761</td>
#     </tr>
#     <tr>
#       <th id="T_9b7c2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b7c2_row4_col0" class="data row4 c

# %% [markdown]
# Show results for a given model.

# %%
pd.concat([TEST_SENT, RESULT['M2']], axis=1).sort_values('pp').style.background_gradient()
# Out:
# <style type="text/css">
# #T_7ef3c_row0_col1, #T_7ef3c_row0_col2, #T_7ef3c_row0_col3, #T_7ef3c_row1_col3, #T_7ef3c_row2_col3, #T_7ef3c_row3_col3, #T_7ef3c_row4_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7ef3c_row1_col1, #T_7ef3c_row1_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_7ef3c_row2_col1, #T_7ef3c_row2_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_7ef3c_row3_col1, #T_7ef3c_row3_col2, #T_7ef3c_row9_col3 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_7ef3c_row4_col1, #T_7ef3c_row4_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_7ef3c_row5_col1, #T_7ef3c_row5_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_7ef3c_row5_col3, #T_7ef3c_row6_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7ef3c_row6_col1, #T_7ef3c_row6_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_7ef3c_row7_col1, #T_7ef3c_row7_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_7ef3c_row7_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_7ef3c_row8_col1, #T_7ef3c_row8_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_7ef3c_row8_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_7ef3c_row9_col1, #T_7ef3c_row9_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_7ef3c_row10_col1, #T_7ef3c_row10_col2, #T_7ef3c_row10_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7ef3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ef3c_level0_col0" class="col_heading level0 col0" >sent_str</th>
#       <th id="T_7ef3c_level0_col1" class="col_heading level0 col1" >sum</th>
#       <th id="T_7ef3c_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_7ef3c_level0_col3" class="col_heading level0 col3" >pp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ef3c_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_7ef3c_row0_col0" class="data row0 col0" >said to him</td>
#       <td id="T_7ef3c_row0_col1" class="data row0 col1" >22.947928</td>
#       <td id="T_7ef3c_row0_col2" class="data row0 col2" >4.589586</td>
#       <td id="T_7ef3c_row0_col3" class="data row0 col3" >24.077033</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_7ef3c_row1_col0" class="data row1 col0" >said to her</td>
#       <td id="T_7ef3c_row1_col1" class="data row1 col1" >25.400683</td>
#       <td id="T_7ef3c_row1_col2" class="data row1 col2" >5.080137</td>
#       <td id="T_7ef3c_row1_col3" class="data row1 col3" >33.827779</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_7ef3c_row2_col0" class="data row2 col0" >I love you</td>
#       <td id="T_7ef3c_row2_col1" class="data row2 col1" >27.052688</td>
#       <td id="T_7ef3c_row2_col2" class="data row2 col2" >5.410538</td>
#       <td id="T_7ef3c_row2_col3" class="data row2 col3" >42.533792</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_7ef3c_row3_col0" class="data row3 col0" >he said to</td>
#       <td id="T_7ef3c_row3_col1" class="data row3 col1" >28.679129</td>
#       <td id="T_7ef3c_row3_col2" class="data row3 col2" >5.735826</td>
#       <td id="T_7ef3c_row3_col3" class="data row3 col3" >53.291214</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_7ef3c_row4_col0" class="data row4 col0" >she said to</td>
#       <td id="T_7ef3c_row4_col1" class="data row4 col1" >29.812309</td>
#       <td id="T_7ef3c_row4_col2" class="data row4 col2" >5.962462</td>
#       <td id="T_7ef3c_row4_col3" class="data row4 col3" >62.356228</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_7ef3c_row5_col0" class="data row5 col0" >she went to</td>
#       <td id="T_7ef3c_row5_col1" class="data row5 col1" >38.371822</td>
#       <td id="T_7ef3c_row5_col2" class="data row5 col2" >7.674364</td>
#       <td id="T_7ef3c_row5_col3" class="data row5 col3" >204.274383</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_7ef3c_row6_col0" class="data row6 col0" >Anne said to</td>
#       <td id="T_7ef3c_row6_col1" class="data row6 col1" >40.232394</td>
#       <td id="T_7ef3c_row6_col2" class="data row6 col2" >8.046479</td>
#       <td id="T_7ef3c_row6_col3" class="data row6 col3" >264.381761</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_7ef3c_row7_col0" class="data row7 col0" >I want to</td>
#       <td id="T_7ef3c_row7_col1" class="data row7 col1" >42.494785</td>
#       <td id="T_7ef3c_row7_col2" class="data row7 col2" >8.498957</td>
#       <td id="T_7ef3c_row7_col3" class="data row7 col3" >361.777006</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_7ef3c_row8_col0" class="data row8 col0" >I love cars</td>
#       <td id="T_7ef3c_row8_col1" class="data row8 col1" >52.935451</td>
#       <td id="T_7ef3c_row8_col2" class="data row8 col2" >10.587090</td>
#       <td id="T_7ef3c_row8_col3" class="data row8 col3" >1538.266952</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_7ef3c_row9_col0" class="data row9 col0" >she read the</td>
#       <td id="T_7ef3c_row9_col1" class="data row9 col1" >53.935451</td>
#       <td id="T_7ef3c_row9_col2" class="data row9 col2" >10.787090</td>
#       <td id="T_7ef3c_row9_col3" class="data row9 col3" >1767.004717</td>
#     </tr>
#     <tr>
#       <th id="T_7ef3c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7ef3c_row10_col0" class="data row10 col0" >robots fly ufos</td>
#       <td id="T_7ef3c_row10_col1" class="data row10 col1" >68.669314</td>
#       <td id="T_7ef3c_row10_col2" class="data row10 col2" >13.733863</td>
#       <td id="T_7ef3c_row10_col3" class="data row10 col3" >13624.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Compare a feature across models.
#
# We use `.swaplevel()` to change the order of the column levels to make selection easy.

# %%
RESULT.swaplevel(axis=1).style.background_gradient()
# Out:
# <style type="text/css">
# #T_99f63_row0_col0, #T_99f63_row0_col1, #T_99f63_row8_col0, #T_99f63_row8_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_99f63_row0_col2, #T_99f63_row8_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_99f63_row0_col3, #T_99f63_row0_col4 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_99f63_row0_col5, #T_99f63_row0_col8, #T_99f63_row2_col5, #T_99f63_row3_col5, #T_99f63_row4_col0, #T_99f63_row4_col1, #T_99f63_row4_col2, #T_99f63_row4_col3, #T_99f63_row4_col4, #T_99f63_row4_col5, #T_99f63_row4_col8, #T_99f63_row5_col2, #T_99f63_row5_col5, #T_99f63_row5_col8, #T_99f63_row6_col2, #T_99f63_row6_col5, #T_99f63_row6_col8, #T_99f63_row7_col2, #T_99f63_row7_col3, #T_99f63_row7_col4, #T_99f63_row7_col5, #T_99f63_row7_col6, #T_99f63_row7_col7, #T_99f63_row7_col8, #T_99f63_row9_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_99f63_row0_col6, #T_99f63_row0_col7, #T_99f63_row3_col0, #T_99f63_row3_col1, #T_99f63_row5_col3, #T_99f63_row5_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_99f63_row1_col0, #T_99f63_row1_col1 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_99f63_row1_col2 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_99f63_row1_col3, #T_99f63_row1_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_99f63_row1_col5, #T_99f63_row3_col8, #T_99f63_row6_col0, #T_99f63_row6_col1, #T_99f63_row8_col5, #T_99f63_row9_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_99f63_row1_col6, #T_99f63_row1_col7 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_99f63_row1_col8 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_99f63_row2_col0, #T_99f63_row2_col1, #T_99f63_row2_col3, #T_99f63_row2_col4, #T_99f63_row9_col0, #T_99f63_row9_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_99f63_row2_col2, #T_99f63_row3_col2, #T_99f63_row9_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_99f63_row2_col6, #T_99f63_row2_col7 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_99f63_row2_col8, #T_99f63_row5_col0, #T_99f63_row5_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_99f63_row3_col3, #T_99f63_row3_col4 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_99f63_row3_col6, #T_99f63_row3_col7 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_99f63_row4_col6, #T_99f63_row4_col7, #T_99f63_row7_col0, #T_99f63_row7_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_99f63_row5_col6, #T_99f63_row5_col7, #T_99f63_row8_col8 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_99f63_row6_col3, #T_99f63_row6_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_99f63_row6_col6, #T_99f63_row6_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_99f63_row8_col3, #T_99f63_row8_col4 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_99f63_row8_col6, #T_99f63_row8_col7 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_99f63_row9_col3, #T_99f63_row9_col4 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_99f63_row9_col6, #T_99f63_row9_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_99f63_row10_col0, #T_99f63_row10_col1, #T_99f63_row10_col2, #T_99f63_row10_col3, #T_99f63_row10_col4, #T_99f63_row10_col5, #T_99f63_row10_col6, #T_99f63_row10_col7, #T_99f63_row10_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_99f63">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99f63_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_99f63_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_99f63_level0_col2" class="col_heading level0 col2" >pp</th>
#       <th id="T_99f63_level0_col3" class="col_heading level0 col3" >sum</th>
#       <th id="T_99f63_level0_col4" class="col_heading level0 col4" >mean</th>
#       <th id="T_99f63_level0_col5" class="col_heading level0 col5" >pp</th>
#       <th id="T_99f63_level0_col6" class="col_heading level0 col6" >sum</th>
#       <th id="T_99f63_level0_col7" class="col_heading level0 col7" >mean</th>
#       <th id="T_99f63_level0_col8" class="col_heading level0 col8" >pp</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_99f63_level1_col0" class="col_heading level1 col0" >M0</th>
#       <th id="T_99f63_level1_col1" class="col_heading level1 col1" >M0</th>
#       <th id="T_99f63_level1_col2" class="col_heading level1 col2" >M0</th>
#       <th id="T_99f63_level1_col3" class="col_heading level1 col3" >M1</th>
#       <th id="T_99f63_level1_col4" class="col_heading level1 col4" >M1</th>
#       <th id="T_99f63_level1_col5" class="col_heading level1 col5" >M1</th>
#       <th id="T_99f63_level1_col6" class="col_heading level1 col6" >M2</th>
#       <th id="T_99f63_level1_col7" class="col_heading level1 col7" >M2</th>
#       <th id="T_99f63_level1_col8" class="col_heading level1 col8" >M2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f63_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99f63_row0_col0" class="data row0 col0" >30.317702</td>
#       <td id="T_99f63_row0_col1" class="data row0 col1" >6.063540</td>
#       <td id="T_99f63_row0_col2" class="data row0 col2" >66.881740</td>
#       <td id="T_99f63_row0_col3" class="data row0 col3" >23.072274</td>
#       <td id="T_99f63_row0_col4" class="data row0 col4" >4.614455</td>
#       <td id="T_99f63_row0_col5" class="data row0 col5" >24.495670</td>
#       <td id="T_99f63_row0_col6" class="data row0 col6" >27.052688</td>
#       <td id="T_99f63_row0_col7" class="data row0 col7" >5.410538</td>
#       <td id="T_99f63_row0_col8" class="data row0 col8" >42.533792</td>
#     </tr>
#     <tr>
#       <th id="T_99f63_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99f63_row1_col0" class="data row1 col0" >41.146632</td>
#       <td id="T_99f63_row1_col1" class="data row1 col1" >8.229326</td>
#       <td id="T_99f63_row1_col2" class="data row1 col2" >300.105601</td>
#       <td id="T_99f63_row1_col3" class="data row1 col3" >43.785131</td>
#       <td id="T_99f63_row1_col4" class="data row1 col4" >8.757026</td>
#       <td id="T_99f63_row1_col5" class="data row1 col5" >432.640857</td>
#       <td id="T_99f63_row1_col6" class="data row1 col6" >52.935451</td>
#       <td id="T_99f63_row1_col7" class="data row1 col7" >10.587090</td>
#       <td id="T_99f63_row1_col8" class="data row1 col8" >1538.266952</td>
#     </tr>
#     <tr>
#       <th id="T_99f63_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99f63_row2_col0" class="data row2 col0" >29.074815</td>
#       <td id="T_99f63_row2_col1" class="data row2 col1" >5.814963</td>
#       <td id="T_99f63_row2_col2" class="data row2 col2" >56.296097</td>
#       <td id="T_99f63_row2_col3" class="data row2 col3" >26.528941</td>
#       <td id="T_99f63_row2_col4" class="data row2 col4" >5.305788</td>
#       <td id="T_99f63_row2_col5" class="data row2 col5" >39.555000</td>
#       <td id="T_99f63_row2_col6" class="data row2 col6" >42.494785</td>
#       <td id="T_99f63_row2_col7" class="data row2 col7" >8.498957</td>
#       <td id="T_99f63_row2_col8" class="data row2 col8" >361.777006</td>
#     </tr>
#     <tr>
#       <th id="T_99f63_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99f63_row3_col0" class="data row3 col0" >28.766060</td>
#       <td id="T_99f63_row3_col1" class="data row3 col1" >5.753212</td>
#       <td id="T_99f63_row3_col2" class="data row3 col2" >53.937325</td>
#       <td id="T_99f63_row3_col3" class="data row3 col3" >29.798316</td>
#       <td id="T_99f63_row3_col4" class="data row3 col4" >5.959663</td>
#       <td

# %%
RESULT.swaplevel(axis=1)['pp'].style.background_gradient()
# Out:
# <style type="text/css">
# #T_99fd0_row0_col0, #T_99fd0_row8_col0 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_99fd0_row0_col1, #T_99fd0_row0_col2, #T_99fd0_row2_col1, #T_99fd0_row3_col1, #T_99fd0_row4_col0, #T_99fd0_row4_col1, #T_99fd0_row4_col2, #T_99fd0_row5_col0, #T_99fd0_row5_col1, #T_99fd0_row5_col2, #T_99fd0_row6_col0, #T_99fd0_row6_col1, #T_99fd0_row6_col2, #T_99fd0_row7_col0, #T_99fd0_row7_col1, #T_99fd0_row7_col2, #T_99fd0_row9_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_99fd0_row1_col0 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_99fd0_row1_col1, #T_99fd0_row3_col2, #T_99fd0_row8_col1, #T_99fd0_row9_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_99fd0_row1_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_99fd0_row2_col0, #T_99fd0_row3_col0, #T_99fd0_row9_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_99fd0_row2_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_99fd0_row8_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_99fd0_row10_col0, #T_99fd0_row10_col1, #T_99fd0_row10_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_99fd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99fd0_level0_col0" class="col_heading level0 col0" >M0</th>
#       <th id="T_99fd0_level0_col1" class="col_heading level0 col1" >M1</th>
#       <th id="T_99fd0_level0_col2" class="col_heading level0 col2" >M2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99fd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99fd0_row0_col0" class="data row0 col0" >66.881740</td>
#       <td id="T_99fd0_row0_col1" class="data row0 col1" >24.495670</td>
#       <td id="T_99fd0_row0_col2" class="data row0 col2" >42.533792</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99fd0_row1_col0" class="data row1 col0" >300.105601</td>
#       <td id="T_99fd0_row1_col1" class="data row1 col1" >432.640857</td>
#       <td id="T_99fd0_row1_col2" class="data row1 col2" >1538.266952</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99fd0_row2_col0" class="data row2 col0" >56.296097</td>
#       <td id="T_99fd0_row2_col1" class="data row2 col1" >39.555000</td>
#       <td id="T_99fd0_row2_col2" class="data row2 col2" >361.777006</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99fd0_row3_col0" class="data row3 col0" >53.937325</td>
#       <td id="T_99fd0_row3_col1" class="data row3 col1" >62.235389</td>
#       <td id="T_99fd0_row3_col2" class="data row3 col2" >264.381761</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99fd0_row4_col0" class="data row4 col0" >36.096597</td>
#       <td id="T_99fd0_row4_col1" class="data row4 col1" >18.528706</td>
#       <td id="T_99fd0_row4_col2" class="data row4 col2" >33.827779</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99fd0_row5_col0" class="data row5 col0" >40.621648</td>
#       <td id="T_99fd0_row5_col1" class="data row5 col1" >35.424359</td>
#       <td id="T_99fd0_row5_col2" class="data row5 col2" >53.291214</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99fd0_row6_col0" class="data row6 col0" >38.375378</td>
#       <td id="T_99fd0_row6_col1" class="data row6 col1" >36.927732</td>
#       <td id="T_99fd0_row6_col2" class="data row6 col2" >62.356228</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99fd0_row7_col0" class="data row7 col0" >46.048628</td>
#       <td id="T_99fd0_row7_col1" class="data row7 col1" >18.480267</td>
#       <td id="T_99fd0_row7_col2" class="data row7 col2" >24.077033</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99fd0_row8_col0" class="data row8 col0" >66.102319</td>
#       <td id="T_99fd0_row8_col1" class="data row8 col1" >501.219175</td>
#       <td id="T_99fd0_row8_col2" class="data row8 col2" >1767.004717</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99fd0_row9_col0" class="data row9 col0" >56.977346</td>
#       <td id="T_99fd0_row9_col1" class="data row9 col1" >26.651133</td>
#       <td id="T_99fd0_row9_col2" class="data row9 col2" >204.274383</td>
#     </tr>
#     <tr>
#       <th id="T_99fd0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99fd0_row10_col0" class="data row10 col0" >3398.058431</td>
#       <td id="T_99fd0_row10_col1" class="data row10 col1" >27250.000000</td>
#       <td id="T_99fd0_row10_col2" class="data row10 col2" >13624.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
RESULT.swaplevel(axis=1)['mean'].style.background_gradient()
# Out:
# <style type="text/css">
# #T_12bb0_row0_col0, #T_12bb0_row8_col0 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_12bb0_row0_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_12bb0_row0_col2, #T_12bb0_row3_col0, #T_12bb0_row5_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_12bb0_row1_col0 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_12bb0_row1_col1 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_12bb0_row1_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_12bb0_row2_col0, #T_12bb0_row2_col1, #T_12bb0_row9_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_12bb0_row2_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_12bb0_row3_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_12bb0_row3_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_12bb0_row4_col0, #T_12bb0_row4_col1, #T_12bb0_row7_col1, #T_12bb0_row7_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_12bb0_row4_col2, #T_12bb0_row7_col0 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_12bb0_row5_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_12bb0_row5_col2 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_12bb0_row6_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_12bb0_row6_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_12bb0_row6_col2 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_12bb0_row8_col1 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_12bb0_row8_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_12bb0_row9_col1 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_12bb0_row9_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_12bb0_row10_col0, #T_12bb0_row10_col1, #T_12bb0_row10_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_12bb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12bb0_level0_col0" class="col_heading level0 col0" >M0</th>
#       <th id="T_12bb0_level0_col1" class="col_heading level0 col1" >M1</th>
#       <th id="T_12bb0_level0_col2" class="col_heading level0 col2" >M2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12bb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12bb0_row0_col0" class="data row0 col0" >6.063540</td>
#       <td id="T_12bb0_row0_col1" class="data row0 col1" >4.614455</td>
#       <td id="T_12bb0_row0_col2" class="data row0 col2" >5.410538</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_12bb0_row1_col0" class="data row1 col0" >8.229326</td>
#       <td id="T_12bb0_row1_col1" class="data row1 col1" >8.757026</td>
#       <td id="T_12bb0_row1_col2" class="data row1 col2" >10.587090</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_12bb0_row2_col0" class="data row2 col0" >5.814963</td>
#       <td id="T_12bb0_row2_col1" class="data row2 col1" >5.305788</td>
#       <td id="T_12bb0_row2_col2" class="data row2 col2" >8.498957</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_12bb0_row3_col0" class="data row3 col0" >5.753212</td>
#       <td id="T_12bb0_row3_col1" class="data row3 col1" >5.959663</td>
#       <td id="T_12bb0_row3_col2" class="data row3 col2" >8.046479</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_12bb0_row4_col0" class="data row4 col0" >5.173791</td>
#       <td id="T_12bb0_row4_col1" class="data row4 col1" >4.211690</td>
#       <td id="T_12bb0_row4_col2" class="data row4 col2" >5.080137</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_12bb0_row5_col0" class="data row5 col0" >5.344177</td>
#       <td id="T_12bb0_row5_col1" class="data row5 col1" >5.146670</td>
#       <td id="T_12bb0_row5_col2" class="data row5 col2" >5.735826</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_12bb0_row6_col0" class="data row6 col0" >5.262109</td>
#       <td id="T_12bb0_row6_col1" class="data row6 col1" >5.206633</td>
#       <td id="T_12bb0_row6_col2" class="data row6 col2" >5.962462</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_12bb0_row7_col0" class="data row7 col0" >5.525086</td>
#       <td id="T_12bb0_row7_col1" class="data row7 col1" >4.207914</td>
#       <td id="T_12bb0_row7_col2" class="data row7 col2" >4.589586</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_12bb0_row8_col0" class="data row8 col0" >6.046629</td>
#       <td id="T_12bb0_row8_col1" class="data row8 col1" >8.969298</td>
#       <td id="T_12bb0_row8_col2" class="data row8 col2" >10.787090</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_12bb0_row9_col0" class="data row9 col0" >5.832317</td>
#       <td id="T_12bb0_row9_col1" class="data row9 col1" >4.736125</td>
#       <td id="T_12bb0_row9_col2" class="data row9 col2" >7.674364</td>
#     </tr>
#     <tr>
#       <th id="T_12bb0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_12bb0_row10_col0" class="data row10 col0" >11.730495</td>
#       <td id="T_12bb0_row10_col1" class="data row10 col1" >14.733969</td>
#       <td id="T_12bb0_row10_col2" class="data row10 col2" >13.733863</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compute Model Perplexity

# %%
np.exp2(RESULT.swaplevel(axis=1)['mean'].mean())
# Out:
# M0     86.471307
# M1     92.523517
# M2    227.205460
# dtype: float64

# %% [markdown]
# In language modeling, perplexity is a measure of how well a probability model predicts a test set. It is often used to compare different models: the lower the perplexity, the better the model's performance in terms of predicting the test set. When dealing with n-gram models like unigrams, bigrams, and trigrams, the relationship between the value of 'n' and the perplexity of the model on a given test corpus can vary, depending on several factors.
#
# 1. **Data Sparsity**: As 'n' increases in n-gram models (moving from unigram to bigram to trigram), the models become more sensitive to the specific sequences of words in the training data. This can lead to an issue known as data sparsity: trigram models, for example, require a lot more data to encounter all possible word sequences of length three. If your training corpus isn't sufficiently large and diverse, trigram and higher n-gram models may suffer because they haven't seen enough examples of each word sequence during training.
#
# 2. **Generalization vs. Specificity**: Unigram models, being the simplest, have high generalizability but low specificity—they treat each word independently and don't capture the context. Trigram models, on the other hand, capture more context but might become too specific to the training data, failing to generalize well to unseen data. If the test corpus contains many word sequences not seen in the training corpus, a higher n-gram model might perform poorly, leading to higher perplexity.
#
# 3. **Model Complexity and Overfitting**: Higher n-gram models (like trigrams) are more complex and can potentially overfit the training data. Overfitting occurs when a model learns patterns that are specific to the training data, including noise and outliers, rather than capturing the underlying structure of the language. This can lead to increased perplexity on the test set, as the model is less able to generalize to unseen data.
#
# In summary, whether perplexity increases or decreases with n depends on the characteristics of your training and test data, as well as how well the model's complexity is suited to the amount and diversity of the data. In an ideal scenario with ample, diverse training data, you might expect a bigram or trigram model to outperform a unigram model, leading to lower perplexity. However, in practical scenarios, especially when dealing with limited or highly specific datasets, the relationship might not be so straightforward.

# %% [markdown]
# ## Bonus: Generate Text
#
# We use so-called "stupid back-off" to account for missing ngrams.

# %%
def generate_text(n=250):
    
    m1, m2, m3 = M
    start_word = m1.sample(weights='p').index[0][0]
    words = [start_word]
    
    for i in range(n):
        
        if len(words) == 1:
            next_word = m2.loc[start_word].sample(weights='p').index[0]
        
        elif len(words) > 1:

            # Get previous two words
            bg = tuple(words[-2:])
            
            # Try trigram model
            try:
                next_word = m3.loc[bg].sample(weights='cp').index[0]
            
            # If not in model, back off ...
            except KeyError:
                
                # Get the last word in the bigram
                ug = bg[1] 

                if ug == '<s>':
                    next_word = m1.sample(weights='p').index[0][0]
                else:
                    next_word = m2.loc[ug].sample(weights='cp').index[0]
            
        # Some words are returned as single item tuples
        if isinstance(next_word, tuple):
            next_word = next_word[0]
        
        words.append(next_word)
    
    text = ' '.join(words)
    lines = text.split('<s> <s>')
    for line in lines:
        print(line.strip().upper())

# %%
# M[1].loc['<s>']

# %%
generate_text()
# Out:
# AND EVEN WHEN HER SPIRITS WERE QUITE UNKNOWN TO MRS
# ELINOR FOR WILLOUGHBY TO BE SPEEDY
# BUT IT WAS A STRUGGLE
# AND HOW DOES HE TRAVEL
# SAID SHE AFTER THE LITTLE BOY
# SHE THANKED HEAVEN THAT SHE IS A RECOLLECTION WHICH OUGHT TO GO IMMEDIATELY TO THEIR BLESSINGS IF SHE WERE TO BE EXPRESSED
# THEY WERE BROUGHT IN AND PUT IN HIS BROTHERS AND SISTERS IN LAW WERE DEGRADED TO THE COTTAGE TO BE EMPLOYED WAS EASILY WHILED AWAY IN ABOUT FIVE MINUTES BROUGHT A GLASS OF WINE WHICH ELINOR PROCURED FOR HER BIRTH
# HERE WERE FUNDS OF ENJOYMENT
# AND SOON BE ON CORDIAL TERMS WITH THE VIEW OF THE FAMILY IT WAS A SINGLE MAN I LIKE
# HIS IMPRUDENCE HAD MADE A POINT OF CONCLUDING IT WHEN YOU ALMOST BROKE IT TO HER
# BUT MRS
# HARRIS AT FOUR O CLOCK THIS MORNING AND MUST ABIDE THE CONSEQUENCES OF HER ELDEST DAUGHTER WHOSE STEADIER JUDGMENT REJECTED SEVERAL HOUSES AS TOO LITTLE
# WHILE ADMIRAL CROFT S GIG
# SHE TURNED THROUGH THE SUBJECT WITH AN ELLIOT AND SIR WALTER ELLIOT S MANNERS BETTER THAN HER YOUNG FRIEND S USUAL STATE OF HALF ENJOYMENT
# I WAS VERY FOND OF HIS LOVE FOR HER AS THEY SLOWLY PACED THE GRADUAL ASCENT THROUGH LARGE ENCLOSURES WHERE THE REST
# FOR HAD HE BEEN EVEN OLD UGLY AND

# %%
generate_text()
# Out:
# SENTENCES BEGUN WHICH HE COULD REFER SIR WALTER ELLIOT HAS EYES UPON HIM WHICH GENERAL ATTENTION AND SHE MIGHT THINK ONLY OF AVOIDING CAPTAIN WENTWORTH HE NEED NOT BE SO UNJUST NOR SO INACCESSIBLE TO ALL HER GOOD NATURE WOULD GO
# IF WE CAN ASK
# THE ARRIVAL OF THE WORLD WHOM I LOVED HIM
# WHICH AFTERWARDS WHEN HIS ASSURANCES HIS FELICITATIONS ON A DECENT EDUCATION WAS BROUGHT TO ME
# BUT MRS
# DID I EVER KNOWN IT MANY WEEKS WE HAD BETTER LEAVE THE ROOM VACANT WE MIGHT NOT BE VERY MUCH FORGOTTEN
# KNOW HIM THEN AS I OUGHT TO BE CONSIDERED AS THE IDEAS OF DANGER
# FOR WHATEVER OTHER CLAIMS MIGHT BE THE FARTHER KNOWLEDGE OF THE HARP WHICH WAS SEEN AGAIN IN NERVOUS GRATITUDE
# THE INTERRUPTION TO PROCEED VERY SOON HAVE A VIEW OF IT ALL REPEATING HER CONVICTION OF THIS
# IT WOULD BE GLAD TO SPARE A HUNDRED A YEAR FOR ANY PLACE COULD GIVE HER EASE
# NOW THERE IS NO USE ON THESE OCCASIONS AS SHE HAD BEEN ZEALOUSLY DISCHARGING ALL THE DELIGHT OF LUCY IN WHICH SHE WAS ENTREATED TO BE AT BATH ON WEDNESDAY AND WE SPENT THE WHOLE OF HIS CAPTAIN WRITTEN THE ONLY INTELLIGIBLE MOTIVE
# I HAVE SOMETHING ELSE YOUR RESOLUTION YOUR SELF COMMAND TO MARIANNE NOR CAN I EVER SAW
# WHAT
# SO EXCEEDING AFFABLE AS SHE FEARED

# %% [markdown]
# ## Save

# %%
path_prefix = f"{output_dir}/austen-combo"
NG.to_csv(f"{path_prefix}-NG.csv")
for i in range(len(M)):
    M[i].to_csv(f"{path_prefix}-M{i}.csv", index=True)

# %% [markdown]
# # A Simple Language Model
#
# ```yaml
# Course:  DS 5001
# Module:  03 Lab
# Topic:   A Simple Language Model
# Version: 1
# Author:  R.C. Alvarado
# Date:    12 December 2023
# ```

# %% [markdown]
# ## Purpose
#
# We now create a simple unigram langage model from a set of novels and use it to predict some sample sentences.
#
# We don't worry about missing words but instead use a simple smoothing hack.
#
# This is just to demonstrate how we convert the counts from a token table into a language model, and how to use the model to predict sentences.
#
# We also demonstrate how to compute the perplexity of our results.

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Configure

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
output_dir = config['DEFAULT']['output_dir']

# %%
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']
path_prefix = f"{output_dir}/austen-combo"

# %% [markdown]
# ## Get Data
#
# We grab our corpus of two novels.

# %%
VOCAB = pd.read_csv(f"{path_prefix}-VOCAB.csv").set_index('term_str')
TOKEN = pd.read_csv(f"{path_prefix}-TOKENS.csv").set_index(OHCO)

# %%
VOCAB
# Out:
#            n
# term_str
# 1          3
# 15         1
# 16         1
# 1760       1
# 1784       1
# ...       ..
# youthful   3
# z          1
# zeal       7
# zealous    4
# zealously  2
#
# [8238 rows x 1 columns]

# %% [markdown]
# ## Create Unigram Model
#
# Our vocabulary already is a language model -- it contains information for the distribution of each word. Each word is an event in the sample space.

# %% [markdown]
# ### Extract probability features ($p$, $i$, and $h$)
#
# We use $i$ to stand for the inverse log probability of $x$, following our intuition that it represents information as "surprisal".
#
# $ i(x) = log_2(\frac{1}{p(x)}) $
#
# $i$ is the inverse of log probability, the second term in the entropy formula $ H(x) = \sum_x p(x) log_2(\frac{1}{p(x)}) $

# %%
n_tokens = VOCAB.n.sum()
n_terms = VOCAB.n.count() # same as vocab.shape[0]

# %%
VOCAB['p'] = VOCAB['n'] / n_tokens
VOCAB['p2'] = VOCAB['n'] / n_terms # Some sources say to do this
VOCAB['i'] = np.log2(1/VOCAB['p'])
VOCAB['h'] = VOCAB['p'] * VOCAB['i']

# %%
VOCAB.sort_values('p', ascending=False)
# Out:
#                  n         p        p2          i         h
# term_str
# the           7435  0.036304  0.902525   4.783746  0.173667
# to            6923  0.033804  0.840374   4.886682  0.165187
# and           6290  0.030713  0.763535   5.025019  0.154332
# of            6146  0.030010  0.746055   5.058431  0.151802
# her           3747  0.018296  0.454843   5.772343  0.105610
# ...            ...       ...       ...        ...       ...
# reservedness     1  0.000005  0.000121  17.643863  0.000086
# reserving        1  0.000005  0.000121  17.643863  0.000086
# enthusiast       1  0.000005  0.000121  17.643863  0.000086
# nipped           1  0.000005  0.000121  17.643863  0.000086
# divisions        1  0.000005  0.000121  17.643863  0.000086
#
# [8238 rows x 5 columns]

# %% [markdown]
# ### Compute entropy $H$ of the model

# %%
H = VOCAB.h.sum()

# %%
H
# Out:
# 9.149850013062554

# %% [markdown]
# ### Compute perplexity $PP$
#
# Perplexity is just the exponentization of entropy.

# %%
PP = np.exp2(H)

# %%
PP
# Out:
# 568.0405114202048

# %% [markdown]
# ### Compute redundancy $R$

# %%
Hmax = np.log2(n_terms)
R = 1 - (H/Hmax)

# %%
R
# Out:
# 0.2966024862351806

# %% [markdown]
# So, the redundancy of Austen's English from these two novels $R_{austen}$ is about $30\%$. Shannon estimated the redundancy of English $R_{english}$ to be $54\%$ (see Shannon 1953 in the Readings).

# %%
VOCAB
# Out:
#            n         p        p2          i         h
# term_str
# 1          3  0.000015  0.000364  16.058901  0.000235
# 15         1  0.000005  0.000121  17.643863  0.000086
# 16         1  0.000005  0.000121  17.643863  0.000086
# 1760       1  0.000005  0.000121  17.643863  0.000086
# 1784       1  0.000005  0.000121  17.643863  0.000086
# ...       ..       ...       ...        ...       ...
# youthful   3  0.000015  0.000364  16.058901  0.000235
# z          1  0.000005  0.000121  17.643863  0.000086
# zeal       7  0.000034  0.000850  14.836508  0.000507
# zealous    4  0.000020  0.000486  15.643863  0.000306
# zealously  2  0.000010  0.000243  16.643863  0.000163
#
# [8238 rows x 5 columns]

# %% [markdown]
# ## Predict Senteces
#
# In other words, estimate the probability of a sentence for a given language model.
#
# We first define some sentences, all of a given length.
#
# We hold length constant because probability estimates are sensitive to sentence length.

# %%
test_sentences = """
I love you
I love cars
I want to
Anne said to
said to her
he said to
she said to
said to him
she read the
she went to
robots fly ufos
""".split('\n')[1:-1]

# %%
TEST_SENT = pd.DataFrame({'sent_str':test_sentences})
TEST_SENT.index.name = 'sent_id'

# %%
TEST_SENT
# Out:
#                 sent_str
# sent_id
# 0             I love you
# 1            I love cars
# 2              I want to
# 3           Anne said to
# 4            said to her
# 5             he said to
# 6            she said to
# 7            said to him
# 8           she read the
# 9            she went to
# 10       robots fly ufos

# %%
TEST_TOKEN = TEST_SENT.sent_str.str.split(expand=True).stack().to_frame('token_str')
TEST_TOKEN.index.names = ['sent_id', 'token_num']
TEST_TOKEN['term_str'] = TEST_TOKEN.token_str.str.replace(r'[\W_]+', '').str.lower()

# %%
TEST_TOKEN
# Out:
#                   token_str term_str
# sent_id token_num
# 0       0                 I        i
#         1              love     love
#         2               you      you
# 1       0                 I        i
#         1              love     love
#         2              cars     cars
# 2       0                 I        i
#         1              want     want
#         2                to       to
# 3       0              Anne     anne
#         1              said     said
#         2                to       to
# 4       0              said     said
#         1                to       to
#         2               her      her
# 5       0                he       he
#         1              said     said
#         2                to       to
# 6       0               she      she
#         1              said     said
#         2                to       to
# 7       0              said     said
#         1                to       to
#         2               him      him
# 8       0               she      she
#         1              read     read
#         2               the      the
# 9       0               she      she
#         1              went     went
#         2                to       to
# 10      0            robots   robots
#         1               fly      fly
#         2              ufos     ufos

# %% [markdown]
# We apply the model by joining it to the test data.

# %%
TEST_TOKEN = TEST_TOKEN.join(VOCAB.p, on='term_str').fillna(VOCAB.p.min())

# %%
TEST_TOKEN.head()
# Out:
#                   token_str term_str         p       logp          i
# sent_id token_num
# 0       0                 I        i  0.015273  -6.032838   6.032838
#         1              love     love  0.000581 -10.749045  10.749045
#         2               you      you  0.008882  -6.814933   6.814933
# 1       0                 I        i  0.015273  -6.032838   6.032838
#         1              love     love  0.000581 -10.749045  10.749045

# %% [markdown]
# We get log probabilities to avoid underflow.

# %%
TEST_TOKEN['logp'] = np.log2(TEST_TOKEN.p)

# %%
TEST_SENT['logp_sum'] = TEST_TOKEN.groupby('sent_id').logp.sum()

# %%
TEST_SENT.sort_values('logp_sum', ascending=False).style.background_gradient()
# Out:
# <style type="text/css">
# #T_d747f_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_d747f_row1_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_d747f_row2_col1 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_d747f_row3_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_d747f_row4_col1 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_d747f_row5_col1, #T_d747f_row6_col1 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_d747f_row7_col1, #T_d747f_row8_col1 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_d747f_row9_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_d747f_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_d747f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d747f_level0_col0" class="col_heading level0 col0" >sent_str</th>
#       <th id="T_d747f_level0_col1" class="col_heading level0 col1" >logp_sum</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d747f_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_d747f_row0_col0" class="data row0 col0" >said to her</td>
#       <td id="T_d747f_row0_col1" class="data row0 col1" >-19.148070</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_d747f_row1_col0" class="data row1 col0" >she said to</td>
#       <td id="T_d747f_row1_col1" class="data row1 col1" >-19.589660</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_d747f_row2_col0" class="data row2 col0" >he said to</td>
#       <td id="T_d747f_row2_col1" class="data row2 col1" >-19.999999</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_d747f_row3_col0" class="data row3 col0" >said to him</td>
#       <td id="T_d747f_row3_col1" class="data row3 col1" >-20.904546</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_d747f_row4_col0" class="data row4 col0" >Anne said to</td>
#       <td id="T_d747f_row4_col1" class="data row4 col1" >-22.045175</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_d747f_row5_col0" class="data row5 col0" >I want to</td>
#       <td id="T_d747f_row5_col1" class="data row5 col1" >-22.353930</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_d747f_row6_col0" class="data row6 col0" >she went to</td>
#       <td id="T_d747f_row6_col1" class="data row6 col1" >-22.440698</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_d747f_row7_col0" class="data row7 col0" >she read the</td>
#       <td id="T_d747f_row7_col1" class="data row7 col1" >-23.512260</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row8" class="row_heading level0 row8" >0</th>
#       <td id="T_d747f_row8_col0" class="data row8 col0" >I love you</td>
#       <td id="T_d747f_row8_col1" class="data row8 col1" >-23.596817</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_d747f_row9_col0" class="data row9 col0" >I love cars</td>
#       <td id="T_d747f_row9_col1" class="data row9 col1" >-34.425747</td>
#     </tr>
#     <tr>
#       <th id="T_d747f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d747f_row10_col0" class="data row10 col0" >robots fly ufos</td>
#       <td id="T_d747f_row10_col1" class="data row10 col1" >-51.931590</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Note the log probability is just the negative of information, which we already computed in our model.
#
# So, going forward we can just do the following.
#
# Note we also compute mean $i$; we will use this below.
#
# Mean and sum of $i$ will be linearly related in this example because sentence length is constant.

# %%
TEST_TOKEN = TEST_TOKEN.join(VOCAB.i, on='term_str').fillna(VOCAB.i.max())
TEST_SENT['i_sum'] = TEST_TOKEN.groupby('sent_id').i.sum()
TEST_SENT['i_mean'] = TEST_TOKEN.groupby('sent_id').i.mean()

# %%
TEST_SENT.sort_values('i_sum').style.background_gradient()
# Out:
# <style type="text/css">
# #T_b1cb0_row0_col1, #T_b1cb0_row10_col2, #T_b1cb0_row10_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b1cb0_row0_col2, #T_b1cb0_row0_col3, #T_b1cb0_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b1cb0_row1_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_b1cb0_row1_col2, #T_b1cb0_row1_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_b1cb0_row2_col1 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_b1cb0_row2_col2, #T_b1cb0_row2_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_b1cb0_row3_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_b1cb0_row3_col2, #T_b1cb0_row3_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_b1cb0_row4_col1 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_b1cb0_row4_col2, #T_b1cb0_row4_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_b1cb0_row5_col1, #T_b1cb0_row6_col1 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_b1cb0_row5_col2, #T_b1cb0_row5_col3, #T_b1cb0_row6_col2, #T_b1cb0_row6_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b1cb0_row7_col1, #T_b1cb0_row8_col1 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_b1cb0_row7_col2, #T_b1cb0_row7_col3, #T_b1cb0_row8_col2, #T_b1cb0_row8_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_b1cb0_row9_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_b1cb0_row9_col2, #T_b1cb0_row9_col3 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1cb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1cb0_level0_col0" class="col_heading level0 col0" >sent_str</th>
#       <th id="T_b1cb0_level0_col1" class="col_heading level0 col1" >logp_sum</th>
#       <th id="T_b1cb0_level0_col2" class="col_heading level0 col2" >i_sum</th>
#       <th id="T_b1cb0_level0_col3" class="col_heading level0 col3" >i_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1cb0_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_b1cb0_row0_col0" class="data row0 col0" >said to her</td>
#       <td id="T_b1cb0_row0_col1" class="data row0 col1" >-19.148070</td>
#       <td id="T_b1cb0_row0_col2" class="data row0 col2" >19.148070</td>
#       <td id="T_b1cb0_row0_col3" class="data row0 col3" >6.382690</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_b1cb0_row1_col0" class="data row1 col0" >she said to</td>
#       <td id="T_b1cb0_row1_col1" class="data row1 col1" >-19.589660</td>
#       <td id="T_b1cb0_row1_col2" class="data row1 col2" >19.589660</td>
#       <td id="T_b1cb0_row1_col3" class="data row1 col3" >6.529887</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_b1cb0_row2_col0" class="data row2 col0" >he said to</td>
#       <td id="T_b1cb0_row2_col1" class="data row2 col1" >-19.999999</td>
#       <td id="T_b1cb0_row2_col2" class="data row2 col2" >19.999999</td>
#       <td id="T_b1cb0_row2_col3" class="data row2 col3" >6.666666</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_b1cb0_row3_col0" class="data row3 col0" >said to him</td>
#       <td id="T_b1cb0_row3_col1" class="data row3 col1" >-20.904546</td>
#       <td id="T_b1cb0_row3_col2" class="data row3 col2" >20.904546</td>
#       <td id="T_b1cb0_row3_col3" class="data row3 col3" >6.968182</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_b1cb0_row4_col0" class="data row4 col0" >Anne said to</td>
#       <td id="T_b1cb0_row4_col1" class="data row4 col1" >-22.045175</td>
#       <td id="T_b1cb0_row4_col2" class="data row4 col2" >22.045175</td>
#       <td id="T_b1cb0_row4_col3" class="data row4 col3" >7.348392</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_b1cb0_row5_col0" class="data row5 col0" >I want to</td>
#       <td id="T_b1cb0_row5_col1" class="data row5 col1" >-22.353930</td>
#       <td id="T_b1cb0_row5_col2" class="data row5 col2" >22.353930</td>
#       <td id="T_b1cb0_row5_col3" class="data row5 col3" >7.451310</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_b1cb0_row6_col0" class="data row6 col0" >she went to</td>
#       <td id="T_b1cb0_row6_col1" class="data row6 col1" >-22.440698</td>
#       <td id="T_b1cb0_row6_col2" class="data row6 col2" >22.440698</td>
#       <td id="T_b1cb0_row6_col3" class="data row6 col3" >7.480233</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_b1cb0_row7_col0" class="data row7 col0" >she read the</td>
#       <td id="T_b1cb0_row7_col1" class="data row7 col1" >-23.512260</td>
#       <td id="T_b1cb0_row7_col2" class="data row7 col2" >23.512260</td>
#       <td id="T_b1cb0_row7_col3" class="data row7 col3" >7.837420</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row8" class="row_heading level0 row8" >0</th>
#       <td id="T_b1cb0_row8_col0" class="data row8 col0" >I love you</td>
#       <td id="T_b1cb0_row8_col1" class="data row8 col1" >-23.596817</td>
#       <td id="T_b1cb0_row8_col2" class="data row8 col2" >23.596817</td>
#       <td id="T_b1cb0_row8_col3" class="data row8 col3" >7.865606</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_b1cb0_row9_col0" class="data row9 col0" >I love cars</td>
#       <td id="T_b1cb0_row9_col1" class="data row9 col1" >-34.425747</td>
#       <td id="T_b1cb0_row9_col2" class="data row9 col2" >34.425747</td>
#       <td id="T_b1cb0_row9_col3" class="data row9 col3" >11.475249</td>
#     </tr>
#     <tr>
#       <th id="T_b1cb0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b1cb0_row10_col0" class="data row10 col0" >robots fly ufos</td>
#       <td id="T_b1cb0_row10_col1" class="data row10 col1" >-51.931590</td>
#       <td id="T_b1cb0_row10_col2" class="data row10 col2" >51.931590</td>
#       <td id="T_b1cb0_row10_col3" class="data row10 col3" >17.310530</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Perplexity
#
# Perplexity is a measure of the performance of the model.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Instead of using mean log probability as in the example above, we can just use mean of $i$.

# %%
TEST_SENT['pp'] = np.exp2(TEST_SENT.i_mean)

# %%
TEST_SENT.sort_values('pp').style.background_gradient()
# Out:
# <style type="text/css">
# #T_76ee6_row0_col1, #T_76ee6_row10_col2, #T_76ee6_row10_col3, #T_76ee6_row10_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_76ee6_row0_col2, #T_76ee6_row0_col3, #T_76ee6_row0_col4, #T_76ee6_row1_col4, #T_76ee6_row2_col4, #T_76ee6_row3_col4, #T_76ee6_row4_col4, #T_76ee6_row5_col4, #T_76ee6_row6_col4, #T_76ee6_row7_col4, #T_76ee6_row8_col4, #T_76ee6_row10_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_76ee6_row1_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
# }
# #T_76ee6_row1_col2, #T_76ee6_row1_col3, #T_76ee6_row9_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_76ee6_row2_col1 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_76ee6_row2_col2, #T_76ee6_row2_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_76ee6_row3_col1 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_76ee6_row3_col2, #T_76ee6_row3_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_76ee6_row4_col1 {
#   background-color: #034f7d;
#   color: #f1f1f1;
# }
# #T_76ee6_row4_col2, #T_76ee6_row4_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_76ee6_row5_col1, #T_76ee6_row6_col1 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_76ee6_row5_col2, #T_76ee6_row5_col3, #T_76ee6_row6_col2, #T_76ee6_row6_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_76ee6_row7_col1, #T_76ee6_row8_col1 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_76ee6_row7_col2, #T_76ee6_row7_col3, #T_76ee6_row8_col2, #T_76ee6_row8_col3 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_76ee6_row9_col1 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_76ee6_row9_col2, #T_76ee6_row9_col3 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_76ee6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76ee6_level0_col0" class="col_heading level0 col0" >sent_str</th>
#       <th id="T_76ee6_level0_col1" class="col_heading level0 col1" >logp_sum</th>
#       <th id="T_76ee6_level0_col2" class="col_heading level0 col2" >i_sum</th>
#       <th id="T_76ee6_level0_col3" class="col_heading level0 col3" >i_mean</th>
#       <th id="T_76ee6_level0_col4" class="col_heading level0 col4" >pp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76ee6_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_76ee6_row0_col0" class="data row0 col0" >said to her</td>
#       <td id="T_76ee6_row0_col1" class="data row0 col1" >-19.148070</td>
#       <td id="T_76ee6_row0_col2" class="data row0 col2" >19.148070</td>
#       <td id="T_76ee6_row0_col3" class="data row0 col3" >6.382690</td>
#       <td id="T_76ee6_row0_col4" class="data row0 col4" >83.441310</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_76ee6_row1_col0" class="data row1 col0" >she said to</td>
#       <td id="T_76ee6_row1_col1" class="data row1 col1" >-19.589660</td>
#       <td id="T_76ee6_row1_col2" class="data row1 col2" >19.589660</td>
#       <td id="T_76ee6_row1_col3" class="data row1 col3" >6.529887</td>
#       <td id="T_76ee6_row1_col4" class="data row1 col4" >92.404214</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_76ee6_row2_col0" class="data row2 col0" >he said to</td>
#       <td id="T_76ee6_row2_col1" class="data row2 col1" >-19.999999</td>
#       <td id="T_76ee6_row2_col2" class="data row2 col2" >19.999999</td>
#       <td id="T_76ee6_row2_col3" class="data row2 col3" >6.666666</td>
#       <td id="T_76ee6_row2_col4" class="data row2 col4" >101.593649</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_76ee6_row3_col0" class="data row3 col0" >said to him</td>
#       <td id="T_76ee6_row3_col1" class="data row3 col1" >-20.904546</td>
#       <td id="T_76ee6_row3_col2" class="data row3 col2" >20.904546</td>
#       <td id="T_76ee6_row3_col3" class="data row3 col3" >6.968182</td>
#       <td id="T_76ee6_row3_col4" class="data row3 col4" >125.207928</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row4" class="row_heading level0 row4" >3</th>
#       <td id="T_76ee6_row4_col0" class="data row4 col0" >Anne said to</td>
#       <td id="T_76ee6_row4_col1" class="data row4 col1" >-22.045175</td>
#       <td id="T_76ee6_row4_col2" class="data row4 col2" >22.045175</td>
#       <td id="T_76ee6_row4_col3" class="data row4 col3" >7.348392</td>
#       <td id="T_76ee6_row4_col4" class="data row4 col4" >162.962001</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row5" class="row_heading level0 row5" >2</th>
#       <td id="T_76ee6_row5_col0" class="data row5 col0" >I want to</td>
#       <td id="T_76ee6_row5_col1" class="data row5 col1" >-22.353930</td>
#       <td id="T_76ee6_row5_col2" class="data row5 col2" >22.353930</td>
#       <td id="T_76ee6_row5_col3" class="data row5 col3" >7.451310</td>
#       <td id="T_76ee6_row5_col4" class="data row5 col4" >175.011992</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row6" class="row_heading level0 row6" >9</th>
#       <td id="T_76ee6_row6_col0" class="data row6 col0" >she went to</td>
#       <td id="T_76ee6_row6_col1" class="data row6 col1" >-22.440698</td>
#       <td id="T_76ee6_row6_col2" class="data row6 col2" >22.440698</td>
#       <td id="T_76ee6_row6_col3" class="data row6 col3" >7.480233</td>
#       <td id="T_76ee6_row6_col4" class="data row6 col4" >178.555966</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_76ee6_row7_col0" class="data row7 col0" >she read the</td>
#       <td id="T_76ee6_row7_col1" class="data row7 col1" >-23.512260</td>
#       <td id="T_76ee6_row7_col2" class="data row7 col2" >23.512260</td>
#       <td id="T_76ee6_row7_col3" class="data row7 col3" >7.837420</td>
#       <td id="T_76ee6_row7_col4" class="data row7 col4" >228.717029</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row8" class="row_heading level0 row8" >0</th>
#       <td id="T_76ee6_row8_col0" class="data row8 col0" >I love you</td>
#       <td id="T_76ee6_row8_col1" class="data row8 col1" >-23.596817</td>
#       <td id="T_76ee6_row8_col2" class="data row8 col2" >23.596817</td>
#       <td id="T_76ee6_row8_col3" class="data row8 col3" >7.865606</td>
#       <td id="T_76ee6_row8_col4" class="data row8 col4" >233.229387</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row9" class="row_heading level0 row9" >1</th>
#       <td id="T_76ee6_row9_col0" class="data row9 col0" >I love cars</td>
#       <td id="T_76ee6_row9_col1" class="data row9 col1" >-34.425747</td>
#       <td id="T_76ee6_row9_col2" class="data row9 col2" >34.425747</td>
#       <td id="T_76ee6_row9_col3" class="data row9 col3" >11.475249</td>
#       <td id="T_76ee6_row9_col4" class="data row9 col4" >2847.043947</td>
#     </tr>
#     <tr>
#       <th id="T_76ee6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76ee6_row10_col0" class="data row10 col0" >robots fly ufos</td>
#       <td id="T_76ee6_row10_col1" class="data row10 col1" >-51.931590</td>
#       <td id="T_76ee6_row10_col2" class="data row10 col2" >51.931590</td>
#       <td id="T_76ee6_row10_col3" class="data row10 col3" >17.310530</td>
#       <td id="T_76ee6_row10_col4" class="data row10 col4" >162550.661422</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If we have lots of high perplexity sentences relative to the performance of another model, then our model is not so good ...

# %%
TEST_SENT.pp.plot(style='o-');

# %%
TEST_SENT.i_mean.plot(style='o-');

# %%
TEST_SENT.pp.mean()
# Out:
# 15161.711713130468

# %% [markdown]
# # NGram Language Models
#
# ```yaml
# Course:  DS 5001
# Module:  03 Lab
# Topic:   NGram Language Models
# Author:  R.C. Alvarado
# Date:    12 December 2023
# ```

# %% [markdown]
# ## Purpose
#
# We now create a series of simple n-gram langage models from our small corpus and evaluate them.

# %% [markdown]
# ## Pattern
#
# 1. Import corpus &rarr; `TOKEN`, `VOCAB`.
# 2. Extract ngrams from training tokens &rarr; `NGRAM`.
# 3. Count ngrams and convert to models &rarr; `MODEL`.
# 4. Convert test sentences into tokens &rarr; `TEST_SENT`, `TEST_TOKEN`.
# 5. Extract ngrams from test tokens &rarr; `TEST_NGRAM`.
# 6. Test model by joining model information `M.i` to `TEST_NGRAM` and then summing i per sentence &rarr; `TEST_NGRAM'`, `TEST_SENT'`.
# 7. Compute model perplexity by averaging sentence information sums and exponentiating.

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Configure

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_dir = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']

# %%
OHCO = ['book_id', 'chap_num', 'para_num', 'sent_num', 'token_num']
path_prefix = f"{output_dir}/austen-combo"
n = 3

# %% [markdown]
# ## Get Data
#
# We grab our corpus of two novels.

# %%
VOCAB = pd.read_csv(f"{path_prefix}-VOCAB.csv").set_index('term_str')
TOKEN = pd.read_csv(f"{path_prefix}-TOKENS.csv").set_index(OHCO)

# %% [markdown]
# ## Generate Models
#
# This function generates models up to the length specified.
#
# Our approach is to bind the sequence of term strings in TOKEN to itself with an offset of 1 for each value of $n$.

# %%
TOKEN
# Out:
#                                                 token_str     term_str
# book_id chap_num para_num sent_num token_num
# 1       1        0        0        0                  Sir          sir
#                                    1               Walter       walter
#                                    2               Elliot       elliot
#                                    3                   of           of
#                                    4             Kellynch     kellynch
# ...                                                   ...          ...
# 2       50       22       0        8                  and          and
#                                    9          Sensibility  sensibility
#                                    10                  by           by
#                                    11                Jane         jane
#                                    12              Austen       austen
#
# [204802 rows x 2 columns]

# %% [markdown]
# ### `get_ngrams()`

# %%
def get_ngrams(TOKEN, VOCAB, n=2, sent_key='sent_num'):
    

    OHCO = TOKEN.index.names
    grouper = list(OHCO)[:OHCO.index(sent_key)+1]

    PADDED = TOKEN.groupby(grouper)\
        .apply(lambda x: '<s> ' + ' '.join(x.term_str) + ' </s>')\
        .apply(lambda x: pd.Series(x.split()))\
        .stack().to_frame('term_str')
    PADDED.index.names = grouper + ['token_num']
    
    # Handle OOV terms -- MAY NOT BE NEEDED
    PADDED.loc[~PADDED.term_str.isin(list(VOCAB.index) + ['<s>','</s>']), 'term_str'] = '<unk>'
    
    for i in range(1, n):
        PADDED = PADDED.join(PADDED.term_str.shift(-i), rsuffix=i)

    PADDED.columns = [f'w{j}' for j in range(n)]

    PADDED = PADDED.fillna('<s>')
    # PADDED = PADDED[~((PADDED.w0 == '</s>') & (PADDED[f'w{n-1}'] == '<s>'))]

    return PADDED

# %%
NG = get_ngrams(TOKEN, VOCAB, n=3)

# %%
NG.iloc[:,:3]
# Out:
#                                                        w0        w1        w2
# book_id chap_num para_num sent_num token_num
# 1       1        0        0        0                  <s>       sir    walter
#                                    1                  sir    walter    elliot
#                                    2               walter    elliot        of
#                                    3               elliot        of  kellynch
#                                    4                   of  kellynch      hall
# ...                                                   ...       ...       ...
# 2       50       22       0        10         sensibility        by      jane
#                                    11                  by      jane    austen
#                                    12                jane    austen      </s>
#                                    13              austen      </s>       <s>
#                                    14                </s>       <s>       <s>
#
# [230426 rows x 3 columns]

# %% [markdown]
# ### `get_ngram_counts()`

# %%
def get_ngram_counts(NGRAM):
    "Compress the sequences into counts"
    
    n = len(NGRAM.columns)
    C = [None for i in range(n)]
    
    for i in range(n):

        # Count distinct ngrams
        C[i] = NGRAM.iloc[:, :i+1].value_counts().to_frame('n').sort_index()
    
        # Get joint probabilities (MLE)
        C[i]['p'] = C[i].n / C[i].n.sum()
        C[i]['i'] = np.log2(1/C[i].p)

        # Get conditional probabilities (MLE)
        if i > 0:
            C[i]['cp'] = C[i].n / C[i-1].n
            C[i]['ci'] = np.log2(1/C[i].cp)
            
    return C

# %% [markdown]
# Generate unigram, bigram, and trigram models.

# %%
M = get_ngram_counts(NG)

# %%
M[0].sort_values('n')
# Out:
#                  n         p          i
# w0
# journeys         1  0.000004  17.813944
# edify            1  0.000004  17.813944
# ponder           1  0.000004  17.813944
# politics         1  0.000004  17.813944
# politicians      1  0.000004  17.813944
# ...            ...       ...        ...
# and           6290  0.027297   5.195100
# to            6923  0.030044   5.056762
# the           7435  0.032266   4.953827
# <s>          12812  0.055601   4.168736
# </s>         12812  0.055601   4.168736
#
# [8240 rows x 3 columns]

# %%
M[1].sort_values('n')
# Out:
#                     n         p          i        cp        ci
# w0    w1
# 1     1760          1  0.000004  17.813944  0.333333  1.584963
# often keeps         1  0.000004  17.813944  0.012195  6.357552
#       led           1  0.000004  17.813944  0.012195  6.357552
#       makes         1  0.000004  17.813944  0.012195  6.357552
#       observed      1  0.000004  17.813944  0.012195  6.357552
# ...               ...       ...        ...       ...       ...
# of    the         857  0.003719   8.070793  0.139440  2.842281
# <s>   but         929  0.004032   7.954409  0.072510  3.785673
#       i          1000  0.004340   7.848160  0.078052  3.679424
#       and        1417  0.006149   7.345320  0.110599  3.176584
# </s>  <s>       12812  0.055601   4.168736  1.000000  0.000000
#
# [78626 rows x 5 columns]

# %%
M[1].sample(5)
# Out:
#                       n         p          i        cp         ci
# w0        w1
# apartment as          1  0.000004  17.813944  0.166667   2.584963
# of        no         16  0.000069  13.813944  0.002603   8.585432
# false     or          1  0.000004  17.813944  0.250000   2.000000
# which     brings      1  0.000004  17.813944  0.000991   9.978710
# the       observant   1  0.000004  17.813944  0.000134  12.860117

# %%
M[2].sample(5)
# Out:
#                             n         p          i        cp        ci
# w0         w1        w2
# said       anne      you    1  0.000004  17.813944  0.055556  4.169925
# died       it        would  1  0.000004  17.813944  1.000000  0.000000
# <s>        dashwood  now    2  0.000009  16.813944  0.014706  6.087463
# feeling    on        his    1  0.000004  17.813944  1.000000  0.000000
# unaffected sincerity </s>   1  0.000004  17.813944  1.000000  0.000000

# %%
M[2].loc[('captain','wentworth')].sort_values('n', ascending=False).head()
# Out:
#        n         p          i        cp        ci
# w2
# s     26  0.000113  13.113504  0.132653  2.914270
# </s>  24  0.000104  13.228981  0.122449  3.029747
# was   15  0.000065  13.907053  0.076531  3.707819
# in     8  0.000035  14.813944  0.040816  4.614710
# had    7  0.000030  15.006589  0.035714  4.807355

# %%
M[2].loc[('anne','elliot')].sort_values('n', ascending=False).head()
# Out:
#        n         p          i        cp        ci
# w2
# </s>   5  0.000022  15.492016  0.217391  2.201634
# and    3  0.000013  16.228981  0.130435  2.938599
# as     2  0.000009  16.813944  0.086957  3.523562
# with   2  0.000009  16.813944  0.086957  3.523562
# again  1  0.000004  17.813944  0.043478  4.523562

# %% [markdown]
# ## Predict Sentences

# %% [markdown]
# ### Get a list of test sentences

# %%
test_sentences = """
I love you
I love cars
I want to
Anne said to
said to her
he said to
she said to
said to him
she read the
she went to
robots fly ufos
""".split('\n')[1:-1]

# %% [markdown]
# ### Convert list to TEST_SENT

# %%
TEST_SENT = pd.DataFrame({'sent_str':test_sentences})
TEST_SENT.index.name = 'sent_num'

# %%
TEST_SENT
# Out:
#                  sent_str
# sent_num
# 0              I love you
# 1             I love cars
# 2               I want to
# 3            Anne said to
# 4             said to her
# 5              he said to
# 6             she said to
# 7             said to him
# 8            she read the
# 9             she went to
# 10        robots fly ufos

# %% [markdown]
# ### Convert TEST_SENT to TEST_TOKEN

# %%
TEST_TOKEN = TEST_SENT.sent_str.str.split(expand=True).stack().to_frame('token_str')
TEST_TOKEN.index.names = ['sent_num', 'token_num']
TEST_TOKEN['term_str'] = TEST_TOKEN.token_str.str.replace(r'[\W_]+', '').str.lower()

# %%
TEST_TOKEN
# Out:
#                    token_str term_str
# sent_num token_num
# 0        0                 I        i
#          1              love     love
#          2               you      you
# 1        0                 I        i
#          1              love     love
#          2              cars     cars
# 2        0                 I        i
#          1              want     want
#          2                to       to
# 3        0              Anne     anne
#          1              said     said
#          2                to       to
# 4        0              said     said
#          1                to       to
#          2               her      her
# 5        0                he       he
#          1              said     said
#          2                to       to
# 6        0               she      she
#          1              said     said
#          2                to       to
# 7        0              said     said
#          1                to       to
#          2               him      him
# 8        0               she      she
#          1              read     read
#          2               the      the
# 9        0               she      she
#          1              went     went
#          2                to       to
# 10       0            robots   robots
#          1               fly      fly
#          2              ufos     ufos

# %% [markdown]
# ### Extract TEST_NGRAMS from TEST_TOKEN

# %%
TEST_NGRAMS = get_ngrams(TEST_TOKEN, VOCAB, n=3, sent_key='sent_num')

# %%
TEST_NGRAMS.head(10)
# Out:
#                        w0     w1     w2
# sent_num token_num
# 0        0            <s>      i   love
#          1              i   love    you
#          2           love    you   </s>
#          3            you   </s>    <s>
#          4           </s>    <s>      i
# 1        0            <s>      i   love
#          1              i   love  <unk>
#          2           love  <unk>   </s>
#          3          <unk>   </s>    <s>
#          4           </s>    <s>      i

# %% [markdown]
# ### Test the model
#
# We test by joining the test ngrams with the model and then saving aggregate statistics to the sentence dataframe.
#
# Note that testing is a special case of the split-apply-combine pattern.

# %% [markdown]
# ### `test_model()`

# %%
def test_model(model, test_ngrams):

    # Get the model level and info feature
    n = len(model.index.names) - 1 
    f = 'c' * bool(n) + 'i'        

    # Do the test by join and then split-apply-combine
    # fillna() is used to hanlde OOV terms
    T = test_ngrams.join(model[f], on=model.index.names, how='left').fillna(model[f].max()).copy()
        
    R = T.groupby('sent_num')[f].agg(['sum','mean'])
    R['pp'] = np.exp2(R['mean'])
    
    return R

# %% [markdown]
# ### Run tests and save as RESULT

# %%
RESULT = pd.concat(
    [test_model(M[i], TEST_NGRAMS.iloc[:,:i+1]) for i in range(len(M))],
    keys=[f"M{n}" for n in range(len(M))],
    axis=1
)

# %%
RESULT.style.background_gradient()
# Out:
# <style type="text/css">
# #T_a8b2b_row0_col0, #T_a8b2b_row0_col1, #T_a8b2b_row0_col2, #T_a8b2b_row0_col3, #T_a8b2b_row0_col4, #T_a8b2b_row0_col5, #T_a8b2b_row0_col8, #T_a8b2b_row1_col0, #T_a8b2b_row1_col1, #T_a8b2b_row1_col2, #T_a8b2b_row2_col0, #T_a8b2b_row2_col1, #T_a8b2b_row2_col2, #T_a8b2b_row3_col0, #T_a8b2b_row3_col1, #T_a8b2b_row3_col2, #T_a8b2b_row4_col0, #T_a8b2b_row4_col1, #T_a8b2b_row4_col2, #T_a8b2b_row4_col3, #T_a8b2b_row4_col4, #T_a8b2b_row4_col5, #T_a8b2b_row4_col8, #T_a8b2b_row5_col0, #T_a8b2b_row5_col1, #T_a8b2b_row5_col2, #T_a8b2b_row5_col8, #T_a8b2b_row6_col0, #T_a8b2b_row6_col1, #T_a8b2b_row6_col2, #T_a8b2b_row7_col0, #T_a8b2b_row7_col1, #T_a8b2b_row7_col2, #T_a8b2b_row7_col3, #T_a8b2b_row7_col4, #T_a8b2b_row7_col5, #T_a8b2b_row7_col6, #T_a8b2b_row7_col7, #T_a8b2b_row7_col8, #T_a8b2b_row8_col0, #T_a8b2b_row8_col1, #T_a8b2b_row8_col2, #T_a8b2b_row9_col0, #T_a8b2b_row9_col1, #T_a8b2b_row9_col2, #T_a8b2b_row9_col5, #T_a8b2b_row10_col0, #T_a8b2b_row10_col1, #T_a8b2b_row10_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a8b2b_row0_col6, #T_a8b2b_row0_col7, #T_a8b2b_row6_col3, #T_a8b2b_row6_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a8b2b_row1_col3, #T_a8b2b_row1_col4 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_a8b2b_row1_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_a8b2b_row1_col6, #T_a8b2b_row1_col7 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_a8b2b_row1_col8 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_a8b2b_row2_col3, #T_a8b2b_row2_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_a8b2b_row2_col5, #T_a8b2b_row5_col5, #T_a8b2b_row6_col5, #T_a8b2b_row6_col8 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_a8b2b_row2_col6, #T_a8b2b_row2_col7, #T_a8b2b_row3_col6, #T_a8b2b_row3_col7 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_a8b2b_row2_col8, #T_a8b2b_row3_col8 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_a8b2b_row3_col3, #T_a8b2b_row3_col4, #T_a8b2b_row6_col6, #T_a8b2b_row6_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_a8b2b_row3_col5, #T_a8b2b_row9_col3, #T_a8b2b_row9_col4, #T_a8b2b_row9_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a8b2b_row4_col6, #T_a8b2b_row4_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a8b2b_row5_col3, #T_a8b2b_row5_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_a8b2b_row5_col6, #T_a8b2b_row5_col7 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_a8b2b_row8_col3, #T_a8b2b_row8_col4 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_a8b2b_row8_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_a8b2b_row8_col6, #T_a8b2b_row8_col7 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_a8b2b_row8_col8 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_a8b2b_row9_col6, #T_a8b2b_row9_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_a8b2b_row10_col3, #T_a8b2b_row10_col4, #T_a8b2b_row10_col5, #T_a8b2b_row10_col6, #T_a8b2b_row10_col7, #T_a8b2b_row10_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a8b2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8b2b_level0_col0" class="col_heading level0 col0" colspan="3">M0</th>
#       <th id="T_a8b2b_level0_col3" class="col_heading level0 col3" colspan="3">M1</th>
#       <th id="T_a8b2b_level0_col6" class="col_heading level0 col6" colspan="3">M2</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a8b2b_level1_col0" class="col_heading level1 col0" >sum</th>
#       <th id="T_a8b2b_level1_col1" class="col_heading level1 col1" >mean</th>
#       <th id="T_a8b2b_level1_col2" class="col_heading level1 col2" >pp</th>
#       <th id="T_a8b2b_level1_col3" class="col_heading level1 col3" >sum</th>
#       <th id="T_a8b2b_level1_col4" class="col_heading level1 col4" >mean</th>
#       <th id="T_a8b2b_level1_col5" class="col_heading level1 col5" >pp</th>
#       <th id="T_a8b2b_level1_col6" class="col_heading level1 col6" >sum</th>
#       <th id="T_a8b2b_level1_col7" class="col_heading level1 col7" >mean</th>
#       <th id="T_a8b2b_level1_col8" class="col_heading level1 col8" >pp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8b2b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8b2b_row0_col0" class="data row0 col0" >89.069720</td>
#       <td id="T_a8b2b_row0_col1" class="data row0 col1" >17.813944</td>
#       <td id="T_a8b2b_row0_col2" class="data row0 col2" >230426.000000</td>
#       <td id="T_a8b2b_row0_col3" class="data row0 col3" >21.181306</td>
#       <td id="T_a8b2b_row0_col4" class="data row0 col4" >4.236261</td>
#       <td id="T_a8b2b_row0_col5" class="data row0 col5" >18.846977</td>
#       <td id="T_a8b2b_row0_col6" class="data row0 col6" >26.875379</td>
#       <td id="T_a8b2b_row0_col7" class="data row0 col7" >5.375076</td>
#       <td id="T_a8b2b_row0_col8" class="data row0 col8" >41.501044</td>
#     </tr>
#     <tr>
#       <th id="T_a8b2b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8b2b_row1_col0" class="data row1 col0" >89.069720</td>
#       <td id="T_a8b2b_row1_col1" class="data row1 col1" >17.813944</td>
#       <td id="T_a8b2b_row1_col2" class="data row1 col2" >230426.000000</td>
#       <td id="T_a8b2b_row1_col3" class="data row1 col3" >39.580865</td>
#       <td id="T_a8b2b_row1_col4" class="data row1 col4" >7.916173</td>
#       <td id="T_a8b2b_row1_col5" class="data row1 col5" >241.549148</td>
#       <td id="T_a8b2b_row1_col6" class="data row1 col6" >52.580832</td>
#       <td id="T_a8b2b_row1_col7" class="data row1 col7" >10.516166</td>
#       <td id="T_a8b2b_row1_col8" class="data row1 col8" >1464.473595</td>
#     </tr>
#     <tr>
#       <th id="T_a8b2b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8b2b_row2_col0" class="data row2 col0" >89.069720</td>
#       <td id="T_a8b2b_row2_col1" class="data row2 col1" >17.813944</td>
#       <td id="T_a8b2b_row2_col2" class="data row2 col2" >230426.000000</td>
#       <td id="T_a8b2b_row2_col3" class="data row2 col3" >24.502196</td>
#       <td id="T_a8b2b_row2_col4" class="data row2 col4" >4.900439</td>
#       <td id="T_a8b2b_row2_col5" class="data row2 col5" >29.866147</td>
#       <td id="T_a8b2b_row2_col6" class="data row2 col6" >42.166699</td>
#       <td id="T_a8b2b_row2_col7" class="data row2 col7" >8.433340</td>
#       <td id="T_a8b2b_row2_col8" class="data row2 col8" >345.691132</td>
#     </tr>
#     <tr>
#       <th id="T_a8b2b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8b2b_row3_col0" class="data row3 col0" >89.069720</td>
#       <td id="T_a8b2b_row3_col1" class="data row3 col1" >17.813944</td>
#       <td id="T_a8b2b_row3_col2" class="data row3 col2" >230426.000000</td>
#       <td id="T_a8b2b_row3_col3" class="data row3 col3" >27.709450</td>
#       <td id="T_a8b2b_row3_col4" class="data row3 col4" >5.541890</td>
#       <td id="T_a8b2b_row3_col5" class="data row3 col5" >46.588113</td>
#       <td id="T_a8b2b_row3_col6" class="data row3 col6" >42.131175</td>
#       <td id="T_a8b2b_row3_col7" class="data row3 col7" >8.426235</td>
#       <td id="T_a8b2b_row3_col8" class="data row3 col8" >343.992908</td>
#     </tr>
#     <tr>
#       <th id="T_a8b2b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a8b2b_row4_col0" class="data row4 col0" >89.069720</td>
#       <td id="T_a8b2b_row4_col1" class="data row4 col1" >17.813944</td>
#       <td id="T_a8b2b_row4_col2" class="data row4 col2" >230426.000000</td>
#       <td id="T_a8b2b_row4_col3" class="data row4 col3" >21.15

# %% [markdown]
# Show results for a given model.

# %%
pd.concat([TEST_SENT, RESULT['M0']], axis=1).sort_values('pp').style.background_gradient()
# Out:
# <style type="text/css">
# #T_9c3fb_row0_col1, #T_9c3fb_row0_col2, #T_9c3fb_row0_col3, #T_9c3fb_row1_col1, #T_9c3fb_row1_col2, #T_9c3fb_row1_col3, #T_9c3fb_row2_col1, #T_9c3fb_row2_col2, #T_9c3fb_row2_col3, #T_9c3fb_row3_col1, #T_9c3fb_row3_col2, #T_9c3fb_row3_col3, #T_9c3fb_row4_col1, #T_9c3fb_row4_col2, #T_9c3fb_row4_col3, #T_9c3fb_row5_col1, #T_9c3fb_row5_col2, #T_9c3fb_row5_col3, #T_9c3fb_row6_col1, #T_9c3fb_row6_col2, #T_9c3fb_row6_col3, #T_9c3fb_row7_col1, #T_9c3fb_row7_col2, #T_9c3fb_row7_col3, #T_9c3fb_row8_col1, #T_9c3fb_row8_col2, #T_9c3fb_row8_col3, #T_9c3fb_row9_col1, #T_9c3fb_row9_col2, #T_9c3fb_row9_col3, #T_9c3fb_row10_col1, #T_9c3fb_row10_col2, #T_9c3fb_row10_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_9c3fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c3fb_level0_col0" class="col_heading level0 col0" >sent_str</th>
#       <th id="T_9c3fb_level0_col1" class="col_heading level0 col1" >sum</th>
#       <th id="T_9c3fb_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_9c3fb_level0_col3" class="col_heading level0 col3" >pp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c3fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c3fb_row0_col0" class="data row0 col0" >I love you</td>
#       <td id="T_9c3fb_row0_col1" class="data row0 col1" >89.069720</td>
#       <td id="T_9c3fb_row0_col2" class="data row0 col2" >17.813944</td>
#       <td id="T_9c3fb_row0_col3" class="data row0 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c3fb_row1_col0" class="data row1 col0" >I love cars</td>
#       <td id="T_9c3fb_row1_col1" class="data row1 col1" >89.069720</td>
#       <td id="T_9c3fb_row1_col2" class="data row1 col2" >17.813944</td>
#       <td id="T_9c3fb_row1_col3" class="data row1 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c3fb_row2_col0" class="data row2 col0" >I want to</td>
#       <td id="T_9c3fb_row2_col1" class="data row2 col1" >89.069720</td>
#       <td id="T_9c3fb_row2_col2" class="data row2 col2" >17.813944</td>
#       <td id="T_9c3fb_row2_col3" class="data row2 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c3fb_row3_col0" class="data row3 col0" >Anne said to</td>
#       <td id="T_9c3fb_row3_col1" class="data row3 col1" >89.069720</td>
#       <td id="T_9c3fb_row3_col2" class="data row3 col2" >17.813944</td>
#       <td id="T_9c3fb_row3_col3" class="data row3 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c3fb_row4_col0" class="data row4 col0" >said to her</td>
#       <td id="T_9c3fb_row4_col1" class="data row4 col1" >89.069720</td>
#       <td id="T_9c3fb_row4_col2" class="data row4 col2" >17.813944</td>
#       <td id="T_9c3fb_row4_col3" class="data row4 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c3fb_row5_col0" class="data row5 col0" >he said to</td>
#       <td id="T_9c3fb_row5_col1" class="data row5 col1" >89.069720</td>
#       <td id="T_9c3fb_row5_col2" class="data row5 col2" >17.813944</td>
#       <td id="T_9c3fb_row5_col3" class="data row5 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c3fb_row6_col0" class="data row6 col0" >she said to</td>
#       <td id="T_9c3fb_row6_col1" class="data row6 col1" >89.069720</td>
#       <td id="T_9c3fb_row6_col2" class="data row6 col2" >17.813944</td>
#       <td id="T_9c3fb_row6_col3" class="data row6 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c3fb_row7_col0" class="data row7 col0" >said to him</td>
#       <td id="T_9c3fb_row7_col1" class="data row7 col1" >89.069720</td>
#       <td id="T_9c3fb_row7_col2" class="data row7 col2" >17.813944</td>
#       <td id="T_9c3fb_row7_col3" class="data row7 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c3fb_row8_col0" class="data row8 col0" >she read the</td>
#       <td id="T_9c3fb_row8_col1" class="data row8 col1" >89.069720</td>
#       <td id="T_9c3fb_row8_col2" class="data row8 col2" >17.813944</td>
#       <td id="T_9c3fb_row8_col3" class="data row8 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9c3fb_row9_col0" class="data row9 col0" >she went to</td>
#       <td id="T_9c3fb_row9_col1" class="data row9 col1" >89.069720</td>
#       <td id="T_9c3fb_row9_col2" class="data row9 col2" >17.813944</td>
#       <td id="T_9c3fb_row9_col3" class="data row9 col3" >230426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c3fb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9c3fb_row10_col0" class="data row10 col0" >robots fly ufos</td>
#       <td id="T_9c3fb_row10_col1" class="data row10 col1" >89.069720</td>
#       <td id="T_9c3fb_row10_col2" class="data row10 col2" >17.813944</td>
#       <td id="T_9c3fb_row10_col3" class="data row10 col3" >230426.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pd.concat([TEST_SENT, RESULT['M2']], axis=1).sort_values('pp').style.background_gradient()
# Out:
# <style type="text/css">
# #T_2fdaa_row0_col1, #T_2fdaa_row0_col2, #T_2fdaa_row0_col3, #T_2fdaa_row1_col3, #T_2fdaa_row2_col3, #T_2fdaa_row3_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2fdaa_row1_col1, #T_2fdaa_row1_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_2fdaa_row2_col1, #T_2fdaa_row2_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_2fdaa_row3_col1, #T_2fdaa_row3_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_2fdaa_row4_col1, #T_2fdaa_row4_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_2fdaa_row4_col3 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_2fdaa_row5_col1, #T_2fdaa_row5_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_2fdaa_row5_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_2fdaa_row6_col1, #T_2fdaa_row6_col2, #T_2fdaa_row7_col1, #T_2fdaa_row7_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_2fdaa_row6_col3, #T_2fdaa_row7_col3 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_2fdaa_row8_col1, #T_2fdaa_row8_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_2fdaa_row8_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_2fdaa_row9_col1, #T_2fdaa_row9_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_2fdaa_row9_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_2fdaa_row10_col1, #T_2fdaa_row10_col2, #T_2fdaa_row10_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2fdaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fdaa_level0_col0" class="col_heading level0 col0" >sent_str</th>
#       <th id="T_2fdaa_level0_col1" class="col_heading level0 col1" >sum</th>
#       <th id="T_2fdaa_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_2fdaa_level0_col3" class="col_heading level0 col3" >pp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fdaa_level0_row0" class="row_heading level0 row0" >7</th>
#       <td id="T_2fdaa_row0_col0" class="data row0 col0" >said to him</td>
#       <td id="T_2fdaa_row0_col1" class="data row0 col1" >22.871142</td>
#       <td id="T_2fdaa_row0_col2" class="data row0 col2" >4.574228</td>
#       <td id="T_2fdaa_row0_col3" class="data row0 col3" >23.822094</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_2fdaa_row1_col0" class="data row1 col0" >said to her</td>
#       <td id="T_2fdaa_row1_col1" class="data row1 col1" >25.335105</td>
#       <td id="T_2fdaa_row1_col2" class="data row1 col2" >5.067021</td>
#       <td id="T_2fdaa_row1_col3" class="data row1 col3" >33.521644</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_2fdaa_row2_col0" class="data row2 col0" >I love you</td>
#       <td id="T_2fdaa_row2_col1" class="data row2 col1" >26.875379</td>
#       <td id="T_2fdaa_row2_col2" class="data row2 col2" >5.375076</td>
#       <td id="T_2fdaa_row2_col3" class="data row2 col3" >41.501044</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_2fdaa_row3_col0" class="data row3 col0" >he said to</td>
#       <td id="T_2fdaa_row3_col1" class="data row3 col1" >28.439985</td>
#       <td id="T_2fdaa_row3_col2" class="data row3 col2" >5.687997</td>
#       <td id="T_2fdaa_row3_col3" class="data row3 col3" >51.553444</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_2fdaa_row4_col0" class="data row4 col0" >she said to</td>
#       <td id="T_2fdaa_row4_col1" class="data row4 col1" >31.749848</td>
#       <td id="T_2fdaa_row4_col2" class="data row4 col2" >6.349970</td>
#       <td id="T_2fdaa_row4_col3" class="data row4 col3" >81.570159</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_2fdaa_row5_col0" class="data row5 col0" >she went to</td>
#       <td id="T_2fdaa_row5_col1" class="data row5 col1" >38.144617</td>
#       <td id="T_2fdaa_row5_col2" class="data row5 col2" >7.628923</td>
#       <td id="T_2fdaa_row5_col3" class="data row5 col3" >197.940544</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_2fdaa_row6_col0" class="data row6 col0" >Anne said to</td>
#       <td id="T_2fdaa_row6_col1" class="data row6 col1" >42.131175</td>
#       <td id="T_2fdaa_row6_col2" class="data row6 col2" >8.426235</td>
#       <td id="T_2fdaa_row6_col3" class="data row6 col3" >343.992908</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_2fdaa_row7_col0" class="data row7 col0" >I want to</td>
#       <td id="T_2fdaa_row7_col1" class="data row7 col1" >42.166699</td>
#       <td id="T_2fdaa_row7_col2" class="data row7 col2" >8.433340</td>
#       <td id="T_2fdaa_row7_col3" class="data row7 col3" >345.691132</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row8" class="row_heading level0 row8" >1</th>
#       <td id="T_2fdaa_row8_col0" class="data row8 col0" >I love cars</td>
#       <td id="T_2fdaa_row8_col1" class="data row8 col1" >52.580832</td>
#       <td id="T_2fdaa_row8_col2" class="data row8 col2" >10.516166</td>
#       <td id="T_2fdaa_row8_col3" class="data row8 col3" >1464.473595</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row9" class="row_heading level0 row9" >8</th>
#       <td id="T_2fdaa_row9_col0" class="data row9 col0" >she read the</td>
#       <td id="T_2fdaa_row9_col1" class="data row9 col1" >53.580832</td>
#       <td id="T_2fdaa_row9_col2" class="data row9 col2" >10.716166</td>
#       <td id="T_2fdaa_row9_col3" class="data row9 col3" >1682.238410</td>
#     </tr>
#     <tr>
#       <th id="T_2fdaa_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2fdaa_row10_col0" class="data row10 col0" >robots fly ufos</td>
#       <td id="T_2fdaa_row10_col1" class="data row10 col1" >68.226040</td>
#       <td id="T_2fdaa_row10_col2" class="data row10 col2" >13.645208</td>
#       <td id="T_2fdaa_row10_col3" class="data row10 col3" >12812.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Compare a feature across models.
#
# We use `.swaplevel()` to change the order of the column levels to make selection easy.

# %%
RESULT.swaplevel(axis=1).style.background_gradient()
# Out:
# <style type="text/css">
# #T_72212_row0_col0, #T_72212_row0_col1, #T_72212_row0_col2, #T_72212_row0_col3, #T_72212_row0_col4, #T_72212_row0_col5, #T_72212_row0_col8, #T_72212_row1_col0, #T_72212_row1_col1, #T_72212_row1_col2, #T_72212_row2_col0, #T_72212_row2_col1, #T_72212_row2_col2, #T_72212_row3_col0, #T_72212_row3_col1, #T_72212_row3_col2, #T_72212_row4_col0, #T_72212_row4_col1, #T_72212_row4_col2, #T_72212_row4_col3, #T_72212_row4_col4, #T_72212_row4_col5, #T_72212_row4_col8, #T_72212_row5_col0, #T_72212_row5_col1, #T_72212_row5_col2, #T_72212_row5_col8, #T_72212_row6_col0, #T_72212_row6_col1, #T_72212_row6_col2, #T_72212_row7_col0, #T_72212_row7_col1, #T_72212_row7_col2, #T_72212_row7_col3, #T_72212_row7_col4, #T_72212_row7_col5, #T_72212_row7_col6, #T_72212_row7_col7, #T_72212_row7_col8, #T_72212_row8_col0, #T_72212_row8_col1, #T_72212_row8_col2, #T_72212_row9_col0, #T_72212_row9_col1, #T_72212_row9_col2, #T_72212_row9_col5, #T_72212_row10_col0, #T_72212_row10_col1, #T_72212_row10_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_72212_row0_col6, #T_72212_row0_col7, #T_72212_row6_col3, #T_72212_row6_col4 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_72212_row1_col3, #T_72212_row1_col4 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_72212_row1_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_72212_row1_col6, #T_72212_row1_col7 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_72212_row1_col8 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_72212_row2_col3, #T_72212_row2_col4 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_72212_row2_col5, #T_72212_row5_col5, #T_72212_row6_col5, #T_72212_row6_col8 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_72212_row2_col6, #T_72212_row2_col7, #T_72212_row3_col6, #T_72212_row3_col7 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_72212_row2_col8, #T_72212_row3_col8 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_72212_row3_col3, #T_72212_row3_col4, #T_72212_row6_col6, #T_72212_row6_col7 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_72212_row3_col5, #T_72212_row9_col3, #T_72212_row9_col4, #T_72212_row9_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_72212_row4_col6, #T_72212_row4_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_72212_row5_col3, #T_72212_row5_col4 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_72212_row5_col6, #T_72212_row5_col7 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_72212_row8_col3, #T_72212_row8_col4 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_72212_row8_col5 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_72212_row8_col6, #T_72212_row8_col7 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_72212_row8_col8 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_72212_row9_col6, #T_72212_row9_col7 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_72212_row10_col3, #T_72212_row10_col4, #T_72212_row10_col5, #T_72212_row10_col6, #T_72212_row10_col7, #T_72212_row10_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72212">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72212_level0_col0" class="col_heading level0 col0" >sum</th>
#       <th id="T_72212_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_72212_level0_col2" class="col_heading level0 col2" >pp</th>
#       <th id="T_72212_level0_col3" class="col_heading level0 col3" >sum</th>
#       <th id="T_72212_level0_col4" class="col_heading level0 col4" >mean</th>
#       <th id="T_72212_level0_col5" class="col_heading level0 col5" >pp</th>
#       <th id="T_72212_level0_col6" class="col_heading level0 col6" >sum</th>
#       <th id="T_72212_level0_col7" class="col_heading level0 col7" >mean</th>
#       <th id="T_72212_level0_col8" class="col_heading level0 col8" >pp</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_72212_level1_col0" class="col_heading level1 col0" >M0</th>
#       <th id="T_72212_level1_col1" class="col_heading level1 col1" >M0</th>
#       <th id="T_72212_level1_col2" class="col_heading level1 col2" >M0</th>
#       <th id="T_72212_level1_col3" class="col_heading level1 col3" >M1</th>
#       <th id="T_72212_level1_col4" class="col_heading level1 col4" >M1</th>
#       <th id="T_72212_level1_col5" class="col_heading level1 col5" >M1</th>
#       <th id="T_72212_level1_col6" class="col_heading level1 col6" >M2</th>
#       <th id="T_72212_level1_col7" class="col_heading level1 col7" >M2</th>
#       <th id="T_72212_level1_col8" class="col_heading level1 col8" >M2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72212_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72212_row0_col0" class="data row0 col0" >89.069720</td>
#       <td id="T_72212_row0_col1" class="data row0 col1" >17.813944</td>
#       <td id="T_72212_row0_col2" class="data row0 col2" >230426.000000</td>
#       <td id="T_72212_row0_col3" class="data row0 col3" >21.181306</td>
#       <td id="T_72212_row0_col4" class="data row0 col4" >4.236261</td>
#       <td id="T_72212_row0_col5" class="data row0 col5" >18.846977</td>
#       <td id="T_72212_row0_col6" class="data row0 col6" >26.875379</td>
#       <td id="T_72212_row0_col7" class="data row0 col7" >5.375076</td>
#       <td id="T_72212_row0_col8" class="data row0 col8" >41.501044</td>
#     </tr>
#     <tr>
#       <th id="T_72212_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72212_row1_col0" class="data row1 col0" >89.069720</td>
#       <td id="T_72212_row1_col1" class="data row1 col1" >17.813944</td>
#       <td id="T_72212_row1_col2" class="data row1 col2" >230426.000000</td>
#       <td id="T_72212_row1_col3" class="data row1 col3" >39.580865</td>
#       <td id="T_72212_row1_col4" class="data row1 col4" >7.916173</td>
#       <td id="T_72212_row1_col5" class="data row1 col5" >241.549148</td>
#       <td id="T_72212_row1_col6" class="data row1 col6" >52.580832</td>
#       <td id="T_72212_row1_col7" class="data row1 col7" >10.516166</td>
#       <td id="T_72212_row1_col8" class="data row1 col8" >1464.473595</td>
#     </tr>
#     <tr>
#       <th id="T_72212_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_72212_row2_col0" class="data row2 col0" >89.069720</td>
#       <td id="T_72212_row2_col1" class="data row2 col1" >17.813944</td>
#       <td id="T_72212_row2_col2" class="data row2 col2" >230426.000000</td>
#       <td id="T_72212_row2_col3" class="data row2 col3" >24.502196</td>
#       <td id="T_72212_row2_col4" class="data row2 col4" >4.900439</td>
#       <td id="T_72212_row2_col5" class="data row2 col5" >29.866147</td>
#       <td id="T_72212_row2_col6" class="data row2 col6" >42.166699</td>
#       <td id="T_72212_row2_col7" class="data row2 col7" >8.433340</td>
#       <td id="T_72212_row2_col8" class="data row2 col8" >345.691132</td>
#     </tr>
#     <tr>
#       <th id="T_72212_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_72212_row3_col0" class="data row3 col0" >89.069720</td>
#       <td id="T_72212_row3_col1" class="data row3 col1" >17.813944</td>
#       <td id="T_72212_row3_col2" class="data row3 col2" >230426.000000</td>
#       <td id="T_72212_row3_col3" class="data row3 col3" >27.709450</td>
#       <td id="T_72212_row3_col4" class="data row3 col4" >5.541890</td>
#       <td id="T_72212_row3_col5" class="data row3 col5" >46.588113</td>
#       <td id="T_72212_row3_col6" class="data row3 col6" >42.131175</td>
#       <td id="T_72212_row3_col7" class="data row3 col7" >8.426235</td>
#       <td id="T_72212_row3

# %%
RESULT.swaplevel(axis=1)['pp'].style.background_gradient()
# Out:
# <style type="text/css">
# #T_e8e31_row0_col0, #T_e8e31_row0_col1, #T_e8e31_row0_col2, #T_e8e31_row1_col0, #T_e8e31_row2_col0, #T_e8e31_row3_col0, #T_e8e31_row4_col0, #T_e8e31_row4_col1, #T_e8e31_row4_col2, #T_e8e31_row5_col0, #T_e8e31_row5_col2, #T_e8e31_row6_col0, #T_e8e31_row7_col0, #T_e8e31_row7_col1, #T_e8e31_row7_col2, #T_e8e31_row8_col0, #T_e8e31_row9_col0, #T_e8e31_row9_col1, #T_e8e31_row10_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_e8e31_row1_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_e8e31_row1_col2 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_e8e31_row2_col1, #T_e8e31_row5_col1, #T_e8e31_row6_col1, #T_e8e31_row6_col2 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_e8e31_row2_col2, #T_e8e31_row3_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_e8e31_row3_col1, #T_e8e31_row9_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_e8e31_row8_col1 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_e8e31_row8_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_e8e31_row10_col1, #T_e8e31_row10_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e8e31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8e31_level0_col0" class="col_heading level0 col0" >M0</th>
#       <th id="T_e8e31_level0_col1" class="col_heading level0 col1" >M1</th>
#       <th id="T_e8e31_level0_col2" class="col_heading level0 col2" >M2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8e31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8e31_row0_col0" class="data row0 col0" >230426.000000</td>
#       <td id="T_e8e31_row0_col1" class="data row0 col1" >18.846977</td>
#       <td id="T_e8e31_row0_col2" class="data row0 col2" >41.501044</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8e31_row1_col0" class="data row1 col0" >230426.000000</td>
#       <td id="T_e8e31_row1_col1" class="data row1 col1" >241.549148</td>
#       <td id="T_e8e31_row1_col2" class="data row1 col2" >1464.473595</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8e31_row2_col0" class="data row2 col0" >230426.000000</td>
#       <td id="T_e8e31_row2_col1" class="data row2 col1" >29.866147</td>
#       <td id="T_e8e31_row2_col2" class="data row2 col2" >345.691132</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8e31_row3_col0" class="data row3 col0" >230426.000000</td>
#       <td id="T_e8e31_row3_col1" class="data row3 col1" >46.588113</td>
#       <td id="T_e8e31_row3_col2" class="data row3 col2" >343.992908</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8e31_row4_col0" class="data row4 col0" >230426.000000</td>
#       <td id="T_e8e31_row4_col1" class="data row4 col1" >18.787421</td>
#       <td id="T_e8e31_row4_col2" class="data row4 col2" >33.521644</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e8e31_row5_col0" class="data row5 col0" >230426.000000</td>
#       <td id="T_e8e31_row5_col1" class="data row5 col1" >26.931877</td>
#       <td id="T_e8e31_row5_col2" class="data row5 col2" >51.553444</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e8e31_row6_col0" class="data row6 col0" >230426.000000</td>
#       <td id="T_e8e31_row6_col1" class="data row6 col1" >27.835204</td>
#       <td id="T_e8e31_row6_col2" class="data row6 col2" >81.570159</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e8e31_row7_col0" class="data row7 col0" >230426.000000</td>
#       <td id="T_e8e31_row7_col1" class="data row7 col1" >18.743415</td>
#       <td id="T_e8e31_row7_col2" class="data row7 col2" >23.822094</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e8e31_row8_col0" class="data row8 col0" >230426.000000</td>
#       <td id="T_e8e31_row8_col1" class="data row8 col1" >279.363474</td>
#       <td id="T_e8e31_row8_col2" class="data row8 col2" >1682.238410</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e8e31_row9_col0" class="data row9 col0" >230426.000000</td>
#       <td id="T_e8e31_row9_col1" class="data row9 col1" >20.088960</td>
#       <td id="T_e8e31_row9_col2" class="data row9 col2" >197.940544</td>
#     </tr>
#     <tr>
#       <th id="T_e8e31_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e8e31_row10_col0" class="data row10 col0" >230426.000000</td>
#       <td id="T_e8e31_row10_col1" class="data row10 col1" >1932.384494</td>
#       <td id="T_e8e31_row10_col2" class="data row10 col2" >12812.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
RESULT.swaplevel(axis=1)['mean'].style.background_gradient()
# Out:
# <style type="text/css">
# #T_7a04d_row0_col0, #T_7a04d_row0_col1, #T_7a04d_row1_col0, #T_7a04d_row2_col0, #T_7a04d_row3_col0, #T_7a04d_row4_col0, #T_7a04d_row4_col1, #T_7a04d_row5_col0, #T_7a04d_row6_col0, #T_7a04d_row7_col0, #T_7a04d_row7_col1, #T_7a04d_row7_col2, #T_7a04d_row8_col0, #T_7a04d_row9_col0, #T_7a04d_row10_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7a04d_row0_col2, #T_7a04d_row6_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_7a04d_row1_col1 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_7a04d_row1_col2 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# #T_7a04d_row2_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_7a04d_row2_col2, #T_7a04d_row3_col2 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_7a04d_row3_col1, #T_7a04d_row6_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_7a04d_row4_col2 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_7a04d_row5_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_7a04d_row5_col2 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_7a04d_row8_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_7a04d_row8_col2 {
#   background-color: #2182b9;
#   color: #f1f1f1;
# }
# #T_7a04d_row9_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7a04d_row9_col2 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_7a04d_row10_col1, #T_7a04d_row10_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7a04d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a04d_level0_col0" class="col_heading level0 col0" >M0</th>
#       <th id="T_7a04d_level0_col1" class="col_heading level0 col1" >M1</th>
#       <th id="T_7a04d_level0_col2" class="col_heading level0 col2" >M2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >sent_num</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a04d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a04d_row0_col0" class="data row0 col0" >17.813944</td>
#       <td id="T_7a04d_row0_col1" class="data row0 col1" >4.236261</td>
#       <td id="T_7a04d_row0_col2" class="data row0 col2" >5.375076</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a04d_row1_col0" class="data row1 col0" >17.813944</td>
#       <td id="T_7a04d_row1_col1" class="data row1 col1" >7.916173</td>
#       <td id="T_7a04d_row1_col2" class="data row1 col2" >10.516166</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a04d_row2_col0" class="data row2 col0" >17.813944</td>
#       <td id="T_7a04d_row2_col1" class="data row2 col1" >4.900439</td>
#       <td id="T_7a04d_row2_col2" class="data row2 col2" >8.433340</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a04d_row3_col0" class="data row3 col0" >17.813944</td>
#       <td id="T_7a04d_row3_col1" class="data row3 col1" >5.541890</td>
#       <td id="T_7a04d_row3_col2" class="data row3 col2" >8.426235</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a04d_row4_col0" class="data row4 col0" >17.813944</td>
#       <td id="T_7a04d_row4_col1" class="data row4 col1" >4.231695</td>
#       <td id="T_7a04d_row4_col2" class="data row4 col2" >5.067021</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a04d_row5_col0" class="data row5 col0" >17.813944</td>
#       <td id="T_7a04d_row5_col1" class="data row5 col1" >4.751243</td>
#       <td id="T_7a04d_row5_col2" class="data row5 col2" >5.687997</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a04d_row6_col0" class="data row6 col0" >17.813944</td>
#       <td id="T_7a04d_row6_col1" class="data row6 col1" >4.798839</td>
#       <td id="T_7a04d_row6_col2" class="data row6 col2" >6.349970</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a04d_row7_col0" class="data row7 col0" >17.813944</td>
#       <td id="T_7a04d_row7_col1" class="data row7 col1" >4.228312</td>
#       <td id="T_7a04d_row7_col2" class="data row7 col2" >4.574228</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a04d_row8_col0" class="data row8 col0" >17.813944</td>
#       <td id="T_7a04d_row8_col1" class="data row8 col1" >8.126000</td>
#       <td id="T_7a04d_row8_col2" class="data row8 col2" >10.716166</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a04d_row9_col0" class="data row9 col0" >17.813944</td>
#       <td id="T_7a04d_row9_col1" class="data row9 col1" >4.328331</td>
#       <td id="T_7a04d_row9_col2" class="data row9 col2" >7.628923</td>
#     </tr>
#     <tr>
#       <th id="T_7a04d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a04d_row10_col0" class="data row10 col0" >17.813944</td>
#       <td id="T_7a04d_row10_col1" class="data row10 col1" >10.916166</td>
#       <td id="T_7a04d_row10_col2" class="data row10 col2" >13.645208</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Compute Model Perplexity

# %%
np.exp2(RESULT.swaplevel(axis=1)['mean'].mean())
# Out:
# M0    230426.000000
# M1        56.334266
# M2       231.744887
# dtype: float64

# %% [markdown]
# In language modeling, perplexity is a measure of how well a probability model predicts a test set. It is often used to compare different models: the lower the perplexity, the better the model's performance in terms of predicting the test set. When dealing with n-gram models like unigrams, bigrams, and trigrams, the relationship between the value of 'n' and the perplexity of the model on a given test corpus can vary, depending on several factors.
#
# 1. **Data Sparsity**: As 'n' increases in n-gram models (moving from unigram to bigram to trigram), the models become more sensitive to the specific sequences of words in the training data. This can lead to an issue known as data sparsity: trigram models, for example, require a lot more data to encounter all possible word sequences of length three. If your training corpus isn't sufficiently large and diverse, trigram and higher n-gram models may suffer because they haven't seen enough examples of each word sequence during training.
#
# 2. **Generalization vs. Specificity**: Unigram models, being the simplest, have high generalizability but low specificity—they treat each word independently and don't capture the context. Trigram models, on the other hand, capture more context but might become too specific to the training data, failing to generalize well to unseen data. If the test corpus contains many word sequences not seen in the training corpus, a higher n-gram model might perform poorly, leading to higher perplexity.
#
# 3. **Model Complexity and Overfitting**: Higher n-gram models (like trigrams) are more complex and can potentially overfit the training data. Overfitting occurs when a model learns patterns that are specific to the training data, including noise and outliers, rather than capturing the underlying structure of the language. This can lead to increased perplexity on the test set, as the model is less able to generalize to unseen data.
#
# In summary, whether perplexity increases or decreases with n depends on the characteristics of your training and test data, as well as how well the model's complexity is suited to the amount and diversity of the data. In an ideal scenario with ample, diverse training data, you might expect a bigram or trigram model to outperform a unigram model, leading to lower perplexity. However, in practical scenarios, especially when dealing with limited or highly specific datasets, the relationship might not be so straightforward.

# %% [markdown]
# ## Generate Text
#
# We use so-called "stupid back-off" to account for missing ngrams.

# %% [markdown]
# ### `generate_text()`

# %%
def generate_text(n=250):
    
    m1, m2, m3 = M
    start_word = m1.sample(weights='p').index[0][0]
    words = [start_word]
    
    for i in range(n):
        
        if len(words) == 1:
            next_word = m2.loc[start_word].sample(weights='p').index[0]
        
        elif len(words) > 1:

            # Get previous two words
            bg = tuple(words[-2:])
            
            # Try trigram model
            try:
                next_word = m3.loc[bg].sample(weights='cp').index[0]
            
            # If not in model, back off ...
            except KeyError:
                
                # Get the last word in the bigram
                ug = bg[1] 

                if ug == '<s>':
                    next_word = m1.sample(weights='p').index[0][0]
                else:
                    next_word = m2.loc[ug].sample(weights='cp').index[0]
            
        # Some words are returned as single item tuples
        if isinstance(next_word, tuple):
            next_word = next_word[0]
        
        words.append(next_word)
    
    text = ' '.join(words)
    lines = text.split('<s> <s>')
    for line in lines:
        print(line.strip().upper())

# %%
generate_text()
# Out:
# SAID NO MORE AND MORE PARTICULAR ACCOUNT OF THEIR DANGER THAT SHE SHOULD EXPRESS HERSELF PROPERLY BY LETTER COULD NOT FINISH HIS HALF AVERTED EYES AND WITH THE MORNING </S> <S> SOME MOTHERS MIGHT HAVE BEEN IN THE WISH OF SOCIETY </S> <S> SO THERE WAS NOTHING TO LOUISA </S> <S> THE IMPERTINENCE OF THESE SORT OF A REVIVAL OF HIS MERITS </S> <S> THERE ARE MOMENTS WHEN THE DOOR TOWARDS THE MANNERS OF ONE SISTER TO A THIRD PERSON OR DRIVING OUT IN ANNUITIES ON THE TABLE AND CONTINUED HER LETTER DIRECTLY WHILE MARIANNE STILL DEEPER BY TREATING THEIR APPREHENSIONS WERE THE WALLS COVERED WITH KISSES HER WOUND BATHED WITH LAVENDER WATER BY ONE OF THEIR LOOKS AND IN ANOTHER MOMENT HENRIETTA SINKING UNDER THE CONSTANT USE AND WITH AN ENERGY WHICH ALWAYS ADORNED HER PRAISE </S> <S> I ASSURE YOU BE SO GOOD HUMOURED AND MERRY </S> <S> HE WAS BY HER HUSBAND WAS A GREAT PLEASURE IN BEING TOGETHER AT ALL AWARE OF BEING PERFECTLY READY TO GIVE HIM MORE THAN EXCUSABLE IN THE COMPARISON IT NECESSARILY PRODUCED BETWEEN ELINOR AND MARIANNE WHO HAD BEEN RESIDING HAD RECEIVED FROM MRS SMITH </S> <S> AND ELINOR WHO KNEW ONLY THAT THE WRETCHED STATE OF SUCH RESIDENT CURATE S BEING TO BE BORNE </S> <S> SHE MUST LEARN TO FEEL THE SAME </S> <S> THE IVORY THE GOLD AND THE CHEERFULNESS OF THE LAW </S> <S> BUT SINCE HE MUST WISH HER JOY </S> <S> THE CHILDREN GO ON </S>

# %%
generate_text()
# Out:
# CANNOT THINK IT TOO LATE THEN I MUST HAVE </S> <S> D </S> <S> HE RECEIVED THE INFORMATION WITHOUT THE SMALLEST SUSPICION THEREFORE HAD EVER COME WITHIN THE LAST EVENING OF THEIR HAVING PASSED CLOSE BY HIM THAT I MIGHT HAVE BEEN TAKEN UP BY SOMETHING ELSE </S> <S> YOUR HOME COUNTRY FRIENDS ALL QUITTED </S> <S> WELL AS TO THE MANNER THE SILENCE AND A VERY GOOD INDEED </S> <S> HOW MUCH HE WANTED TO ANIMATE HER CURIOSITY GRATIFIED </S> <S> AT LAST RECOVERING FROM ILLNESS HAD BEEN ASHAMED TO BE INTRODUCED TO THEM CONCLUDED A SHORT RECAPITULATION OF WHAT SHE HAD TURNED FROM HIM SOME TASTE OF THE QUESTION COULD NOT LIVE ENTIRELY BY THE PRESENT WAS NOT ONLY UPON GAINING EVERY NEW PRINT OF MERIT IN MAINTAINING HER OWN COMPLETE INDEPENDENCE OF MRS </S> <S> HIS KINDNESS IN STEPPING FORWARD TO </S> <S> YES YES WE CAN MEAN NO OTHER VISITOR APPEARED THAT EVENING IN WESTGATE BUILDINGS AS ANNE S LOT TO BE READ WITH LESS RELUCTANCE THAN SHE FORESAW AND TO BE THOUGHT SO THEN HE HAD DONE IT AWAY </S> <S> BY HIS COMMENDATION </S> <S> HIS NAME </S> <S> WILLOUGHBY </S> <S> SURFACES STRANGE AND UNREASONABLE IF HE WOULD HAVE BEEN STRONG DISGUST </S> <S> IT WOULD NOT DO LESS THAN HIS </S> <S> I AM A LITTLE DISAGREEMENT IN WHICH MISS ELLIOT TO BE BY THE LINGERING AND LONG PETTED MASTER HARRY SENT TO SCHOOL AFTER HIS DEATH AND THEY BOTH SEEMED DELIGHTED WITH

# %% [markdown]
# ## Save

# %%
path_prefix = f"{output_dir}/austen-combo"
NG.to_csv(f"{path_prefix}-NG.csv")
for i in range(len(M)):
    M[i].to_csv(f"{path_prefix}-M{i}.csv", index=True)

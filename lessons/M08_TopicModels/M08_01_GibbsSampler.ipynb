# %% [markdown]
# # Gibbs Sampler
#
# ```yaml
# Course:    DS 5001
# Module:    08 Lab
# Topic:     Gibbs Sampler
# Author:    R.C. Alvarado
# Date:      03 March 2023 (revised)
# ```
# **Purpose:** We develop a simple topic modeler using collapsed Gibbs sampling as described by [Griffiths and Steyvers (2004)](https://collab.its.virginia.edu/access/content/group/b9e58ce7-0f44-48fe-9861-b7a7657f551a/Articles/sciencetopics.pdf).

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import re
from nltk.corpus import stopwords

# %% [markdown]
# # Convert F1 Corpus
#
# We want to convert any given F1 corpus (DOC) into unannotated TOKEN and VOCAB tables.
#
# This is so we can work with ad hoc training data.

# %%
class Corpus:

    def __init__(self, doc_list:list, doc_col='doc_str'):
        "Create DOC table from F1 list"
        self.DOC = pd.DataFrame(doc_list, columns=[doc_col])
        self.DOC.index.name = 'doc_id'
        self.stop_words = set(stopwords.words('english')) 
        
    def convert_corpus(self):        
        "Convert raw docs into TOKEN and BOW tables"
        tokens = []
        for i, row in self.DOC.iterrows():
            for j, token in enumerate(row.doc_str.split()):
                term_str = re.sub(r'[\W_]+', '', token).lower()
                if term_str not in self.stop_words:
                    tokens.append((i, j, term_str))
        self.TOKEN = pd.DataFrame(tokens, columns=['doc_id','token_num','term_str'])\
            .set_index(['doc_id','token_num'])
        self.BOW = self.TOKEN.groupby(['doc_id','term_str']).term_str.count().to_frame('n')
        return self
        
    def extract_vocab(self):
        "Extract vocabulary VOCAB"
        self.VOCAB = self.TOKEN.term_str.value_counts().to_frame('n')
        self.VOCAB.index.name = 'term_str'   
        return self

# %%
raw_docs = """
I ate a banana and a spinach smoothie for breakfast.
I like to eat broccoli and bananas.
Chinchillas and kittens are cute.
My sister adopted a kitten yesterday.
Look at this cute hamster munching on a piece of broccoli.
""".split("\n")[1:-1]

# %%
corpus1 = Corpus(raw_docs).convert_corpus().extract_vocab()

# %%
corpus1.BOW
# Out:
#                     n
# doc_id term_str
# 0      ate          1
#        banana       1
#        breakfast    1
#        smoothie     1
#        spinach      1
# 1      bananas      1
#        broccoli     1
#        eat          1
#        like         1
# 2      chinchillas  1
#        cute         1
#        kittens      1
# 3      adopted      1
#        kitten       1
#        sister       1
#        yesterday    1
# 4      broccoli     1
#        cute         1
#        hamster      1
#        look         1
#        munching     1
#        piece        1

# %% [markdown]
# # Gibbs Sampler
#
# We sample each document and word combination in the BOW table. In each case,
# we are looking for two values:
#
# * the topic with which a word has been most frequently labeled
# * the topic with which the document has the most labeled words
#
# We combine these values in order to align the label of the current word with the rest of the data.\
# If a the topic is highly associated with both the word and the document, then that topic will get a high value.
#
# Note that all that is going on here is a sorting operation -- the random assignment does not predict anything.\
# Instead, we are just gathering words under topics and topics under documents.

# %% [markdown]
# **From Darling 2011:**
# <hr />
# <div style="float:left;">
# <img src="images/gibbs-algo-text.png" width="650px" />
# <img src="images/gibbs-algo.png" width="650px" />
# </div>

# %%
class GibbsSampler:

    def __init__(self, n_topics=10, iters=100, a = 1, b = 1):

        # Map arguments
        self.n_topics = n_topics
        self.iters = iters
        self.a = a
        self.b = b 
        
        # Define topic table
        topic_names = [f"T{str(t).zfill(len(str(self.n_topics)))}" for t in range(self.n_topics)]
        self.TOPIC = pd.DataFrame({'top_terms':'TBD'}, index=topic_names)
        self.TOPIC.index.name = 'topic_id'

    def add_corpus(self, corpus:Corpus):
        
        # Copy BOW and assign random topics        
        self.BOW = corpus.BOW.copy()
        self.BOW['topic_id'] = self.TOPIC.sample(len(self.BOW), replace=True).index
        
        # Get vocab length
        self.VOCAB = corpus.VOCAB
        self.W = self.VOCAB.shape[0]       
        
        return self
            
    def compute_topics(self):
        
        # Create count tables
        self.THETA = self.BOW.groupby(['doc_id', 'topic_id']).size().unstack(fill_value=0)
        self.PHI = self.BOW.groupby(['topic_id', 'term_str']).size().unstack(fill_value=0)
        self.TOPIC['n'] = self.BOW['topic_id'].value_counts().reindex(self.TOPIC.index, fill_value=0)

        # Iterate
        for i in tqdm(range(self.iters)):

            # Estimate topic per word
            for (doc_id, term_str), row in self.BOW.iterrows():

                # Get the current topic
                z = row['topic_id']

                # Decrement counts
                self.THETA.at[doc_id, z] -= 1
                self.PHI.at[z, term_str] -= 1
                self.TOPIC.at[z, 'n'] -= 1
                self.W -= 1

                # Calculate topic probabilities
                doc_topic_prob = (self.THETA.loc[doc_id] + self.a) / (self.THETA.loc[doc_id].sum() + self.a * self.n_topics)                
                topic_term_prob = (self.PHI[term_str] + self.b) / (self.TOPIC['n'] + self.b * self.W) 
                
                PZ = doc_topic_prob * topic_term_prob
                PZ /= PZ.sum()  # Normalize

                # Sample new topic
                z_new = PZ.sample(weights=PZ).index[0]
                self.BOW.at[(doc_id, term_str), 'topic_id'] = z_new

                # Increment counts
                self.THETA.at[doc_id, z_new] += 1
                self.PHI.at[z_new, term_str] += 1
                self.TOPIC.at[z_new, 'n'] += 1
                self.W += 1
                
        return self
        
    def get_top_terms(self):
        # Get top words for each topic
        for topic_id in self.TOPIC.index:
            self.TOPIC.loc[topic_id, 'top_terms'] = ' '.join(self.PHI.loc[topic_id, self.PHI.loc[topic_id] > 0].index.values)
            
        return self

# %%
def do_all(f1_list:[], k=4, iters=100):
    corpus = Corpus(f1_list).convert_corpus().extract_vocab()
    model = GibbsSampler(n_topics=k, iters=iters, a=1, b=1).add_corpus(corpus).compute_topics().get_top_terms()
    corpus = corpus.DOC.join(model.THETA.astype('int'))
    return corpus, model

# %% [markdown]
# # Demo 1
#
# We use a toy example to see if the method works.\
# Because our codd is not vert efficient, we just

# %% [markdown]
# ## Data
#
# A small F1 corpus.

# %%
raw_docs = """
I ate a banana and a spinach smoothie for breakfast.
I like to eat broccoli and bananas.
Chinchillas and kittens are cute.
My sister adopted a kitten yesterday.
Look at this cute hamster munching on a piece of broccoli.
""".split("\n")[1:-1]

# %% [markdown]
# ## Process

# %%
cp1, tm1 = do_all(raw_docs, k=5, iters=500)
# Out:
#   1%|          | 5/500 [00:00<00:22, 21.68it/s]
# T topic_id
# T0    5
# T1    3
# T2    2
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    4
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    2
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    1
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    4
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    4
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    2
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    2
# T3    4
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    5
# T2    2
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    1
# T3    4
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    4
# T2    1
# T3    4
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    4
# T2    1
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    1
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    1
# T3    4
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    4
# T2    1
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    1
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    3
# T2    1
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    1
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    1
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    0
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    3
# T2    0
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    4
# T2    0
# T3    5
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    9
# T1    4
# T2    0
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    4
# T2    0
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    4
# T2    1
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    3
# T2    1
# T3    4
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    9
# T1    3
# T2    1
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    1
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    3
# T2    1
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    3
# T2    1
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    4
# T2    1
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    1
# T3    3
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    9
# T1    5
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    10
# T1     5
# T2     1
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    10
# T1     5
# T2     1
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    1
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    1
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    1
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    6
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    6
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    6
# T2    1
# T3    4
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    7
# T1    6
# T2    1
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    7
# T2    0
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    7
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    7
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    8
# T1    7
# T2    1
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    7
# T2    1
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    7
# T2    2
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    3
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    5
# T2    3
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    5
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    5
# T2    4
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    4
# T3    5
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    4
# T3    6
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    5
# T3    5
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    6
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    6
# T3    5
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    6
# T3    5
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    7
# T3    5
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    3
# T2    7
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    7
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    3
# T2    7
# T3    4
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    2
# T2    7
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    6
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    6
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    6
# T3    5
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    2
# T2    6
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    5
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    7
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    7
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    3
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    3
# T3    9
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    2
# T2    3
# T3    9
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    2
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    5
# T3    7
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    4
# T3    7
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    4
# T2    3
# T3    7
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    5
# T2    3
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    4
# T2    4
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    3
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    6
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    6
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    4
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    3
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    3
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    3
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    3
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    2
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    3
# T3    3
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    5
# T2    3
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    4
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    3
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    3
# T3    3
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    7
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    4
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    8
# T2    5
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    8
# T2    5
# T3    1
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    2
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    2
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    6
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    5
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    8
# T2    4
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    4
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    4
# T3    3
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    4
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    5
# T3    2
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    5
# T2    5
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    3
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#   2%|▏         | 11/500 [00:00<00:21, 23.28it/s]
# T topic_id
# T0    2
# T1    6
# T2    3
# T3    4
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    6
# T2    3
# T3    4
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    2
# T3    4
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    2
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    2
# T3    3
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    6
# T2    2
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    3
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    3
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    4
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    4
# T3    2
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    3
# T3    2
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    7
# T2    3
# T3    2
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    6
# T2    3
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    3
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    3
# T3    2
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    4
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    4
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    4
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    3
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    3
# T3    1
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    4
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    5
# T3    1
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    4
# T2    5
# T3    1
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    5
# T2    5
# T3    1
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    5
# T3    1
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    5
# T3    1
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    5
# T3    1
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    5
# T3    1
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    5
# T3    1
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    4
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    6
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    4
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    5
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    6
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    7
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    3
# T2    7
# T3    1
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    7
# T3    0
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    8
# T3    0
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    4
# T2    8
# T3    0
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    4
# T2    7
# T3    0
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    3
# T2    7
# T3    0
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    8
# T1    2
# T2    7
# T3    0
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    2
# T2    7
# T3    0
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    2
# T2    7
# T3    0
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    2
# T2    7
# T3    1
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    2
# T2    7
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    6
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    6
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    6
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    6
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    6
# T3    2
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    3
# T2    7
# T3    2
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    3
# T2    7
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    3
# T2    7
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    3
# T2    7
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    3
# T2    7
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    8
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    8
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    7
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    8
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    2
# T2    8
# T3    2
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    2
# T2    8
# T3    2
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    2
# T2    8
# T3    2
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    2
# T2    8
# T3    2
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    3
# T2    8
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    3
# T2    8
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    8
# T3    2
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    3
# T2    8
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    7
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    7
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    7
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    7
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    6
# T3    1
# T4    9
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    3
# T2    7
# T3    1
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    3
# T2    6
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    4
# T2    5
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    4
# T2    4
# T3    2
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    5
# T2    3
# T3    2
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     5
# T2     3
# T3     2
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     5
# T2     3
# T3     2
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     6
# T2     2
# T3     2
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     6
# T2     2
# T3     2
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    2
# T3    2
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    2
# T3    2
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    2
# T3    2
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    7
# T2    3
# T3    2
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    3
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    9
# T2    3
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    9
# T2    3
# T3    1
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    9
# T2    3
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    9
# T2    2
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    9
# T2    2
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    3
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    8
# T2    3
# T3    2
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    8
# T2    3
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    3
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    3
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    4
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    3
# T3    2
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    4
# T3    2
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    7
# T2    4
# T3    2
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    8
# T2    4
# T3    2
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    4
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    4
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    8
# T2    4
# T3    1
# T4    5
# Name: n, dtype: int64
# P 0
#   4%|▍         | 20/500 [00:00<00:18, 25.41it/s]
# T topic_id
# T0    2
# T1    8
# T2    4
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    9
# T2    4
# T3    1
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    4
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    3
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    8
# T2    3
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    8
# T2    3
# T3    0
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    4
# T3    0
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    4
# T3    1
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    2
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    5
# T2    4
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    5
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    4
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    3
# T2    4
# T3    3
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    3
# T2    3
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    3
# T3    5
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    1
# T2    3
# T3    5
# T4    9
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    1
# T2    3
# T3    5
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    3
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    1
# T2    3
# T3    5
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    1
# T2    3
# T3    5
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    0
# T2    4
# T3    5
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    0
# T2    4
# T3    5
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    0
# T2    4
# T3    5
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    0
# T2    4
# T3    6
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    0
# T2    5
# T3    6
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    0
# T2    4
# T3    7
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    0
# T2    4
# T3    6
# T4    9
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    0
# T2    4
# T3    6
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    0
# T2    4
# T3    6
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1     0
# T2     4
# T3     5
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1     0
# T2     4
# T3     5
# T4    10
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     3
# T1     0
# T2     3
# T3     5
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    5
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    6
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    6
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    6
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    6
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    6
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    6
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    3
# T3    7
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    3
# T3    7
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    2
# T3    8
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    2
# T3    9
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    3
# T3    9
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    3
# T3    9
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    2
# T3    9
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    3
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    3
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    2
# T3    8
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    0
# T2    2
# T3    8
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    3
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    4
# T3    7
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    4
# T3    7
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    0
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    0
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    0
# T2    4
# T3    8
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    4
# T3    8
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    1
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    1
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    4
# T3    8
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    4
# T3    7
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    5
# T3    6
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    4
# T3    6
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    5
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    6
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    5
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    6
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    2
# T2    6
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    2
# T2    6
# T3    6
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    2
# T2    5
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    2
# T2    4
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    9
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    8
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    8
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    8
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    8
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    4
# T3    9
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    1
# T2    4
# T3    9
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    4
# T3    9
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    2
# T2    4
# T3    8
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    1
# T2    5
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    2
# T2    5
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    4
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    4
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    3
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    1
# T3    9
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    1
# T3    9
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    8
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    8
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    2
# T3    7
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    6
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    6
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    6
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    6
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    6
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    6
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    2
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    7
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    7
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    2
# T3    9
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    2
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    2
# T3    9
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    2
# T3    9
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    2
# T3    8
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    2
# T3    8
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    3
# T2    3
# T3    7
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    3
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    4
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    4
# T3    4
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    5
# T2    3
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    3
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    4
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    4
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    3
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    5
# T2    4
# T3    5
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    5
# T2    4
# T3    6
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    5
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    5
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    5
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    5
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#   5%|▌         | 27/500 [00:01<00:17, 26.96it/s]
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    5
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    6
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    7
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    7
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    7
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    6
# T3    4
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    7
# T2    6
# T3    4
# T4    0
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    5
# T2    6
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    5
# T2    5
# T3    3
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    4
# T3    3
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    4
# T3    2
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    9
# T1    6
# T2    3
# T3    2
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    9
# T1    5
# T2    3
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    3
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    3
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    3
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    6
# T2    3
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    6
# T2    2
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    6
# T2    2
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    6
# T2    2
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    6
# T2    2
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    6
# T2    2
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    7
# T2    2
# T3    4
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    8
# T2    2
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    9
# T2    2
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    8
# T2    3
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    8
# T2    2
# T3    4
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    8
# T2    2
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    9
# T2    2
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    9
# T2    2
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    9
# T2    2
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    9
# T2    2
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    8
# T2    2
# T3    4
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    8
# T2    3
# T3    4
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    8
# T2    3
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    3
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    3
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    3
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    3
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    2
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    2
# T3    5
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    3
# T2    2
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    1
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    1
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    6
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    7
# T1    4
# T2    1
# T3    6
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    1
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    2
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    2
# T3    7
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    7
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    7
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    8
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    5
# T2    1
# T3    9
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    1
# T3    9
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    6
# T2    1
# T3    8
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    8
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    1
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    7
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    7
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    7
# T2    1
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    1
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    0
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    0
# T3    7
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    0
# T3    8
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    7
# T2    0
# T3    8
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    8
# T2    0
# T3    7
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    8
# T2    0
# T3    7
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    8
# T2    0
# T3    7
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    9
# T2    0
# T3    7
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    10
# T2     0
# T3     7
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    11
# T2     0
# T3     6
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    11
# T2     0
# T3     5
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    11
# T2     0
# T3     6
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    11
# T2     0
# T3     5
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    11
# T2     0
# T3     4
# T4     4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    10
# T2     0
# T3     4
# T4     5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    10
# T2     0
# T3     4
# T4     5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     2
# T1    10
# T2     0
# T3     4
# T4     5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1    10
# T2     0
# T3     5
# T4     4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1    10
# T2     0
# T3     5
# T4     5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1    10
# T2     0
# T3     5
# T4     5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    9
# T2    0
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    9
# T2    0
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    9
# T2    0
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    9
# T2    0
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    9
# T2    0
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    9
# T2    0
# T3    3
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    0
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    0
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    0
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    0
# T3    5
# T4    9
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     1
# T1     6
# T2     0
# T3     4
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     6
# T2     0
# T3     4
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     5
# T2     0
# T3     5
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     5
# T2     0
# T3     5
# T4    10
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     2
# T1     5
# T2     0
# T3     4
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    0
# T3    4
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    0
# T3    4
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    5
# T2    0
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    0
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    0
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    0
# T3    6
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    1
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    1
# T3    5
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    2
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    3
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    3
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    3
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    3
# T3    5
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    4
# T2    3
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    3
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    4
# T2    3
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    4
# T2    3
# T3    5
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    4
# T2    3
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    4
# T3    5
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    4
# T3    6
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    3
# T2    4
# T3    6
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    4
# T3    6
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    2
# T2    4
# T3    5
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    2
# T2    4
# T3    4
# T4    7
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    1
# T2    5
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    5
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    5
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    4
# T3    3
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    4
# T3    3
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    3
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    2
# T3    4
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    3
# T3    4
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    4
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    4
# T3    4
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    1
# T2    4
# T3    4
# T4    6
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    1
# T2    5
# T3    3
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    1
# T2    6
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    6
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    6
# T3    4
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    1
# T2    6
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    6
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    6
# T3    4
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    6
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    1
# T2    6
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    6
# T3    6
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# ...
# T3    7
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    7
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    7
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    7
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    4
# T3    6
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    7
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    7
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    7
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    3
# T3    6
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    3
# T3    5
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    6
# T2    3
# T3    5
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    5
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    5
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    7
# T2    4
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    7
# T2    4
# T3    5
# T4    0
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    6
# T2    4
# T3    5
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    7
# T2    4
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    7
# T2    5
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    7
# T2    5
# T3    5
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    6
# T3    5
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    6
# T2    7
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    8
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    7
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    8
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    5
# T2    9
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1     4
# T2    10
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1     4
# T2    10
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1     3
# T2    10
# T3     3
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     3
# T2    10
# T3     3
# T4     4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    4
# T2    9
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    5
# T2    8
# T3    3
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    5
# T2    8
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    5
# T2    9
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    9
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    9
# T3    2
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    7
# T2    8
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    8
# T3    2
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    8
# T3    1
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    7
# T3    1
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    7
# T3    0
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    6
# T3    0
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    0
# T1    7
# T2    5
# T3    0
# T4    9
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    0
# T1    7
# T2    5
# T3    0
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    6
# T3    0
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    5
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    5
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    8
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    8
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    8
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    8
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    5
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    5
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    0
# T1    7
# T2    5
# T3    1
# T4    8
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    7
# T2    4
# T3    1
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     5
# T2     4
# T3     1
# T4    10
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     1
# T1     5
# T2     4
# T3     1
# T4    10
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    1
# T4    9
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    2
# T4    8
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    3
# T4    7
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    4
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    4
# T3    5
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    6
# T2    3
# T3    5
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    2
# T1    6
# T2    2
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    6
# T2    2
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    6
# T2    1
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    1
# T3    6
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    5
# T2    2
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    2
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    5
# T2    2
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    2
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    2
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    2
# T3    6
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    3
# T2    2
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    3
# T3    6
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    4
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    5
# T3    6
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    1
# T2    5
# T3    6
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    1
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    1
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    1
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    1
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    5
# T3    5
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    1
# T2    5
# T3    5
# T4    5
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    5
# T1    1
# T2    5
# T3    4
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    5
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    1
# T2    5
# T3    5
# T4    6
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    1
# T2    5
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    4
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    4
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    2
# T2    4
# T3    5
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    2
# T2    4
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    2
# T2    4
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    4
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    4
# T3    5
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    2
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    6
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    6
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    5
# T2    1
# T3    6
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    5
# T2    1
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    5
# T2    1
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    6
# T2    1
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    7
# T2    1
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    8
# T2    1
# T3    3
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    7
# T1    8
# T2    1
# T3    3
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    7
# T1    9
# T2    1
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    8
# T2    2
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    9
# T2    2
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    9
# T2    2
# T3    2
# T4    2
# Name: n, dtype: int64
# P 0
# 100%|██████████| 500/500 [00:20<00:00, 24.23it/s]
# T topic_id
# T0     5
# T1    10
# T2     2
# T3     2
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     6
# T1    10
# T2     1
# T3     2
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     5
# T1    10
# T2     2
# T3     2
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     4
# T1    11
# T2     2
# T3     2
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     4
# T1    10
# T2     3
# T3     2
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     3
# T1    10
# T2     4
# T3     2
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     3
# T1    10
# T2     4
# T3     2
# T4     2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    3
# T1    9
# T2    4
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    9
# T2    4
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    9
# T2    5
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    9
# T2    5
# T3    3
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    9
# T2    6
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    9
# T2    6
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    9
# T2    6
# T3    2
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    6
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    6
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    8
# T2    6
# T3    3
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    7
# T2    6
# T3    3
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    1
# T1    7
# T2    5
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    7
# T2    5
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    6
# T2    6
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    5
# T2    6
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    5
# T2    6
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    1
# T1    5
# T2    6
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    4
# T2    6
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    4
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    5
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    5
# T3    4
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    4
# T2    5
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    5
# T3    3
# T4    5
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    4
# T2    6
# T3    3
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    5
# T3    3
# T4    4
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    4
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    3
# T2    5
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    5
# T3    3
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    4
# T2    5
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    4
# T2    5
# T3    3
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    5
# T2    5
# T3    3
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    7
# T1    5
# T2    5
# T3    3
# T4    1
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    8
# T1    4
# T2    5
# T3    3
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    4
# T3    3
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    4
# T3    3
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    4
# T3    3
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    3
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    3
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    3
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    9
# T1    5
# T2    2
# T3    4
# T4    1
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    5
# T2    2
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    4
# T2    3
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    4
# T2    3
# T3    4
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    8
# T1    4
# T2    3
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    8
# T1    4
# T2    2
# T3    5
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    7
# T1    4
# T2    3
# T3    5
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    5
# T2    3
# T3    5
# T4    2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    6
# T1    5
# T2    3
# T3    4
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    6
# T1    4
# T2    3
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    4
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    4
# T2    4
# T3    5
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    4
# T3    6
# T4    3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    4
# T3    6
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    3
# T2    5
# T3    6
# T4    3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0    4
# T1    2
# T2    5
# T3    6
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    2
# T2    6
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    7
# T3    5
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    3
# T1    2
# T2    8
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    9
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    2
# T1    2
# T2    9
# T3    4
# T4    4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     2
# T2    10
# T3     4
# T4     4
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     2
# T2    10
# T3     5
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     2
# T2    10
# T3     5
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     2
# T2    10
# T3     5
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     2
# T2    10
# T3     5
# T4     3
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     1
# T1     2
# T2    11
# T3     4
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     3
# T2    10
# T3     4
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     1
# T1     2
# T2    11
# T3     4
# T4     3
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     2
# T1     2
# T2    11
# T3     4
# T4     2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     3
# T1     2
# T2    11
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     3
# T1     2
# T2    11
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     3
# T1     2
# T2    11
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     3
# T1     2
# T2    11
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     3
# T1     2
# T2    11
# T3     3
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0     3
# T1     2
# T2    11
# T3     3
# T4     2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     3
# T1     2
# T2    11
# T3     3
# T4     2
# Name: n, dtype: int64
# P 1
#
# T topic_id
# T0     3
# T1     2
# T2    10
# T3     4
# T4     2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    2
# T2    9
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    4
# T1    3
# T2    8
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0
#
# T topic_id
# T0    5
# T1    3
# T2    7
# T3    4
# T4    2
# Name: n, dtype: int64
# P 0

# %%
tm1.TOPIC
# Out:
#                                                   top_terms  n
# topic_id
# T0                                      ate banana smoothie  3
# T1                           adopted broccoli eat yesterday  4
# T2        bananas breakfast cute kitten kittens look sis...  9
# T3                                                           0
# T4         broccoli chinchillas hamster like munching piece  6

# %%
cp1.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_46946_row0_col1 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_46946_row0_col2, #T_46946_row0_col4, #T_46946_row0_col5, #T_46946_row1_col1, #T_46946_row1_col4, #T_46946_row2_col1, #T_46946_row2_col2, #T_46946_row2_col4, #T_46946_row3_col1, #T_46946_row3_col4, #T_46946_row3_col5, #T_46946_row4_col1, #T_46946_row4_col2, #T_46946_row4_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_46946_row0_col3, #T_46946_row1_col2, #T_46946_row2_col3, #T_46946_row3_col2, #T_46946_row3_col3, #T_46946_row4_col3 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_46946_row1_col3, #T_46946_row1_col5, #T_46946_row2_col5 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_46946_row4_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_46946">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46946_level0_col0" class="col_heading level0 col0" >doc_str</th>
#       <th id="T_46946_level0_col1" class="col_heading level0 col1" >T0</th>
#       <th id="T_46946_level0_col2" class="col_heading level0 col2" >T1</th>
#       <th id="T_46946_level0_col3" class="col_heading level0 col3" >T2</th>
#       <th id="T_46946_level0_col4" class="col_heading level0 col4" >T3</th>
#       <th id="T_46946_level0_col5" class="col_heading level0 col5" >T4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >doc_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46946_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_46946_row0_col0" class="data row0 col0" >I ate a banana and a spinach smoothie for breakfast.</td>
#       <td id="T_46946_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_46946_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_46946_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_46946_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_46946_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46946_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_46946_row1_col0" class="data row1 col0" >I like to eat broccoli and bananas.</td>
#       <td id="T_46946_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_46946_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_46946_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_46946_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_46946_row1_col5" class="data row1 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_46946_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_46946_row2_col0" class="data row2 col0" >Chinchillas and kittens are cute.</td>
#       <td id="T_46946_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_46946_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_46946_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_46946_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_46946_row2_col5" class="data row2 col5" >1</td>
#     </tr>
#     <tr>
#       <th id="T_46946_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_46946_row3_col0" class="data row3 col0" >My sister adopted a kitten yesterday.</td>
#       <td id="T_46946_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_46946_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_46946_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_46946_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_46946_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_46946_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_46946_row4_col0" class="data row4 col0" >Look at this cute hamster munching on a piece of broccoli.</td>
#       <td id="T_46946_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_46946_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_46946_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_46946_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_46946_row4_col5" class="data row4 col5" >4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Demo 2

# %% [markdown]
# ## Data

# %%
some_documents = [
    ["Hadoop", "Big Data", "HBase", "Java", "Spark", "Storm", "Cassandra"],
    ["NoSQL", "MongoDB", "Cassandra", "HBase", "Postgres"],
    ["Python", "scikit-learn", "scipy", "numpy", "statsmodels", "pandas"],
    ["R", "Python", "statistics", "regression", "probability"],
    ["machine learning", "regression", "decision trees", "libsvm"],
    ["Python", "R", "Java", "C++", "Haskell", "programming languages"],
    ["statistics", "probability", "mathematics", "theory"],
    ["machine learning", "scikit-learn", "Mahout", "neural networks"],
    ["neural networks", "deep learning", "Big Data", "artificial intelligence"],
    ["Hadoop", "Java", "MapReduce", "Big Data"],
    ["statistics", "R", "statsmodels"],
    ["C++", "deep learning", "artificial intelligence", "probability"],
    ["pandas", "R", "Python"],
    ["databases", "HBase", "Postgres", "MySQL", "MongoDB"],
    ["libsvm", "regression", "support vector machines"]
]
raw_docs2  = [' '.join(item) for item in some_documents]

# %% [markdown]
# ## Process

# %%
cp2, tm2 = do_all(raw_docs2, k=10, iters=500)
# Out:
# 100%|██████████| 500/500 [00:52<00:00,  9.47it/s]

# %%
tm2.TOPIC
# Out:
#                                                   top_terms   n
# topic_id
# T00       hbase intelligence java languages machines mys...   8
# T01       decision java learning libsvm networks statist...   7
# T02                  cassandra mahout mongodb r scikitlearn   6
# T03       cassandra mapreduce numpy postgres r regressio...   9
# T04       artificial big c data databases deep haskell h...  15
# T05       artificial c data hadoop intelligence neural p...  13
# T06                                  hbase mongodb pandas r   4
# T07       machine mathematics probability regression sci...   6
# T08       big deep hadoop learning libsvm machine networ...  11
# T09                                pandas python statistics   3

# %%
cp2.style.background_gradient(axis=None)
# Out:
# <style type="text/css">
# #T_558e1_row0_col1, #T_558e1_row0_col2, #T_558e1_row0_col3, #T_558e1_row0_col5, #T_558e1_row0_col10, #T_558e1_row1_col2, #T_558e1_row1_col3, #T_558e1_row1_col7, #T_558e1_row2_col4, #T_558e1_row3_col3, #T_558e1_row3_col5, #T_558e1_row3_col10, #T_558e1_row4_col3, #T_558e1_row4_col10, #T_558e1_row5_col1, #T_558e1_row5_col5, #T_558e1_row5_col6, #T_558e1_row5_col9, #T_558e1_row5_col10, #T_558e1_row6_col6, #T_558e1_row6_col8, #T_558e1_row7_col6, #T_558e1_row8_col7, #T_558e1_row8_col9, #T_558e1_row8_col10, #T_558e1_row9_col1, #T_558e1_row9_col10, #T_558e1_row10_col8, #T_558e1_row11_col4, #T_558e1_row11_col7, #T_558e1_row12_col4, #T_558e1_row13_col4, #T_558e1_row13_col6, #T_558e1_row13_col9, #T_558e1_row14_col8, #T_558e1_row14_col9, #T_558e1_row14_col10 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_558e1_row0_col4, #T_558e1_row0_col6, #T_558e1_row0_col8, #T_558e1_row0_col9, #T_558e1_row1_col1, #T_558e1_row1_col4, #T_558e1_row1_col5, #T_558e1_row1_col6, #T_558e1_row1_col8, #T_558e1_row1_col10, #T_558e1_row2_col1, #T_558e1_row2_col5, #T_558e1_row2_col6, #T_558e1_row2_col7, #T_558e1_row2_col8, #T_558e1_row2_col9, #T_558e1_row2_col10, #T_558e1_row3_col1, #T_558e1_row3_col2, #T_558e1_row3_col4, #T_558e1_row3_col7, #T_558e1_row3_col8, #T_558e1_row3_col9, #T_558e1_row4_col1, #T_558e1_row4_col2, #T_558e1_row4_col4, #T_558e1_row4_col5, #T_558e1_row4_col6, #T_558e1_row4_col7, #T_558e1_row5_col2, #T_558e1_row5_col3, #T_558e1_row5_col7, #T_558e1_row5_col8, #T_558e1_row6_col1, #T_558e1_row6_col2, #T_558e1_row6_col3, #T_558e1_row6_col4, #T_558e1_row6_col5, #T_558e1_row6_col9, #T_558e1_row6_col10, #T_558e1_row7_col2, #T_558e1_row7_col3, #T_558e1_row7_col4, #T_558e1_row7_col5, #T_558e1_row7_col8, #T_558e1_row7_col9, #T_558e1_row7_col10, #T_558e1_row8_col2, #T_558e1_row8_col3, #T_558e1_row8_col4, #T_558e1_row8_col5, #T_558e1_row8_col8, #T_558e1_row9_col2, #T_558e1_row9_col3, #T_558e1_row9_col4, #T_558e1_row9_col5, #T_558e1_row9_col6, #T_558e1_row9_col7, #T_558e1_row9_col9, #T_558e1_row10_col1, #T_558e1_row10_col2, #T_558e1_row10_col3, #T_558e1_row10_col5, #T_558e1_row10_col6, #T_558e1_row10_col7, #T_558e1_row10_col9, #T_558e1_row10_col10, #T_558e1_row11_col1, #T_558e1_row11_col2, #T_558e1_row11_col5, #T_558e1_row11_col6, #T_558e1_row11_col8, #T_558e1_row11_col9, #T_558e1_row12_col1, #T_558e1_row12_col3, #T_558e1_row12_col5, #T_558e1_row12_col6, #T_558e1_row12_col7, #T_558e1_row12_col8, #T_558e1_row12_col9, #T_558e1_row12_col10, #T_558e1_row13_col1, #T_558e1_row13_col2, #T_558e1_row13_col3, #T_558e1_row13_col5, #T_558e1_row13_col7, #T_558e1_row13_col8, #T_558e1_row14_col1, #T_558e1_row14_col2, #T_558e1_row14_col3, #T_558e1_row14_col5, #T_558e1_row14_col6, #T_558e1_row14_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_558e1_row0_col7, #T_558e1_row2_col3, #T_558e1_row7_col7, #T_558e1_row8_col1, #T_558e1_row9_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_558e1_row1_col9, #T_558e1_row2_col2, #T_558e1_row3_col6, #T_558e1_row4_col8, #T_558e1_row4_col9, #T_558e1_row5_col4, #T_558e1_row6_col7, #T_558e1_row7_col1, #T_558e1_row8_col6, #T_558e1_row10_col4, #T_558e1_row11_col3, #T_558e1_row11_col10, #T_558e1_row12_col2, #T_558e1_row13_col10, #T_558e1_row14_col4 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_558e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_558e1_level0_col0" class="col_heading level0 col0" >doc_str</th>
#       <th id="T_558e1_level0_col1" class="col_heading level0 col1" >T00</th>
#       <th id="T_558e1_level0_col2" class="col_heading level0 col2" >T01</th>
#       <th id="T_558e1_level0_col3" class="col_heading level0 col3" >T02</th>
#       <th id="T_558e1_level0_col4" class="col_heading level0 col4" >T03</th>
#       <th id="T_558e1_level0_col5" class="col_heading level0 col5" >T04</th>
#       <th id="T_558e1_level0_col6" class="col_heading level0 col6" >T05</th>
#       <th id="T_558e1_level0_col7" class="col_heading level0 col7" >T06</th>
#       <th id="T_558e1_level0_col8" class="col_heading level0 col8" >T07</th>
#       <th id="T_558e1_level0_col9" class="col_heading level0 col9" >T08</th>
#       <th id="T_558e1_level0_col10" class="col_heading level0 col10" >T09</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >doc_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_558e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_558e1_row0_col0" class="data row0 col0" >Hadoop Big Data HBase Java Spark Storm Cassandra</td>
#       <td id="T_558e1_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_558e1_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_558e1_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_558e1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_558e1_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_558e1_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_558e1_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_558e1_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_558e1_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_558e1_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_558e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_558e1_row1_col0" class="data row1 col0" >NoSQL MongoDB Cassandra HBase Postgres</td>
#       <td id="T_558e1_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_558e1_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_558e1_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_558e1_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_558e1_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_558e1_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_558e1_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_558e1_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_558e1_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_558e1_row1_col10" class="data row1 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_558e1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_558e1_row2_col0" class="data row2 col0" >Python scikit-learn scipy numpy statsmodels pandas</td>
#       <td id="T_558e1_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_558e1_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_558e1_row2_col3" class="data row2 col3" >3</td>
#       <td id="T_558e1_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_558e1_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_558e1_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_558e1_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_558e1_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_558e1_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_558e1_row2_col10" class="data row2 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_558e1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_558e1_row3_col0" class="data row3 col0" >R Python statistics regression probability</td>
#       <td id="T_558e1_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_558e1_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_558e1_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_558e1_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_558e1_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_558e1_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_558e1_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_558e1_row3_col8"

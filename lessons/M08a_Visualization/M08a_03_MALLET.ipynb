# %% [markdown]
# # Using MALLET
#
# ```yaml
# Course:   DS 5001
# Module:   08a Lab
# Topic:    Using MALLET
# Author:   R.C. Alvarado
# Date:     23 March 2023
# ```

# %% [markdown]
# ## Getting MALLET on Your System
#
# [Download MALLET](https://github.com/mimno/Mallet/zipball/master) here. This will download a zip archive file.
#
# For other options, check out the [home page](https://mimno.github.io/Mallet/).
#
# Once downloaded, you will find an executable in the `/bin` directory of the folder created when unzipping the archive file.
#
# You can just now run MALLET in a variety of ways:
#
# - You can just run the `mallet` binary file by its full path.\
#   `/home/rca2t/Documents/MSDS/DS5001/mimno-Mallet-5fbf800/bin/mallet`
# - You create a symbolic link of the binary to somewhere convenient on your system and call the link.\
#   e.g. `ln -s mimno-Mallet-5fbf800/bin/mallet mallet`
# - You can run `ant` and build and install it on your system.\
#   See Appendix below information on how compile <a href="https://mimno.github.io/Mallet/topics">MALLET</a> if you are so inclined.

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Configure

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']
local_lib = config['DEFAULT']['local_lib']

# %%
data_prefix = 'novels'

# %%
mallet_data = f"{output_dir}/mallet-demo"
# !mkdir {mallet_data}
# Out:
# mkdir: /Users/rca2t1/Dropbox/Courses/DS/DS5001/DS5001_2024_01_R/output/mallet-demo: File exists

# %%
OHCO = ['book_id', 'chap_id', 'para_num', 'sent_num', 'token_num']

# %%
max_words = 10000

# For MALLET
num_topics = 20
num_iters = 1000
show_interval = 100

# %% [markdown]
# ### Import

# %%
import pandas as pd
# import numpy as np # Not needed today

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Import a CORPUS

# %%
LIB = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-LIB.csv").set_index(OHCO[:1])

# %%
CORPUS = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-CORPUS.csv").set_index(OHCO)

# %%
CORPUS.head()
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy

# %% [markdown]
# ### Create DOC

# %%
def gather_docs(CORPUS, ohco_level, term_col='term_str'):
    OHCO = CORPUS.index.names
    CORPUS[term_col] = CORPUS[term_col].astype('str')
    DOC = CORPUS.groupby(OHCO[:ohco_level])[term_col].apply(lambda x:' '.join(x)).to_frame('doc_str')
    return DOC

# %%
DOC = gather_docs(CORPUS, 2)

# %%
DOC['n_tokens'] = DOC.doc_str.apply(lambda x: len(x.split()))

# %%
DOC
# Out:
#                                                               doc_str  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     n_tokens
# book_id    chap_id
# adventures 1            8608
#            2            9197
#            3            7020
#            4            9685
#            5            7365
# ...                      ...
# udolpho    54           5605
#            55           4164
#            56           2522
#            57            977
# usher      1            7212
#
# [320 rows x 2 columns]

# %% [markdown]
# ### Dump corpus to CSV file

# %%
mallet_corpus = DOC.join(LIB)[['doc_str','author_id']]
mallet_corpus.columns = 'doc_content doc_label'.split()
mallet_corpus[['doc_label','doc_content']].to_csv(f'{mallet_data}/novels-corpus.csv', index=False)

# %% [markdown]
# ## MALLET Time

# %% [markdown]
# ### Show MALLET options

# %%
# mallet_home = "/home/rca2t/Documents/MSDS/DS5001/mimno-Mallet-5fbf800/bin"
mallet_home = config['DEFAULT']['mallet_home']
mallet_home
# Out:
# '/Users/rca2t1/opt/mallet/bin'

# %%
! {mallet_home}/mallet
# Out:
# Unrecognized command:
# Mallet 2.0 commands:
#
#   import-dir         load the contents of a directory into mallet instances (one per file)
#   import-file        load a single file into mallet instances (one per line)
#   import-svmlight    load SVMLight format data files into Mallet instances
#   info               get information about Mallet instances
#   train-classifier   train a classifier from Mallet data files
#   classify-dir       classify data from a single file with a saved classifier
#   classify-file      classify the contents of a directory with a saved classifier
#   classify-svmlight  classify data from a single file in SVMLight format
#   train-topics       train a topic model from Mallet data files
#   infer-topics       use a trained topic model to infer topics for new documents
#   evaluate-topics    estimate the probability of new documents under a trained model
#   prune              remove features based on frequency or information gain
#   split              divide data into testing, training, and validation portions
#   bulk-load          for big input files, efficiently prune vocabulary and import docs
#
# Include --help with any option for more information

# %% [markdown]
# ### Import corpus
#
# This converts the `.csv` file we just created into a `.mallet` file.
#
# This file has a format that MALLET can more effectively process.
#
# Here we pass all of our arguments as command line arguments.
#
# Note there is an option to put this arguments into file and just pass the file as an argument.

# %%
# !{mallet_home}/mallet import-file \
--input {mallet_data}/novels-corpus.csv \
--output {mallet_data}/novels-corpus.mallet \
--keep-sequence TRUE

# %% [markdown]
# ### Train topics
#
# Now we generate our model with a bunch of paramaters.
#
# - `num-topics`: Number of topics to generate.
# - `num-iterations`: The number of iterations to run.
# - `output-doc-topics`: The file to dump our doc-topic data (THETA)
# - `output-topic-keys`: The file to dump our topic keys.
# - `word-topic-counts-file`: The file to dump our word-topic counts (raw PHI)
# - `topic-word-weights-file`: The file to dump our topic-word weights (PHI)
# - `xml-topic-report`: The XML file to dump a report.
# - `xml-topic-phrase-report`: The XML file to dump the phrases associated with topics.
# - `show-topics-interval`: The iteration interval to show results during model fitting.
# - `use-symmetric-alpha`: Whether or not to use the same alpha value for each topic.
# - `optimize-interval`: The optimization interval.
# - `diagnostics-file`: The XML file to dump some diagnostic information.

# %%
# !{mallet_home}/mallet train-topics \
--input {mallet_data}/novels-corpus.mallet \
--num-topics {num_topics} \
--num-iterations {num_iters} \
--output-doc-topics {mallet_data}/novels-doc-topics.txt \
--output-topic-keys {mallet_data}/novels-topic-keys.txt \
--word-topic-counts-file {mallet_data}/novels-word-topic-counts-file.txt \
--topic-word-weights-file {mallet_data}/novels-topic-word-weights-file.txt \
--xml-topic-report {mallet_data}/novels-topic-report.xml \
--xml-topic-phrase-report {mallet_data}/novels-topic-phrase-report.xml \
--show-topics-interval {show_interval} \
--use-symmetric-alpha false  \
--optimize-interval 100 \
--diagnostics-file {mallet_data}/novels-diagnostics.xml
# Out:
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 15717
# total tokens: 1164070
# <10> LL/token: -9.09243
# <20> LL/token: -8.60254
# <30> LL/token: -8.40738
# <40> LL/token: -8.30243
# <50> LL/token: -8.23592
# <60> LL/token: -8.18852
# <70> LL/token: -8.14655
# <80> LL/token: -8.11019
# <90> LL/token: -8.08107
#
# 0	0.25	the and they their this were which with that its from for than them woods sea far air soon road
# 1	0.25	and was had his him for that but all when were there see what very would good who man own
# 2	0.25	her she the had was that and for this herself not but been from who would could replied said castle
# 3	0.25	the with this any may all other will work and house letter without has more done own give from under
# 4	0.25	you have not your the that will what and for but from him shall would with can some time should
# 5	0.25	her and she the not was for very had with they catherine could but miss such been were have mrs
# 6	0.25	the that not was have been had poirot but there inglethorp will with from for would are one evidence very
# 7	0.25	the was his tuppence tommy with had but its and julius they there face right head get out other thats
# 8	0.25	the and which had that from but upon this was been its these were for now some could long many
# 9	0.25	the said not and matilda manfred thou his thy theodore project for isabella gutenberg this but with thee lord that
# 10	0.25	and the that with was but when are their our not one myself life most every towards felt yet little
# 11	0.25	the and emily that with which montoni his said valancourt now when but not count had annette madame while aubert
# 12	0.25	the that and his have which upon you holmes with our was had for there this from been has not
# 13	0.25	you that said and what have know not but sir are will think your can out then the about yes
# 14	0.25	the his and with upon which him was from were himself had such father death then more hand length few
# 15	0.25	the and had that her which you have for was with sergeant franklin miss she from when what rachel diamond
# 16	0.25	and the that not for all his have her when she with are must may our him shall there then
# 17	0.25	the his and that him was said them its time two their one out with three they scrooge here little
# 18	0.25	the and his said you him that lord sir will they your for with edmund baron them this but father
# 19	0.25	the and was with they door room there into night down them were through seemed could way light out then
#
# <100> LL/token: -8.05837
# <110> LL/token: -8.03662
# <120> LL/token: -8.01621
# <130> LL/token: -8.00067
# <140> LL/token: -7.99061
# <150> LL/token: -7.97479
# <160> LL/token: -7.96267
# <170> LL/token: -7.94842
# <180> LL/token: -7.94207
# <190> LL/token: -7.93512
#
# 0	0.25	the and with they their this from were its over them sun mountains sea for upon distance air whose scene
# 1	0.25	and his was that had him for all when were one there would with who could what but have made
# 2	0.25	her she had the was and this for that with been herself from said who could lady castle though not
# 3	0.25	the that with and this has some are any house from more other all may own without must letter far
# 4	0.25	you not have your the that will but for would what this shall from more should can may them let
# 5	0.25	the her and she not catherine was very they but such for with could which miss their been tilney mrs
# 6	0.25	the that was have not been poirot but inglethorp john there will would cavendish evidence one from which very this
# 7	0.25	the tuppence tommy was but julius thats they its dont james got girl jane brown would ive for from young
# 8	0.25	the and which had from upon that was this for its some not were been now these but first long
# 9	0.25	the said manfred not thou and his project this isabella gutenberg thy matilda but with theodore thee your for you
# 10	0.25	and the but was that with when their our which myself one are life they towards these felt most those
# 11	0.25	the and emily that which montoni but with his said valancourt they now then when count annette madame while aubert
# 12	0.25	the that and his have which upon holmes our there you with been from this had man for has was
# 13	0.25	you said that what not have and know will are but sir think then your out did little say how
# 14	0.25	the his and with upon which him her was from that then every were himself hand agnes antonia such father
# 15	0.25	the and had that which her was sergeant franklin for have miss with rachel when she diamond from betteredge lady
# 16	0.25	the and that not for her all she when have but with our are may shall which must from van
# 17	0.25	the and his its said they their two with this time man little them scrooge three have one people were
# 18	0.25	the and his said you lord sir him will they edmund that baron your with their philip upon them but
# 19	0.25	the and was with door they room there were out through but down night into then seemed light that them
#
# <200> LL/token: -7.93027
# <210> LL/token: -7.92037
# <220> LL/token: -7.91393
# <230> LL/token: -7.91049
# <240> LL/token: -7.90385
# <250> LL/token: -7.89993
# <260> LL/token: -7.89664
# <270> LL/token: -7.89235
# <280> LL/token: -7.88221
# <290> LL/token: -7.88567
#
# 0	0.25	the and with they their from were this its mountains them little sun over whose soon along for air where
# 1	0.25	and his was him had that for all were when would who could one have there but not them been
# 2	0.25	her she and had the was for with this herself been from but not said lady when upon that could
# 3	0.25	the with that has this and from will may any house some all far other more part our without great
# 4	0.25	you not that have your the this will but for from what are which should more shall would with can
# 5	0.25	the her and not she catherine very they for was such could but with had miss their tilney were mrs
# 6	0.25	the that was not have poirot been but inglethorp john would mrs there cavendish are one evidence will this from
# 7	0.25	the tuppence tommy was julius but sir dont thats its they james jane girl got ive with vandemeyer brown young
# 8	0.25	the which had and was that from upon this for its not been now were these long could some first
# 9	0.25	the said manfred thou not and project his isabella gutenberg thy matilda this lord with theodore thee hippolita your princess
# 10	0.25	and but the with that was which when their myself one our life they felt these every towards mind most
# 11	0.25	the and emily that which montoni said but now valancourt then his with count madame annette they while aubert had
# 12	0.25	the and that have which upon holmes his our with was from this there been man but sir had should
# 13	0.25	you that said what have know not and out are will then think now little but about there your how
# 14	0.25	the his and with him upon which from her was agnes antonia that himself every convent were such ambrosio lorenzo
# 15	0.25	the and had that which was her sergeant franklin have miss rachel for when diamond with betteredge from time way
# 16	0.25	the and that not for all her she have when with our may are shall which but van must more
# 17	0.25	the and his they their its said with scrooge three little were man time have boy out being other them
# 18	0.25	the and his said lord you sir him will edmund they your that baron with philip upon but their them
# 19	0.25	the and was with door room there but they out through down were night one saw seemed into then them
#
# [beta: 0.01809]
# <300> LL/token: -7.87351
# <310> LL/token: -7.87835
# <320> LL/token: -7.87756
# <330> LL/token: -7.87548
# <340> LL/token: -7.87339
# <350> LL/token: -7.86859
# <360> LL/token: -7.86995
# <370> LL/token: -7.86854
# <380> LL/token: -7.86597
# <390> LL/token: -7.8627
#
# 0	0.25466	the and with they their aubert from over this were mountains them woods among while little along its sun are
# 1	0.39316	and his was that had him for when would with were all who them they one there have been before
# 2	0.32381	her she the had was and for this from with herself could been said that all lady upon other might
# 3	0.35278	the that with this from has any house other may our time one some without was only far years second
# 4	0.35517	you the not have your with will that this but for which what from and are shall would should can
# 5	0.19041	her and not the catherine she very was they but for could miss such tilney their had mrs been were
# 6	0.15207	the have was not that poirot been inglethorp but john will mrs are cavendish very this would which had evidence
# 7	0.15567	the tuppence tommy but julius was sir its dont thats james jane girl they her vandemeyer young got would ive
# 8	0.34217	the and which had that upon from for was its this not were been now all more their long but
# 9	0.10998	the said manfred thou project isabella gutenberg not and thy his matilda this lord theodore with thee hippolita princess prince
# 10	0.29114	and the but was with that which when myself our every towards mind death one felt life these their did
# 11	0.17183	the and emily that which montoni said but valancourt now then his count had annette madame who they when till
# 12	0.20287	the which have and that holmes upon his our this had from been man are but there sir you was
# 13	0.33299	you that said what not have know out all your for are now and will little think with about there
# 14	0.20629	the his and with upon him was that her agnes antonia which ambrosio lorenzo every then himself matilda till convent
# 15	0.16098	the and had which have sergeant her franklin miss was that rachel when for diamond betteredge first this room blake
# 16	0.18411	the and not all her that for have she but are which when our may shall van must helsing this
# 17	0.27169	the and his scrooge they its said their man upon with boy were three spirit ghost christmas little old other
# 18	0.16166	the and his said lord sir you him edmund will they baron your upon philip their but all this oswald
# 19	0.35773	the and was with but door room there were night through then some they from out one down saw into
#
# [beta: 0.02129]
# <400> LL/token: -7.85695
# <410> LL/token: -7.85916
# <420> LL/token: -7.85472
# <430> LL/token: -7.85363
# <440> LL/token: -7.85133
# <450> LL/token: -7.85046
# <460> LL/token: -7.84644
# <470> LL/token: -7.84794
# <480> LL/token: -7.84467
# <490> LL/token: -7.84864
#
# 0	0.23047	the and with they their aubert from were mountains woods this his over among where light its little sun whose
# 1	0.52632	and his was that had the for him with were have all would them they when who there more been
# 2	0.37432	her she the had was and for from with this herself when could been upon did moment all said might
# 3	0.4306	the with that from has some this time house was one any may years without our second only own under
# 4	0.43236	the you not and that have your with will but for this from what which are shall would must heart
# 5	0.13666	her not and catherine she very they but could miss tilney been mrs for such their which was being isabella
# 6	0.0978	the that was have not poirot been inglethorp but will mrs john would there are cavendish which what evidence one
# 7	0.1042	the tuppence tommy julius but sir its dont james thats jane they girl was get vandemeyer mrs got young ive
# 8	0.39865	the and which had this that upon from not its for was were been now these but all long yet
# 9	0.0582	the said manfred thou his isabella project gutenberg not this matilda thy lord theodore hippolita thee princess prince but work
# 10	0.29709	and the but was which when that with myself every our life these towards father felt one did during their
# 11	0.12471	the emily and that which but montoni said valancourt then now count annette madame not who castle when they heard
# 12	0.15331	the which that have upon holmes his and had our been this sir from man are but would very there
# 13	0.3945	you that said what not have know are but all your now out for about will see think how this
# 14	0.1309	the his and him upon her with was which antonia agnes then ambrosio lorenzo every matilda himself till were but
# 15	0.1129	the which had and sergeant franklin that have miss rachel when diamond betteredge first her this your again time lady
# 16	0.14068	and the not all that her for when she have which may but our are shall van helsing must there
# 17	0.22535	the scrooge its they and upon his their boy said spirit ghost christmas which three like little old cried were
# 18	0.11159	the and his said lord sir you him edmund will they baron your philip upon this their all but that
# 19	0.43977	the and was with door there but out night room from one were through could into saw some eyes down
#
# [beta: 0.02272]
# <500> LL/token: -7.84475
# <510> LL/token: -7.8448
# <520> LL/token: -7.83849
# <530> LL/token: -7.83867
# <540> LL/token: -7.83773
# <550> LL/token: -7.83594
# <560> LL/token: -7.83272
# <570> LL/token: -7.83028
# <580> LL/token: -7.83121
# <590> LL/token: -7.82664
#
# 0	0.21482	the and with they from aubert their over its were this mountains among little woods whose while some where light
# 1	0.6488	and the his was that had for with him have were all they would when who but them one before
# 2	0.41361	her she was had and the for from with herself this could been when moment more might said door now
# 3	0.48462	the was with that has this from house some may time without any three morning one our name can interest
# 4	0.48396	you the not and that your but have with will from this which what for are shall him heart would
# 5	0.10066	not catherine her very they and but tilney miss could mrs such their which she being would isabella morland thorpe
# 6	0.06325	the poirot not have was that but been inglethorp john mrs will cavendish are would very which there evidence cynthia
# 7	0.07619	tuppence the tommy but julius sir its dont james they jane was thats get vandemeyer girl mrs young got ive
# 8	0.42164	the which and had this that upon from not its were for been now was all these some yet their
# 9	0.03788	the said manfred thou isabella gutenberg project matilda thy not this lord theodore his hippolita princess thee prince work you
# 10	0.27676	and but was which when that myself life the father our felt these feelings man sometimes mind miserable yet should
# 11	0.09577	the emily which that and montoni said but valancourt then count who not annette madame now had castle heard his
# 12	0.11927	which that upon holmes have the and his our had been from sir man very but this are there you
# 13	0.44418	you that said not what have your know are out will all about now there think and see how this
# 14	0.08345	the his and upon her him which with agnes antonia was ambrosio lorenzo matilda himself till their every them then
# 15	0.08896	the which had sergeant franklin and miss rachel have when diamond betteredge that first own again blake time lady cuff
# 16	0.10395	and not that all for when her shall our which have are but may van must she helsing then can
# 17	0.14773	scrooge its they upon their said ghost christmas spirit his dont which ferrier bob like cried young scrooges merry boy
# 18	0.08154	the and his said lord sir you edmund him will baron they your philip upon all their them oswald shall
# 19	0.49433	the and was with there but door room then one down were night through from out into back some saw
#
# [beta: 0.0235]
# <600> LL/token: -7.8244
# <610> LL/token: -7.822
# <620> LL/token: -7.82039
# <630> LL/token: -7.81679
# <640> LL/token: -7.81591
# <650> LL/token: -7.81196
# <660> LL/token: -7.81039
# <670> LL/token: -7.80533
# <680> LL/token: -7.80868
# <690> LL/token: -7.80636
#
# 0	0.20349	the and with they which aubert their from were over woods now its among whose mountains air light this where
# 1	0.76589	the and his was that had for with him were have all they them when would who but one this
# 2	0.44529	her she and was had the with herself for could this from been when moment all might did seemed without
# 3	0.50846	the which with from was has this some that house may any three one our two these without will only
# 4	0.51763	you the and not that but your have will with from for this which what his him shall are must
# 5	0.081	not catherine very they miss tilney her their but such could mrs general isabella morland being thorpe allen been much
# 6	0.04824	the that not poirot was have been inglethorp but will mrs john cavendish would one had evidence cynthia there yes
# 7	0.06124	tuppence tommy the julius but sir they its james thats dont jane get was girl vandemeyer young would got out
# 8	0.43396	the which and that had from upon this not its were was now been for all are more yet these
# 9	0.0272	the said manfred thou isabella project gutenberg matilda thy not lord this theodore hippolita thee princess prince work any cried
# 10	0.2501	and but which when was myself every life did felt with night their towards feelings these yet eyes became miserable
# 11	0.08278	the emily which that said montoni and but valancourt count now then annette madame heard not had some castle they
# 12	0.09901	which that upon holmes have his had been our the sir and very from man this should but would there
# 13	0.47976	you that said what not have know are your all about for will now there out think see but him
# 14	0.0612	the his upon with him her and which agnes antonia ambrosio lorenzo every your was matilda till himself their eyes
# 15	0.07443	the had sergeant that franklin which miss rachel have diamond when betteredge first time again own out house room blake
# 16	0.08349	and not that all for when her which our shall she are must van may but have helsing then lucy
# 17	0.09302	scrooge its they his upon their said christmas ghost spirit which cried were old dont ferrier bob scrooges merry young
# 18	0.06369	and the his lord said sir you edmund him will baron your they philip upon their all oswald them lovel
# 19	0.52403	the and was with but door there out room then night through down some from one were back into could
#
# [beta: 0.02391]
# <700> LL/token: -7.80428
# <710> LL/token: -7.80244
# <720> LL/token: -7.80274
# <730> LL/token: -7.80206
# <740> LL/token: -7.79985
# <750> LL/token: -7.79914
# <760> LL/token: -7.79737
# <770> LL/token: -7.79443
# <780> LL/token: -7.79359
# <790> LL/token: -7.7938
#
# 0	0.19465	the and which with they aubert from their this its were woods over mountains while his whose now among that
# 1	0.87895	the and was his that had for with him were all they but would who when have one them this
# 2	0.46999	her she and was had the for herself with could from been this when all too moment more seemed into
# 3	0.50907	the which was this with some may has house from that will any three having these first without point only
# 4	0.54266	the you and not that with your but have his from which will for this what him are shall would
# 5	0.06491	not catherine very they tilney miss but mrs could such their isabella general morland thorpe allen being though for henry
# 6	0.03803	the that was poirot not inglethorp have been but mrs john cavendish will there would had evidence cynthia very lawrence
# 7	0.05265	tuppence tommy the but julius sir was its james thats jane dont girl they vandemeyer get mrs ive brown then
# 8	0.43617	the and which had from upon that not this its been were now have but all for more yet their
# 9	0.02135	the said manfred thou isabella gutenberg project not matilda thy this lord theodore hippolita your princess thee prince work castle
# 10	0.22724	and but when was which myself our father these life feelings every did those felt elizabeth miserable towards became again
# 11	0.07461	the emily that which said montoni but valancourt then now count not annette madame who heard castle they though again
# 12	0.08622	that which upon his holmes have had our sir been this very man and has from your should there then
# 13	0.51202	you said that have not what are know your will out all now there about very him for see think
# 14	0.05246	the his upon her him was which agnes antonia with ambrosio lorenzo your every matilda himself and till bosom convent
# 15	0.06445	the had sergeant which franklin that miss rachel when diamond betteredge have own blake lady again cuff time back sir
# 16	0.06939	and not all that her for she when which shall our van may have helsing are must then him lucy
# 17	0.06783	scrooge his its upon they said their ghost christmas spirit which old cried young ferrier bob child scrooges hope merry
# 18	0.0552	and the his said lord sir edmund you will him baron philip upon they your shall their oswald them lovel
# 19	0.53858	the and was with there but door room night through out down then from into over were could some saw
#
# [beta: 0.02431]
# <800> LL/token: -7.79209
# <810> LL/token: -7.79497
# <820> LL/token: -7.79478
# <830> LL/token: -7.7914
# <840> LL/token: -7.78763
# <850> LL/token: -7.794
# <860> LL/token: -7.78775
# <870> LL/token: -7.78708
# <880> LL/token: -7.78459
# <890> LL/token: -7.78633
#
# 0	0.1885	the and which with they from aubert their that were its now over woods among while blanche mountains upon light
# 1	0.98343	the and his was that had for with him were this all they them when who one but would have
# 2	0.48753	her she was and had the herself for with could when from been might now more lady all still moment
# 3	0.50064	the was which from this with has been house will may three any without some man most one that these
# 4	0.56537	the you and not that but with have his your will for from him this which would are shall what
# 5	0.05735	not catherine very but they tilney miss her mrs such would their isabella general morland could thorpe being much which
# 6	0.03218	the that poirot not was inglethorp but been john mrs have will cavendish yes there would evidence cynthia did lawrence
# 7	0.04719	tuppence tommy the julius but sir its they was james dont jane thats well vandemeyer girl got get brown mrs
# 8	0.42292	the which upon that had this from not its and have been were now are all yet but for body
# 9	0.01941	the said manfred thou isabella not project gutenberg matilda thy lord this theodore hippolita thee but princess from prince any
# 10	0.20717	and but which when was myself eyes life our did father feelings every during towards their elizabeth miserable man these
# 11	0.06835	the emily which that said montoni but valancourt not this count then annette madame had heard who castle they though
# 12	0.07743	which that upon holmes his have our had sir man very has been there should are from but your would
# 13	0.54148	you said that have what not him are your know all will for out but see about very now think
# 14	0.04294	the his upon her which with him your was antonia agnes from ambrosio lorenzo every matilda their till himself bosom
# 15	0.0572	the had which sergeant franklin miss rachel that diamond betteredge have time when own lady house back blake again cuff
# 16	0.05881	and not all that her which when for she but may are shall van our helsing have must then lucy
# 17	0.05412	scrooge his its they upon said ghost christmas spirit their which like young were cried ferrier bob scrooges old child
# 18	0.04778	lord said and his sir you edmund the him will baron your they philip upon oswald them their shall lovel
# 19	0.54249	the and was with there door but room out from then through down into night were could hand over some
#
# [beta: 0.02462]
# <900> LL/token: -7.78642
# <910> LL/token: -7.78462
# <920> LL/token: -7.78219
# <930> LL/token: -7.78068
# <940> LL/token: -7.78302
# <950> LL/token: -7.77908
# <960> LL/token: -7.77809
# <970> LL/token: -7.77489
# <980> LL/token: -7.76843
# <990> LL/token: -7.76498
#
# 0	0.18628	the and with which they from aubert their now its were over among woods while upon that light whose mountains
# 1	1.07613	the and was his that for had with this him were them they when all who one have would but
# 2	0.50239	her she was had and the for with herself could been when from all might moment now than more upon
# 3	0.48346	the which that from was has been with house will may some three most two having are now only morning
# 4	0.58166	you the and not that his but with your have will from which this him for what would are shall
# 5	0.0508	not catherine very they her miss tilney but mrs could such their isabella would morland thorpe general being allen must
# 6	0.02907	the that poirot was not inglethorp mrs but john been cavendish will yes would cynthia there had did lawrence howard
# 7	0.04544	tuppence tommy the julius but sir its james thats they jane dont get mrs girl vandemeyer got ive brown young
# 8	0.40606	the upon that its this have not which had from been were but and one body are all for now
# 9	0.01996	the said manfred thou isabella project not gutenberg matilda thy lord this theodore hippolita work thee princess prince castle but
# 10	0.19365	and but which was when had myself life these yet did feelings were during even their father elizabeth also felt
# 11	0.0667	the emily which that said montoni but valancourt and this count then not annette madame heard had now who they
# 12	0.06876	upon that holmes his which have had our sir very man this been there but has should would watson not
# 13	0.56269	you said that have what not are him your know all will but out there about see now very one
# 14	0.03896	the his upon which her your with antonia him agnes from ambrosio lorenzo every was matilda their till bosom convent
# 15	0.05576	the had sergeant franklin miss rachel which diamond betteredge when have own time again lady blake room out cuff house
# 16	0.05094	and not that all for when her shall have our van but are must helsing him she may then which
# 17	0.04537	scrooge his its upon they ghost christmas said their spirit were young cried ferrier bob scrooges little until father like
# 18	0.04648	his lord said sir you will edmund and him baron your they philip upon oswald shall all lovel their them
# 19	0.54096	the and was with from which door but there through room then out night down hand back could over were
#
# [beta: 0.02509]
# <1000> LL/token: -7.76104
#
# Total time: 1 minutes 46 seconds

# %% [markdown]
# # Inspect Results

# %%
# !ls -l {mallet_data}
# Out:
# total 62944
# -rw-r--r--@ 1 rca2t1  staff   7960141 Mar 20 14:17 novels-corpus.csv
# -rw-r--r--@ 1 rca2t1  staff   4998802 Mar 20 14:40 novels-corpus.mallet
# -rw-r--r--@ 1 rca2t1  staff     92194 Mar 20 14:48 novels-diagnostics.xml
# -rw-r--r--@ 1 rca2t1  staff    138783 Mar 20 14:48 novels-doc-topics.txt
# -rw-r--r--@ 1 rca2t1  staff      2370 Mar 20 14:48 novels-topic-keys.txt
# -rw-r--r--@ 1 rca2t1  staff     56261 Mar 20 14:48 novels-topic-phrase-report.xml
# -rw-r--r--@ 1 rca2t1  staff     18808 Mar 20 14:48 novels-topic-report.xml
# -rw-r--r--@ 1 rca2t1  staff  17387976 Mar 20 14:48 novels-topic-word-weights-file.txt
# -rw-r--r--@ 1 rca2t1  staff    640847 Mar 20 14:48 novels-word-topic-counts-file.txt

# %% [markdown]
# ## Appendix
#
# ### Mallet
#
# Website: https://mimno.github.io/Mallet/
#
# MALLET is a Java-based package for statistical natural language processing, document classification, clustering, topic modeling, information extraction, and other machine learning applications to text.
#
# MALLET includes sophisticated tools for document classification: efficient routines for converting text to "features", a wide variety of algorithms (including Naïve Bayes, Maximum Entropy, and Decision Trees), and code for evaluating classifier performance using several commonly used metrics.
#
# In addition to classification, MALLET includes tools for sequence tagging for applications such as named-entity extraction from text. Algorithms include Hidden Markov Models, Maximum Entropy Markov Models, and Conditional Random Fields. These methods are implemented in an extensible system for finite state transducers.
#
# Topic models are useful for analyzing large collections of unlabeled text. The MALLET topic modeling toolkit contains efficient, sampling-based implementations of Latent Dirichlet Allocation, Pachinko Allocation, and Hierarchical LDA.
#
# Many of the algorithms in MALLET depend on numerical optimization. MALLET includes an efficient implementation of Limited Memory BFGS, among many other optimization methods.
#
# In addition to sophisticated Machine Learning applications, MALLET includes routines for transforming text documents into numerical representations that can then be processed efficiently. This process is implemented through a flexible system of "pipes", which handle distinct tasks such as tokenizing strings, removing stopwords, and converting sequences into count vectors.
#
# An add-on package to MALLET, called GRMM, contains support for inference in general graphical models, and training of CRFs with arbitrary graphical structure.
#
# ### Installation
#
# To build a Mallet 2.0 development release, you must have the Apache ant build tool installed. From the command prompt, first change to the mallet directory, and then type
# `ant`
#
# If `ant` finishes with `"BUILD SUCCESSFUL"`, Mallet is now ready to use.
#
# If you would like to deploy Mallet as part of a larger application, it is helpful to create a single ".jar" file that contains all of the compiled code. Once you have compiled the individual Mallet class files, use the command:
# `ant jar`
#
# This process will create a file "mallet.jar" in the "dist" directory within Mallet.
#
# ### Usage
#
# Once you have installed Mallet you can use it using the following command:
#
# ```bash
# bin/mallet [command] --option value --option value ...
# ```
# Type `bin/mallet` to get a list of commands, and use the option `--help` with any command to get a description of valid options.
#
# For details about the commands please visit the API documentation and website at: https://mimno.github.io/Mallet/
#
#
# ### List of Algorithms
#
# * Topic Modelling
#   * LDA
#   * Parallel LDA
#   * DMR LDA
#   * Hierarchical LDA
#   * Labeled LDA
#   * Polylingual Topic Model
#   * Hierarchical Pachinko Allocation Model (PAM)
#   * Weighted Topic Model
#   * LDA with integrated phrase discovery
#   * Word Embeddings (word2vec) using skip-gram with negative sampling
# * Classification
#   * AdaBoost
#   * Bagging
#   * Winnow
#   * C45 Decision Tree
#   * Ensemble Trainer
#   * Maximum Entropy Classifier (Multinomial Logistic Regression)
#   * Naive Bayes
#   * Rank Maximum Entropy Classifier
#   * Posterior Regularization Auxiliary Model
# * Clustering
#   * Greedy Agglomerative
#   * Hill Climbing
#   * K-Means
#   * K-Best
# * Sequence Prediction Models
#   * Conditional Random Fields
#   * Maximum Entropy Markov Models
#   * Hidden Markov Models
#   * Semi-Supervised Sequence Prediction Models
# * Linear Regression

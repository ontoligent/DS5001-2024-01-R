# %% [markdown]
# # Using MALLET
#
# ```yaml
# Course:   DS 5001
# Module:   08a Lab
# Topic:    Using MALLET
# Author:   R.C. Alvarado
# Date:     23 March 2023
# ```

# %% [markdown]
# ## Notes
#
# See Appendix below information on how download and install <a href="https://mimno.github.io/Mallet/topics">MALLET</a>.

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Configure

# %%
import configparser
config = configparser.ConfigParser()
config.read("../../../env.ini")
data_home = config['DEFAULT']['data_home']
output_dir = config['DEFAULT']['output_dir']
local_lib = config['DEFAULT']['local_lib']

# %%
data_prefix = 'novels'

# %%
mallet_data = f"{output_dir}/mallet-demo"
# !mkdir {mallet_data}
# Out:
# mkdir: /Users/rca2t1/Dropbox/Courses/DS/DS5001/DS5001_2024_01_R/output/mallet-demo: File exists

# %%
OHCO = ['book_id', 'chap_id', 'para_num', 'sent_num', 'token_num']

# %%
max_words = 10000

# For MALLET
num_topics = 20
num_iters = 1000
show_interval = 100

# %% [markdown]
# ### Import

# %%
import pandas as pd
# import numpy as np

# %% [markdown]
# ## Prepare

# %% [markdown]
# ### Import CORPUS

# %%
LIB = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-LIB.csv").set_index(OHCO[:1])

# %%
CORPUS = pd.read_csv(f"{data_home}/{data_prefix}/{data_prefix}-CORPUS.csv").set_index(OHCO)

# %%
CORPUS.head()
# Out:
#                                                      pos     term_str
# book_id         chap_id para_num sent_num token_num
# secretadversary 1       0        1        0           DT          the
#                                           1          NNP        young
#                                           2          NNP  adventurers
#                                           3          NNP          ltd
#                         1        0        0           JJ        tommy

# %% [markdown]
# ### Create DOC

# %%
def gather_docs(CORPUS, ohco_level, term_col='term_str'):
    OHCO = CORPUS.index.names
    CORPUS[term_col] = CORPUS[term_col].astype('str')
    DOC = CORPUS.groupby(OHCO[:ohco_level])[term_col].apply(lambda x:' '.join(x)).to_frame('doc_str')
    return DOC

# %%
DOC = gather_docs(CORPUS, 2)

# %%
DOC['n_tokens'] = DOC.doc_str.apply(lambda x: len(x.split()))

# %%
DOC
# Out:
#                                                               doc_str  \
# book_id    chap_id
# adventures 1        a scandal in bohemia i to sherlock holmes she ...
#            2        the red headed league i had called upon my fri...
#            3        a case of identity my dear fellow said sherloc...
#            4        the boscombe valley mystery we were seated at ...
#            5        the five orange pips when i glance over my not...
# ...                                                               ...
# udolpho    54       vi unnatural deeds do breed unnatural troubles...
#            55       vii but in these cases we still have judgment ...
#            56       viii then fresh tears stood on her cheek as do...
#            57       ix now my task is smoothly done i can fly or i...
# usher      1        fall of the house of usher son coeur est un lu...
#
#                     n_tokens
# book_id    chap_id
# adventures 1            8608
#            2            9197
#            3            7020
#            4            9685
#            5            7365
# ...                      ...
# udolpho    54           5605
#            55           4164
#            56           2522
#            57            977
# usher      1            7212
#
# [320 rows x 2 columns]

# %% [markdown]
# ### Dump corpus to CSV file

# %%
mallet_corpus = DOC.join(LIB)[['doc_str','author_id']]
mallet_corpus.columns = 'doc_content doc_label'.split()
mallet_corpus[['doc_label','doc_content']].to_csv(f'{mallet_data}/novels-corpus.csv', index=False)

# %% [markdown]
# ## MALLET Time

# %% [markdown]
# ### Show MALLET options

# %%
# mallet_home = "/Users/rca2t1/opt/mallet/bin"
mallet_home = config['DEFAULT']['mallet_home']

# %%
! {mallet_home}/mallet
# Out:
# Unrecognized command:
# Mallet 2.0 commands:
#
#   import-dir         load the contents of a directory into mallet instances (one per file)
#   import-file        load a single file into mallet instances (one per line)
#   import-svmlight    load SVMLight format data files into Mallet instances
#   info               get information about Mallet instances
#   train-classifier   train a classifier from Mallet data files
#   classify-dir       classify data from a single file with a saved classifier
#   classify-file      classify the contents of a directory with a saved classifier
#   classify-svmlight  classify data from a single file in SVMLight format
#   train-topics       train a topic model from Mallet data files
#   infer-topics       use a trained topic model to infer topics for new documents
#   evaluate-topics    estimate the probability of new documents under a trained model
#   prune              remove features based on frequency or information gain
#   split              divide data into testing, training, and validation portions
#   bulk-load          for big input files, efficiently prune vocabulary and import docs
#
# Include --help with any option for more information

# %% [markdown]
# ### Import corpus

# %%
# !{mallet_home}/mallet import-file \
--input {mallet_data}/novels-corpus.csv \
--output {mallet_data}/novels-corpus.mallet \
--keep-sequence TRUE

# %% [markdown]
# ### Train topics

# %%
# !{mallet_home}/mallet train-topics \
--input {mallet_data}/novels-corpus.mallet \
--num-topics {num_topics} \
--num-iterations {num_iters} \
--output-doc-topics {mallet_data}/novels-doc-topics.txt \
--output-topic-keys {mallet_data}/novels-topic-keys.txt \
--word-topic-counts-file {mallet_data}/novels-word-topic-counts-file.txt \
--topic-word-weights-file {mallet_data}/novels-topic-word-weights-file.txt \
--xml-topic-report {mallet_data}/novels-topic-report.xml \
--xml-topic-phrase-report {mallet_data}/novels-topic-phrase-report.xml \
--show-topics-interval {show_interval} \
--use-symmetric-alpha false  \
--optimize-interval 100 \
--diagnostics-file {mallet_data}/novels-diagnostics.xml
# Out:
# Mallet LDA: 20 topics, 5 topic bits, 11111 topic mask
# Data loaded.
# max tokens: 15717
# total tokens: 1164070
# <10> LL/token: -9.12846
# <20> LL/token: -8.61971
# <30> LL/token: -8.43259
# <40> LL/token: -8.32592
# <50> LL/token: -8.25605
# <60> LL/token: -8.21004
# <70> LL/token: -8.16843
# <80> LL/token: -8.13473
# <90> LL/token: -8.10637
#
# 0	0.25	the was and had all been with some upon were door from for might could being room having every nothing
# 1	0.25	the his and their him were them they who family any into upon himself where its this house than many
# 2	0.25	the that which was had from him would first his found without moment once left time for same still own
# 3	0.25	the had that and have this her for sergeant lady when has betteredge with our been blake house cuff godfrey
# 4	0.25	the tuppence tommy she her but you was his they julius said there thats dont james out with its well
# 5	0.25	her she and the had with that which for was herself his not could much madame more been valancourt only
# 6	0.25	his the her and with upon him for your but matilda then from antonia agnes himself ambrosio lorenzo theodore till
# 7	0.25	and that but was had for when with the which heart father from ever were these life felt our dear
# 8	0.25	the and emily that but said montoni for was who this from then count annette now what when they not
# 9	0.25	and you said that the his will him for your lord but sir they with all have edmund shall father
# 10	0.25	the and which they with his their was from who time that while among some after its even man men
# 11	0.25	the was his that and had said him not sir room door did out but franklin there who what poirot
# 12	0.25	you the not have this your will that are shall said should and must what may now can yet who
# 13	0.25	the and his upon that you which holmes was with our have from had for there this down him your
# 14	0.25	her she not the for but catherine isabella was manfred had with thou would thy could what must from this
# 15	0.25	you and she her with all that what said your miss have out for was see can again say will
# 16	0.25	the this that with will any all until are from work watson these cried and said has project gutenberg for
# 17	0.25	the and were they with them there its through their one but seemed down saw into like had light out
# 18	0.25	and the that his for all not her when him was with she our but have then may must shall
# 19	0.25	that but have was the not very and had for one could would been there are now man what then
#
# <100> LL/token: -8.08123
# <110> LL/token: -8.05842
# <120> LL/token: -8.04263
# <130> LL/token: -8.02515
# <140> LL/token: -8.01003
# <150> LL/token: -7.9922
# <160> LL/token: -7.97999
# <170> LL/token: -7.97369
# <180> LL/token: -7.96607
# <190> LL/token: -7.95656
#
# 0	0.25	the and was door upon all from some which been into were every not what being room with nothing bed
# 1	0.25	the his and with they him their them who this were was himself any family where own its other house
# 2	0.25	the that was had which from for his would him this been found without time not left one first once
# 3	0.25	the that had her sergeant franklin when have rachel this diamond miss lady betteredge house and has with blake cuff
# 4	0.25	the tuppence tommy her she you but his julius was said they sir dont thats that james out with jane
# 5	0.25	her she and had with which was the could herself not for that much all when been though some would
# 6	0.25	her his and the with upon him for but your from agnes antonia then ambrosio lorenzo matilda till bosom himself
# 7	0.25	and but was when had for that father with heart ever felt yet dear which friend did all would could
# 8	0.25	the and emily that but for said montoni had then was this valancourt now who count his annette when they
# 9	0.25	and the said lord that him sir you for will but his edmund your baron all philip upon father son
# 10	0.25	the and which with that from their they aubert among its some more while sea road little mountains after upon
# 11	0.25	the his was that not and poirot mrs yes scrooge you had inglethorp cried john said did door its him
# 12	0.25	you not the have that your will this are said what shall should with must may can who from when
# 13	0.25	the his and which upon that holmes you our was this from with said had sir him have man your
# 14	0.25	her not she catherine the for but isabella manfred thou was tilney had would could very mrs thy miss young
# 15	0.25	you and was said what all for him out with she will time your her say about know room had
# 16	0.25	the this have its project that with gutenberg work upon any not will until all evidence are these for from
# 17	0.25	the and was were they with had there through this them night over its down but light could for saw
# 18	0.25	and the his that all not her for him when she our with but shall must then van may helsing
# 19	0.25	that have but and not there for very the been was would one could are had then has well now
#
# <200> LL/token: -7.94488
# <210> LL/token: -7.93754
# <220> LL/token: -7.93008
# <230> LL/token: -7.92471
# <240> LL/token: -7.9173
# <250> LL/token: -7.91293
# <260> LL/token: -7.9079
# <270> LL/token: -7.90557
# <280> LL/token: -7.90416
# <290> LL/token: -7.90336
#
# 0	0.25	the was and which upon door were from some what all every being been not room one voice nothing into
# 1	0.25	and his the with they him their them was were who himself this any where than family other house many
# 2	0.25	the that had which was his from this for would without him been first found time not made more these
# 3	0.25	the had sergeant and franklin that when have rachel this her diamond miss betteredge lady house has own blake cuff
# 4	0.25	the tuppence tommy her but his julius you she said was sir thats dont they that james know girl jane
# 5	0.25	her she and had was with the which that for could herself from been all not when such much than
# 6	0.25	the his and her upon him with for your but then agnes antonia this ambrosio lorenzo matilda from himself till
# 7	0.25	and but had for was father when that which all yet this heart felt ever life every friend our myself
# 8	0.25	the and emily that but for this said montoni had then valancourt his who count now annette him not madame
# 9	0.25	the and said lord his for sir him that edmund your but will baron all philip father upon son you
# 10	0.25	the and which with that from aubert their they his among mountains after upon scene little over some more were
# 11	0.25	the poirot his that scrooge not inglethorp mrs was john yes had but did cavendish its you said cynthia christmas
# 12	0.25	you not have that your will the are with what but this said shall and should can must may when
# 13	0.25	the his upon and which holmes you that our this had him from sir said man down has your watson
# 14	0.25	her not the catherine for she but isabella manfred had thou would tilney could miss mrs matilda thy morland thorpe
# 15	0.25	you and said was what all him for out with had will your room say that she about know see
# 16	0.25	the this and project with its gutenberg all have upon any not will from that for work about are these
# 17	0.25	the and was had with they were there them through but into out down its could for saw over their
# 18	0.25	and the his that all not for her him she when our but then shall van helsing may are with
# 19	0.25	that the have and but not there was very for been one would are could man when then with some
#
# [beta: 0.01803]
# <300> LL/token: -7.89677
# <310> LL/token: -7.9013
# <320> LL/token: -7.89867
# <330> LL/token: -7.89976
# <340> LL/token: -7.8996
# <350> LL/token: -7.89715
# <360> LL/token: -7.89456
# <370> LL/token: -7.89536
# <380> LL/token: -7.89541
# <390> LL/token: -7.894
#
# 0	0.35677	the and was which not upon door all into now some were what being room been from voice however nothing
# 1	0.36107	and the his with was their they him them were who himself other than father where family its these this
# 2	0.36732	the that had which was his from for him time this would been found first one without left made more
# 3	0.15317	the have sergeant franklin when rachel miss diamond this betteredge house lady and blake before cuff her godfrey own has
# 4	0.15321	the tuppence tommy her his she but julius sir you they was thats dont james jane girl its get well
# 5	0.3027	her she and was had with for the which could not herself been when would much such only all very
# 6	0.1477	his her and the upon him for with but this agnes antonia from your then ambrosio lorenzo matilda every till
# 7	0.30688	and but for when had that was which the with this myself heart every life yet these were from father
# 8	0.16905	the emily and that but this for montoni said had then his valancourt now who count annette him when madame
# 9	0.15112	the and lord said his sir for him edmund will baron but that philip your this then they son all
# 10	0.25435	the and which with that aubert they their from among mountains woods had over its scene now his some blanche
# 11	0.15125	the poirot his scrooge not inglethorp mrs was john but you yes cavendish did that sir cynthia christmas lawrence howard
# 12	0.33035	you not have that your the will and but with are said this what shall who may can should must
# 13	0.19606	the his upon which holmes and you our sir that him had from this all watson sherlock your said however
# 14	0.12602	not catherine her the but isabella for manfred tilney thou miss would they mrs thy could matilda morland thorpe general
# 15	0.34668	you and said what was all that him for had with out your about will know time see say room
# 16	0.17567	the this project with gutenberg its any upon from all and for work not will have works these body about
# 17	0.34039	the and was with had they were but there from its through out could them down for where night their
# 18	0.1836	and the his that not all for her him when she shall our van may helsing but must lucy are
# 19	0.36313	the that have but and not there was very been for are one would this then man some could when
#
# [beta: 0.02088]
# <400> LL/token: -7.89379
# <410> LL/token: -7.89216
# <420> LL/token: -7.89076
# <430> LL/token: -7.89022
# <440> LL/token: -7.88613
# <450> LL/token: -7.88806
# <460> LL/token: -7.88606
# <470> LL/token: -7.88081
# <480> LL/token: -7.88039
# <490> LL/token: -7.88132
#
# 0	0.42368	the and was which not door were now upon from some into what all heard here room being voice appeared
# 1	0.44077	and the his with was they their them him were who this father all its other than where himself day
# 2	0.46138	the that had which his from for was this been time him first found would left mind once more one
# 3	0.10148	the and have sergeant franklin miss when rachel diamond house betteredge lady has this with own blake cuff sir godfrey
# 4	0.10262	the tuppence tommy his julius but she her sir you they james dont thats mrs jane its girl said vandemeyer
# 5	0.3527	her she and was had with not could for the from herself been all which such much would when more
# 6	0.09161	his her and upon with but him your antonia agnes then for ambrosio lorenzo matilda every this bosom convent would
# 7	0.31217	and but which when that was had for with yet myself life these one every would before thus heart felt
# 8	0.11587	the and emily that but montoni this said for had then valancourt his when who would count now annette madame
# 9	0.10428	the and lord his said sir edmund for him baron but will that philip your then all upon they oswald
# 10	0.22995	the and that which with from aubert their they among over had now woods mountains little were after air along
# 11	0.07395	poirot his scrooge inglethorp mrs not was yes john the but cavendish you did sir its cynthia lawrence howard christmas
# 12	0.37754	you the that have not your will and this but with are him said his what for shall may who
# 13	0.14692	his upon which you holmes the and our that sir him from man your has with said had watson however
# 14	0.07159	not catherine but isabella manfred for tilney thou they mrs would miss matilda thy morland thorpe theodore said young allen
# 15	0.42424	you and was said what that all out him for had with about know your see say room good way
# 16	0.12116	the this project gutenberg upon with any its all not will work from about works are these marie body corpse
# 17	0.40485	the and was with had they there were for but could from through them its out night when down seemed
# 18	0.13752	and his the all not that for her him when she but our van shall may helsing which lucy must
# 19	0.44909	the that have and but not there was very been would are this one for then some were man who
#
# [beta: 0.02203]
# <500> LL/token: -7.87945
# <510> LL/token: -7.88026
# <520> LL/token: -7.88061
# <530> LL/token: -7.88092
# <540> LL/token: -7.8784
# <550> LL/token: -7.87917
# <560> LL/token: -7.8775
# <570> LL/token: -7.8773
# <580> LL/token: -7.87809
# <590> LL/token: -7.88036
#
# 0	0.45245	the and was which upon from not door some now were all into its room being one what heard their
# 1	0.4939	and the his with their they was were them him who all such father himself other own than day this
# 2	0.534	the that had was which his from for this been him time would first found more left these mind once
# 3	0.07819	the and sergeant franklin have miss when rachel diamond betteredge house with own lady blake has your cuff godfrey rosanna
# 4	0.07709	the tuppence tommy his julius but her sir she they you was james mrs thats dont jane said its girl
# 5	0.40101	her she and was had not for with the could herself when would from been all than before only might
# 6	0.0631	his her upon with but him and agnes antonia your ambrosio lorenzo then matilda for till convent without himself hand
# 7	0.28405	and but that when for which had was with yet these not life myself all our would every before man
# 8	0.09021	the and emily that but said montoni had this then valancourt who which count they his for now annette madame
# 9	0.07519	the and lord his said sir him edmund baron for philip will but your then they all upon oswald lovel
# 10	0.20678	the and that with which aubert from they their his now mountains woods had whose some among its for little
# 11	0.0426	poirot his scrooge inglethorp mrs john not but the yes cavendish was that did cynthia sir lawrence howard christmas ghost
# 12	0.41637	you the that have and not your with will this his but what are for shall said him may can
# 13	0.1111	his upon which you holmes that our sir had him from and man the your said however watson sherlock has
# 14	0.04817	not catherine but isabella manfred thou tilney said for mrs miss they thy matilda would morland thorpe theodore allen hippolita
# 15	0.48999	you and said that was what all him out had for about know room any say time your see now
# 16	0.08511	the this project gutenberg any all upon work and its with about will what from body marie works these than
# 17	0.45064	the and was with had were they but there his this could night out for when them from over through
# 18	0.10604	and that his all not for the her when him she our which van helsing shall but may then lucy
# 19	0.50812	the have and that not but there very was been with would for this one are some then could who
#
# [beta: 0.02239]
# <600> LL/token: -7.87761
# <610> LL/token: -7.87863
# <620> LL/token: -7.87759
# <630> LL/token: -7.88
# <640> LL/token: -7.88045
# <650> LL/token: -7.8779
# <660> LL/token: -7.88136
# <670> LL/token: -7.87869
# <680> LL/token: -7.88077
# <690> LL/token: -7.87712
#
# 0	0.45351	the and was which from upon not were door into all heard now some its who voice their one room
# 1	0.53111	and the his with their they was were them him all than who father day such any family other this
# 2	0.59275	the that had was which his from for this been time first found him these before left would made one
# 3	0.06406	the and sergeant franklin when have miss rachel diamond house betteredge own with has lady blake cuff this godfrey rosanna
# 4	0.06195	the tuppence tommy but julius his her you sir she was they said james mrs dont jane its thats girl
# 5	0.44315	her she and was had not for with could from the herself which been all such only when than more
# 6	0.04945	his her with but him upon and your agnes antonia that ambrosio lorenzo then matilda every for bosom till convent
# 7	0.25546	and but had that was which when for with life these myself towards felt could yet man did even all
# 8	0.07721	the and emily that but montoni said had this now then valancourt for which count when who annette his madame
# 9	0.05743	and the lord his said sir edmund him for baron will philip but that they upon your all then oswald
# 10	0.19312	the and that with which aubert they from had woods mountains some their over among where its light whose while
# 11	0.02915	poirot scrooge inglethorp mrs his not john yes did cavendish but sir cynthia you lawrence howard christmas its ghost cried
# 12	0.45364	you the and have that not his your will this with but are for him what said shall would may
# 13	0.08958	his which upon holmes you that and our sir from man had your all said him watson however sherlock small
# 14	0.03878	not catherine but isabella manfred said thou tilney mrs for miss thy matilda could morland thorpe theodore allen hippolita princess
# 15	0.54465	you and that said what was all him for out had about with know time your any room see say
# 16	0.06305	the this project gutenberg any with all upon work its for about body works what thus marie corpse these from
# 17	0.48393	the and was with his had were they there but for them could this when then out night over down
# 18	0.08491	and that all for not his her she when which van may our helsing him shall the must lucy are
# 19	0.55208	the have that and but not there was very been would with this are one then some could has for
#
# [beta: 0.02267]
# <700> LL/token: -7.87826
# <710> LL/token: -7.87665
# <720> LL/token: -7.87695
# <730> LL/token: -7.87953
# <740> LL/token: -7.87996
# <750> LL/token: -7.87974
# <760> LL/token: -7.87658
# <770> LL/token: -7.87275
# <780> LL/token: -7.87188
# <790> LL/token: -7.87118
#
# 0	0.45283	the and was which upon from not were door now into their some all heard voice who its what room
# 1	0.54574	and the his with was they their were them him all than such more who upon young being this father
# 2	0.6429	the that had was which his from for been this him first found time made after these before would one
# 3	0.0587	the and sergeant franklin when miss rachel have diamond betteredge house with this own has lady blake cuff godfrey sir
# 4	0.05503	the tuppence tommy julius but his you sir her she dont james mrs was jane thats they its vandemeyer got
# 5	0.47405	her she and was had not for could with the herself from been when all would such very than only
# 6	0.04208	his her with upon but him antonia agnes ambrosio lorenzo your that matilda then every bosom convent soon don while
# 7	0.23435	and but that had which was when for with these myself even every life all man did thus yet eyes
# 8	0.07179	the emily that and but had montoni said this valancourt with for now then count which his they annette who
# 9	0.05068	and the his lord said sir him edmund baron will they philip for your that all then oswald them upon
# 10	0.18085	the and with which that aubert from they woods over its among now mountains for after their little while whose
# 11	0.02257	poirot scrooge inglethorp mrs his not that yes you john cavendish did its was cynthia sir lawrence christmas but howard
# 12	0.4816	you the and have not that your his with will this but him for are said what shall would should
# 13	0.07717	his which upon you holmes that and sir our man your from said had has watson sherlock however all small
# 14	0.0368	not catherine but isabella manfred for thou tilney said mrs miss matilda thy thorpe theodore morland allen hippolita lord princess
# 15	0.59458	you that and said what him all for was out had with about have room see know little any say
# 16	0.0494	the this project gutenberg with any all upon work its for works other about marie corpse what body her thus
# 17	0.51742	the and was with his had they were there but for could this them night then out one down from
# 18	0.07584	and that all not for his her when she him which van helsing may shall our must some are lucy
# 19	0.58387	the and have that but not was there very been would this are one with will some for then has
#
# [beta: 0.0228]
# <800> LL/token: -7.87142
# <810> LL/token: -7.87016
# <820> LL/token: -7.87271
# <830> LL/token: -7.87393
# <840> LL/token: -7.87252
# <850> LL/token: -7.87436
# <860> LL/token: -7.87062
# <870> LL/token: -7.87182
# <880> LL/token: -7.87267
# <890> LL/token: -7.87105
#
# 0	0.44825	the and which was from upon were not some all door heard their its into who now what voice room
# 1	0.55157	and the his with they their was were them all such than but being father who young other upon any
# 2	0.68604	the that was had which his from for this him been first time found one made more these some after
# 3	0.05708	the and sergeant franklin miss when rachel with diamond have betteredge house has lady blake cuff godfrey own rosanna your
# 4	0.05158	the tuppence tommy but julius his sir they james mrs its jane thats dont she her girl vandemeyer get got
# 5	0.49932	her she and was had not for with could herself been would the from when which only but than should
# 6	0.03507	his her upon with him antonia agnes but ambrosio lorenzo your then matilda every that bosom them for convent till
# 7	0.2178	and but that which when for had was with man did thus life could eyes towards myself our not these
# 8	0.0676	the emily that and but had montoni said this now valancourt was count then for annette madame they which his
# 9	0.04583	and lord his the said sir him edmund baron will they philip for all that then your them oswald upon
# 10	0.17347	the and that with which aubert from they woods their where mountains now its over among for whose some had
# 11	0.01941	poirot scrooge inglethorp mrs not his was john but yes cavendish that its did cynthia sir lawrence howard christmas ghost
# 12	0.50489	you and the that have not your with his will this but him for what are shall said would may
# 13	0.06765	his upon which holmes you that our from sir had man your watson sherlock said however and all small for
# 14	0.03399	not catherine isabella manfred said but thou tilney mrs miss for matilda thy theodore thorpe morland allen hippolita lord princess
# 15	0.63291	you that said what and was him for all out about had know your have room see say any with
# 16	0.04343	the this gutenberg project any upon all for work from with its about her works marie corpse body these other
# 17	0.54495	the and was with his had they were but there for them could then this out one night him over
# 18	0.06808	and that all not for his when her she van our helsing shall him may must lucy which are some
# 19	0.59907	the and have that not but very been there would this was are with will one has then who some
#
# [beta: 0.02298]
# <900> LL/token: -7.87141
# <910> LL/token: -7.87128
# <920> LL/token: -7.87285
# <930> LL/token: -7.87142
# <940> LL/token: -7.87347
# <950> LL/token: -7.87309
# <960> LL/token: -7.87231
# <970> LL/token: -7.8709
# <980> LL/token: -7.873
# <990> LL/token: -7.87255
#
# 0	0.44653	the and was which from upon were that not door their some heard all into its now who voice than
# 1	0.55633	and the his with they their were was them all than such young other any more very old being every
# 2	0.72389	the that was had which his for from this been him found time first made after without these one himself
# 3	0.05376	the and sergeant franklin when miss rachel with diamond betteredge house have has this lady blake cuff godfrey rosanna your
# 4	0.0491	the tuppence tommy but julius sir his they dont james thats mrs jane she its get girl vandemeyer know got
# 5	0.52227	her she and had was not the for could but with herself from would been when only all much should
# 6	0.03218	his her with upon antonia agnes then ambrosio lorenzo him matilda but your that every till bosom convent don nuns
# 7	0.20492	and but when that was which had for myself could did our life every these towards even man might feelings
# 8	0.06711	the emily and that but montoni said had then this valancourt now which who count was annette for they madame
# 9	0.04463	and the his lord said sir him edmund baron will they philip but your all for that then them oswald
# 10	0.16346	the and that with which aubert from they had woods among where mountains little over this light now along after
# 11	0.01903	poirot scrooge inglethorp mrs his not was john yes cavendish but did cynthia lawrence howard ghost sir cried christmas its
# 12	0.52205	you and the his have not that your with this will but him for are would shall what said may
# 13	0.06223	his which upon holmes that you our sir from your watson sherlock however had man all until moor down henry
# 14	0.03264	catherine not isabella manfred but said thou tilney mrs for miss matilda thy morland thorpe theodore allen hippolita princess prince
# 15	0.66297	you that said and what was him all for out have about know with there your had see say little
# 16	0.03579	the this project gutenberg any upon all with its work about other body works not marie thus corpse these from
# 17	0.5759	the and was his with had but they for there were could this him them one when night down out
# 18	0.06462	and that all not for when her his our van she shall helsing which may are lucy must have him
# 19	0.607	the and have that not but very been would this was there are with has one will could some when
#
# [beta: 0.02299]
# <1000> LL/token: -7.87611
#
# Total time: 2 minutes 1 seconds

# %% [markdown]
# ## Appendix
#
# ### Mallet
#
# Website: https://mimno.github.io/Mallet/
#
# MALLET is a Java-based package for statistical natural language processing, document classification, clustering, topic modeling, information extraction, and other machine learning applications to text.
#
# MALLET includes sophisticated tools for document classification: efficient routines for converting text to "features", a wide variety of algorithms (including Naïve Bayes, Maximum Entropy, and Decision Trees), and code for evaluating classifier performance using several commonly used metrics.
#
# In addition to classification, MALLET includes tools for sequence tagging for applications such as named-entity extraction from text. Algorithms include Hidden Markov Models, Maximum Entropy Markov Models, and Conditional Random Fields. These methods are implemented in an extensible system for finite state transducers.
#
# Topic models are useful for analyzing large collections of unlabeled text. The MALLET topic modeling toolkit contains efficient, sampling-based implementations of Latent Dirichlet Allocation, Pachinko Allocation, and Hierarchical LDA.
#
# Many of the algorithms in MALLET depend on numerical optimization. MALLET includes an efficient implementation of Limited Memory BFGS, among many other optimization methods.
#
# In addition to sophisticated Machine Learning applications, MALLET includes routines for transforming text documents into numerical representations that can then be processed efficiently. This process is implemented through a flexible system of "pipes", which handle distinct tasks such as tokenizing strings, removing stopwords, and converting sequences into count vectors.
#
# An add-on package to MALLET, called GRMM, contains support for inference in general graphical models, and training of CRFs with arbitrary graphical structure.
#
# ### Installation
#
# To build a Mallet 2.0 development release, you must have the Apache ant build tool installed. From the command prompt, first change to the mallet directory, and then type
# `ant`
#
# If `ant` finishes with `"BUILD SUCCESSFUL"`, Mallet is now ready to use.
#
# If you would like to deploy Mallet as part of a larger application, it is helpful to create a single ".jar" file that contains all of the compiled code. Once you have compiled the individual Mallet class files, use the command:
# `ant jar`
#
# This process will create a file "mallet.jar" in the "dist" directory within Mallet.
#
# ### Usage
#
# Once you have installed Mallet you can use it using the following command:
#
# ```bash
# bin/mallet [command] --option value --option value ...
# ```
# Type `bin/mallet` to get a list of commands, and use the option `--help` with any command to get a description of valid options.
#
# For details about the commands please visit the API documentation and website at: https://mimno.github.io/Mallet/
#
#
# ### List of Algorithms
#
# * Topic Modelling
#   * LDA
#   * Parallel LDA
#   * DMR LDA
#   * Hierarchical LDA
#   * Labeled LDA
#   * Polylingual Topic Model
#   * Hierarchical Pachinko Allocation Model (PAM)
#   * Weighted Topic Model
#   * LDA with integrated phrase discovery
#   * Word Embeddings (word2vec) using skip-gram with negative sampling
# * Classification
#   * AdaBoost
#   * Bagging
#   * Winnow
#   * C45 Decision Tree
#   * Ensemble Trainer
#   * Maximum Entropy Classifier (Multinomial Logistic Regression)
#   * Naive Bayes
#   * Rank Maximum Entropy Classifier
#   * Posterior Regularization Auxiliary Model
# * Clustering
#   * Greedy Agglomerative
#   * Hill Climbing
#   * K-Means
#   * K-Best
# * Sequence Prediction Models
#   * Conditional Random Fields
#   * Maximum Entropy Markov Models
#   * Hidden Markov Models
#   * Semi-Supervised Sequence Prediction Models
# * Linear Regression
